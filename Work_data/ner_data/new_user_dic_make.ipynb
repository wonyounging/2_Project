# %% [markdown]
# # 새로운 user_dic 만들기

# %%
import pandas as pd

# %%
new_user_dict = []

# %%
# 파일 경로
file_path = 'c:/2nd_project/Data/ner_tag_data_10.txt'

# 파일 열기
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

txts = []
# 파일 내용 줄 단위로 출력
for line in lines:
    txts.append(line.strip())

txts
# Out:
# ['0시\tNNG\tB_DT',
#  '1시\tNNG\tB_DT',
#  '2시\tNNG\tB_DT',
#  '3시\tNNG\tB_DT',
#  '4시\tNNG\tB_DT',
#  '5시\tNNG\tB_DT',
#  '6시\tNNG\tB_DT',
#  '7시\tNNG\tB_DT',
#  '8시\tNNG\tB_DT',
#  '9시\tNNG\tB_DT',
#  '10시\tNNG\tB_DT',
#  '11시\tNNG\tB_DT',
#  '12시\tNNG\tB_DT',
#  '13시\tNNG\tB_DT',
#  '14시\tNNG\tB_DT',
#  '15시\tNNG\tB_DT',
#  '16시\tNNG\tB_DT',
#  '17시\tNNG\tB_DT',
#  '18시\tNNG\tB_DT',
#  '19시\tNNG\tB_DT',
#  '20시\tNNG\tB_DT',
#  '21시\tNNG\tB_DT',
#  '22시\tNNG\tB_DT',
#  '23시\tNNG\tB_DT',
#  '24시\tNNG\tB_DT',
#  '0분\tNNG\tB_DT',
#  '1분\tNNG\tB_DT',
#  '2분\tNNG\tB_DT',
#  '3분\tNNG\tB_DT',
#  '4분\tNNG\tB_DT',
#  '5분\tNNG\tB_DT',
#  '6분\tNNG\tB_DT',
#  '7분\tNNG\tB_DT',
#  '8분\tNNG\tB_DT',
#  '9분\tNNG\tB_DT',
#  '10분\tNNG\tB_DT',
#  '11분\tNNG\tB_DT',
#  '12분\tNNG\tB_DT',
#  '13분\tNNG\tB_DT',
#  '14분\tNNG\tB_DT',
#  '15분\tNNG\tB_DT',
#  '16분\tNNG\tB_DT',
#  '17분\tNNG\tB_DT',
#  '18분\tNNG\tB_DT',
#  '19분\tNNG\tB_DT',
#  '20분\tNNG\tB_DT',
#  '21분\tNNG\tB_DT',
#  '22분\tNNG\tB_DT',
#  '23분\tNNG\tB_DT',
#  '24분\tNNG\tB_DT',
#  '25분\tNNG\tB_DT',
#  '26분\tNNG\tB_DT',
#  '27분\tNNG\tB_DT',
#  '28분\tNNG\tB_DT',
#  '29분\tNNG\tB_DT',
#  '30분\tNNG\tB_DT',
#  '31분\tNNG\tB_DT',
#  '32분\tNNG\tB_DT',
#  '33분\tNNG\tB_DT',
#  '34분\tNNG\tB_DT',
#  '35분\tNNG\tB_DT',
#  '36분\tNNG\tB_DT',
#  '37분\tNNG\tB_DT',
#  '38분\tNNG\tB_DT',
#  '39분\tNNG\tB_DT',
#  '40분\tNNG\tB_DT',
#  '41분\tNNG\tB_DT',
#  '42분\tNNG\tB_DT',
#  '43분\tNNG\tB_DT',
#  '44분\tNNG\tB_DT',
#  '45분\tNNG\tB_DT',
#  '46분\tNNG\tB_DT',
#  '47분\tNNG\tB_DT',
#  '48분\tNNG\tB_DT',
#  '49분\tNNG\tB_DT',
#  '50분\tNNG\tB_DT',
#  '51분\tNNG\tB_DT',
#  '52분\tNNG\tB_DT',
#  '53분\tNNG\tB_DT',
#  '54분\tNNG\tB_DT',
#  '55분\tNNG\tB_DT',
#  '56분\tNNG\tB_DT',
#  '57분\tNNG\tB_DT',
#  '58분\tNNG\tB_DT',
#  '59분\tNNG\tB_DT',
#  '60분\tNNG\tB_DT',
#  '1월\tNNG\tB_DT',
#  '2월\tNNG\tB_DT',
#  '3월\tNNG\tB_DT',
#  '4월\tNNG\tB_DT',
#  '5월\tNNG\tB_DT',
#  '6월\tNNG\tB_DT',
#  '7월\tNNG\tB_DT',
#  '8월\tNNG\tB_DT',
#  '9월\tNNG\tB_DT',
#  '10월\tNNG\tB_DT',
#  '11월\tNNG\tB_DT',
#  '12월\tNNG\tB_DT',
#  '1일\tNNG\tB_DT',
#  '2일\tNNG\tB_DT',
#  '3일\tNNG\tB_DT',
#  '4일\tNNG\tB_DT',
#  '5일\tNNG\tB_DT',
#  '6일\tNNG\tB_DT',
#  '7일\tNNG\tB_DT',
#  '8일\tNNG\tB_DT',
#  '9일\tNNG\tB_DT',
#  '10일\tNNG\tB_DT',
#  '11일\tNNG\tB_DT',
#  '12일\tNNG\tB_DT',
#  '13일\tNNG\tB_DT',
#  '14일\tNNG\tB_DT',
#  '15일\tNNG\tB_DT',
#  '16일\tNNG\tB_DT',
#  '17일\tNNG\tB_DT',
#  '18일\tNNG\tB_DT',
#  '19일\tNNG\tB_DT',
#  '20일\tNNG\tB_DT',
#  '21일\tNNG\tB_DT',
#  '22일\tNNG\tB_DT',
#  '23일\tNNG\tB_DT',
#  '24일\tNNG\tB_DT',
#  '25일\tNNG\tB_DT',
#  '26일\tNNG\tB_DT',
#  '27일\tNNG\tB_DT',
#  '28일\tNNG\tB_DT',
#  '29일\tNNG\tB_DT',
#  '30일\tNNG\tB_DT',
#  '31일\tNNG\tB_DT',
#  '월요일\tNNG\tB_DT',
#  '화요일\tNNG\tB_DT',
#  '수요일\tNNG\tB_DT',
#  '목요일\tNNG\tB_DT',
#  '금요일\tNNG\tB_DT',
#  '토요일\tNNG\tB_DT',
#  '일요일\tNNG\tB_DT',
#  '#살아있다\tNNG\tB_MOVIE',
#  '0.0MHz\tNNG\tB_MOVIE',
#  '007 노 타임 투 다이\tNNG\tB_MOVIE',
#  '007 스카이폴\tNNG\tB_MOVIE',
#  '007 스펙터\tNNG\tB_MOVIE',
#  '007 카지노 로얄\tNNG\tB_MOVIE',
#  '007 퀀텀 오브 솔러스\tNNG\tB_MOVIE',
#  '10,000 BC\tNNG\tB_MOVIE',
#  '10억\tNNG\tB_MOVIE',
#  '12 솔져스\tNNG\tB_MOVIE',
#  '127시간\tNNG\tB_MOVIE',
#  '13구역\tNNG\tB_MOVIE',
#  '13구역: 얼티메이텀\tNNG\tB_MOVIE',
#  '13시간\tNNG\tB_MOVIE',
#  '13일의 금요일\tNNG\tB_MOVIE',
#  '1408\tNNG\tB_MOVIE',
#  '1724 기방난동사건\tNNG\tB_MOVIE',
#  '1917\tNNG\tB_MOVIE',
#  '1987\tNNG\tB_MOVIE',
#  '19곰 테드\tNNG\tB_MOVIE',
#  '19곰 테드 2\tNNG\tB_MOVIE',
#  '1급기밀\tNNG\tB_MOVIE',
#  '1번가의 기적\tNNG\tB_MOVIE',
#  '2012\tNNG\tB_MOVIE',
#  '2046\tNNG\tB_MOVIE',
#  '20세기 소년\tNNG\tB_MOVIE',
#  '21\tNNG\tB_MOVIE',
#  '21 브릿지: 테러 셧다운\tNNG\tB_MOVIE',
#  '22 블렛\tNNG\tB_MOVIE',
#  '23 아이덴티티\tNNG\tB_MOVIE',
#  '26년\tNNG\tB_MOVIE',
#  '27번의 결혼리허설\tNNG\tB_MOVIE',
#  '300\tNNG\tB_MOVIE',
#  '300: 제국의 부활\tNNG\tB_MOVIE',
#  '4.4.4\tNNG\tB_MOVIE',
#  '47 미터\tNNG\tB_MOVIE',
#  '47미터 2\tNNG\tB_MOVIE',
#  '50/50\tNNG\tB_MOVIE',
#  '500일의 썸머\tNNG\tB_MOVIE',
#  '50가지 그림자: 심연\tNNG\tB_MOVIE',
#  '50가지 그림자: 해방\tNNG\tB_MOVIE',
#  '5백만불의 사나이\tNNG\tB_MOVIE',
#  '6년째 연애중\tNNG\tB_MOVIE',
#  '6월의 일기\tNNG\tB_MOVIE',
#  '7광구\tNNG\tB_MOVIE',
#  '7급 공무원\tNNG\tB_MOVIE',
#  '7년의 밤\tNNG\tB_MOVIE',
#  '7번방의 선물\tNNG\tB_MOVIE',
#  '7호실\tNNG\tB_MOVIE',
#  '80일간의 세계 일주\tNNG\tB_MOVIE',
#  '82년생 김지영\tNNG\tB_MOVIE',
#  '88분\tNNG\tB_MOVIE',
#  '8인: 최후의 결사단\tNNG\tB_MOVIE',
#  'A-특공대\tNNG\tB_MOVIE',
#  'BB프로젝트\tNNG\tB_MOVIE',
#  'B형 남자친구\tNNG\tB_MOVIE',
#  'CJ7:장강7호\tNNG\tB_MOVIE',
#  'DC 리그 오브 슈퍼-펫\tNNG\tB_MOVIE',
#  'DMZ, 비무장지대\tNNG\tB_MOVIE',
#  'DOA\tNNG\tB_MOVIE',
#  'GP 506\tNNG\tB_MOVIE',
#  'Mr.로빈 꼬시기\tNNG\tB_MOVIE',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG\tB_MOVIE',
#  'P.S. 아이 러브 유\tNNG\tB_MOVIE',
#  'PMC: 더 벙커\tNNG\tB_MOVIE',
#  'R.I.P.D. : 알.아이.피.디.\tNNG\tB_MOVIE',
#  'R2B: 리턴투베이스\tNNG\tB_MOVIE',
#  'S 다이어리\tNNG\tB_MOVIE',
#  'pm 11:14\tNNG\tB_MOVIE',
#  '가디언\tNNG\tB_MOVIE',
#  '가디언의 전설\tNNG\tB_MOVIE',
#  '가디언즈\tNNG\tB_MOVIE',
#  '가디언즈 오브 갤럭시\tNNG\tB_MOVIE',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG\tB_MOVIE',
#  '가려진 시간\tNNG\tB_MOVIE',
#  '가루지기\tNNG\tB_MOVIE',
#  '가면\tNNG\tB_MOVIE',
#  '가문의 부활 - 가문의 영광3\tNNG\tB_MOVIE',
#  '가문의 영광4 - 가문의 수난\tNNG\tB_MOVIE',
#  '가문의 영광5 - 가문의 귀환\tNNG\tB_MOVIE',
#  '가문의 위기(가문의 영광2)\tNNG\tB_MOVIE',
#  '가발\tNNG\tB_MOVIE',
#  '가버나움\tNNG\tB_MOVIE',
#  '가부와 메이 이야기\tNNG\tB_MOVIE',
#  '가비\tNNG\tB_MOVIE',
#  '가시\tNNG\tB_MOVIE',
#  '가을로\tNNG\tB_MOVIE',
#  '가장 보통의 연애\tNNG\tB_MOVIE',
#  '가족\tNNG\tB_MOVIE',
#  '가족의 탄생\tNNG\tB_MOVIE',
#  '가필드\tNNG\tB_MOVIE',
#  '가필드 2\tNNG\tB_MOVIE',
#  '각설탕\tNNG\tB_MOVIE',
#  '간 큰 가족\tNNG\tB_MOVIE',
#  '간기남\tNNG\tB_MOVIE',
#  '간신\tNNG\tB_MOVIE',
#  '간첩\tNNG\tB_MOVIE',
#  '감기\tNNG\tB_MOVIE',
#  '감바의 대모험\tNNG\tB_MOVIE',
#  '감시자들\tNNG\tB_MOVIE',
#  '감쪽같은 그녀\tNNG\tB_MOVIE',
#  '갓 오브 이집트\tNNG\tB_MOVIE',
#  '강남 1970\tNNG\tB_MOVIE',
#  '강력 3반\tNNG\tB_MOVIE',
#  '강릉\tNNG\tB_MOVIE',
#  '강적\tNNG\tB_MOVIE',
#  '강철대오:구국의 철가방\tNNG\tB_MOVIE',
#  '강철비\tNNG\tB_MOVIE',
#  '강철비2: 정상회담\tNNG\tB_MOVIE',
#  '강철중: 공공의 적 1-1\tNNG\tB_MOVIE',
#  '개구쟁이 스머프\tNNG\tB_MOVIE',
#  '개구쟁이 스머프 2\tNNG\tB_MOVIE',
#  '개를 훔치는 완벽한 방법\tNNG\tB_MOVIE',
#  '거룩한 계보\tNNG\tB_MOVIE',
#  '거북이 달린다\tNNG\tB_MOVIE',
#  '거울나라의 앨리스\tNNG\tB_MOVIE',
#  '건축학개론\tNNG\tB_MOVIE',
#  '걸리버 여행기\tNNG\tB_MOVIE',
#  '걸스카우트\tNNG\tB_MOVIE',
#  '걸캅스\tNNG\tB_MOVIE',
#  '걸프렌즈\tNNG\tB_MOVIE',
#  '검객\tNNG\tB_MOVIE',
#  '검사외전\tNNG\tB_MOVIE',
#  '검우강호\tNNG\tB_MOVIE',
#  '검은 사제들\tNNG\tB_MOVIE',
#  '검은 집\tNNG\tB_MOVIE',
#  '겁나는 여친의 완벽한 비밀\tNNG\tB_MOVIE',
#  '게드전기 : 어스시의 전설\tNNG\tB_MOVIE',
#  '게스후\tNNG\tB_MOVIE',
#  '게이머\tNNG\tB_MOVIE',
#  '게이샤의 추억\tNNG\tB_MOVIE',
#  '게이트\tNNG\tB_MOVIE',
#  '겟 스마트\tNNG\tB_MOVIE',
#  '겟 썸\tNNG\tB_MOVIE',
#  '겟 아웃\tNNG\tB_MOVIE',
#  '겨울왕국\tNNG\tB_MOVIE',
#  '겨울왕국 2\tNNG\tB_MOVIE',
#  '결백\tNNG\tB_MOVIE',
#  '결혼전야\tNNG\tB_MOVIE',
#  '경관의 피\tNNG\tB_MOVIE',
#  '경성학교: 사라진 소녀들\tNNG\tB_MOVIE',
#  '계춘할망\tNNG\tB_MOVIE',
#  '고死 : 피의 중간고사\tNNG\tB_MOVIE',
#  '고死 두 번째 이야기: 교생실습\tNNG\tB_MOVIE',
#  '고고 70\tNNG\tB_MOVIE',
#  '고령화 가족\tNNG\tB_MOVIE',
#  '고산자, 대동여지도\tNNG\tB_MOVIE',
#  '고스트 라이더\tNNG\tB_MOVIE',
#  '고스트 라이더 : 복수의 화신\tNNG\tB_MOVIE',
#  '고스트버스터즈\tNNG\tB_MOVIE',
#  '고스트버스터즈 라이즈\tNNG\tB_MOVIE',
#  '고양이: 죽음을 보는 두 개의 눈\tNNG\tB_MOVIE',
#  '고장난 론\tNNG\tB_MOVIE',
#  '고지전\tNNG\tB_MOVIE',
#  '고질라\tNNG\tB_MOVIE',
#  '고질라 VS. 콩\tNNG\tB_MOVIE',
#  '고질라: 킹 오브 몬스터\tNNG\tB_MOVIE',
#  '곡성\tNNG\tB_MOVIE',
#  '곤지암\tNNG\tB_MOVIE',
#  '골든 에이지\tNNG\tB_MOVIE',
#  '골든슬럼버\tNNG\tB_MOVIE',
#  '곰돌이 푸 다시 만나 행복해\tNNG\tB_MOVIE',
#  '공각기동대 : 고스트 인 더 쉘\tNNG\tB_MOVIE',
#  '공공의 적 2\tNNG\tB_MOVIE',
#  '공기살인\tNNG\tB_MOVIE',
#  '공모자들\tNNG\tB_MOVIE',
#  '공범\tNNG\tB_MOVIE',
#  '공범자들\tNNG\tB_MOVIE',
#  '공자 춘추전국시대\tNNG\tB_MOVIE',
#  '공작\tNNG\tB_MOVIE',
#  '공작부인:세기의 스캔들\tNNG\tB_MOVIE',
#  '공조\tNNG\tB_MOVIE',
#  '공조2: 인터내셔날\tNNG\tB_MOVIE',
#  '공주와 개구리\tNNG\tB_MOVIE',
#  '공포의 묘지\tNNG\tB_MOVIE',
#  '공필두\tNNG\tB_MOVIE',
#  '과속스캔들\tNNG\tB_MOVIE',
#  '관능의 법칙\tNNG\tB_MOVIE',
#  '관상\tNNG\tB_MOVIE',
#  '광대들: 풍문조작단\tNNG\tB_MOVIE',
#  '광식이 동생 광태\tNNG\tB_MOVIE',
#  '광해, 왕이 된 남자\tNNG\tB_MOVIE',
#  '괴물\tNNG\tB_MOVIE',
#  '괴물의 아이\tNNG\tB_MOVIE',
#  '교회오빠\tNNG\tB_MOVIE',
#  '구르믈 버서난 달처럼\tNNG\tB_MOVIE',
#  '구미호 가족\tNNG\tB_MOVIE',
#  '구세주\tNNG\tB_MOVIE',
#  '구세주 2\tNNG\tB_MOVIE',
#  '구스범스\tNNG\tB_MOVIE',
#  '구타유발자들\tNNG\tB_MOVIE',
#  '국가대표\tNNG\tB_MOVIE',
#  '국가대표 2\tNNG\tB_MOVIE',
#  '국가대표 완결판-못 다한 이야기\tNNG\tB_MOVIE',
#  '국가부도의 날\tNNG\tB_MOVIE',
#  '국경의 남쪽\tNNG\tB_MOVIE',
#  '국제수사\tNNG\tB_MOVIE',
#  '국제시장\tNNG\tB_MOVIE',
#  '군도: 민란의 시대\tNNG\tB_MOVIE',
#  '군함도\tNNG\tB_MOVIE',
#  '굿 다이노\tNNG\tB_MOVIE',
#  '굿모닝 에브리원\tNNG\tB_MOVIE',
#  '굿모닝 프레지던트\tNNG\tB_MOVIE',
#  '굿바이\tNNG\tB_MOVIE',
#  '굿바이 싱글\tNNG\tB_MOVIE',
#  '궁녀\tNNG\tB_MOVIE',
#  '궁합\tNNG\tB_MOVIE',
#  '권순분여사 납치사건\tNNG\tB_MOVIE',
#  '귀신이 산다\tNNG\tB_MOVIE',
#  '귀향\tNNG\tB_MOVIE',
#  '그 여자 작사 그 남자 작곡\tNNG\tB_MOVIE',
#  '그것\tNNG\tB_MOVIE',
#  '그것: 두 번째 이야기\tNNG\tB_MOVIE',
#  '그것만이 내 세상\tNNG\tB_MOVIE',
#  '그날, 바다\tNNG\tB_MOVIE',
#  '그날의 분위기\tNNG\tB_MOVIE',
#  '그녀\tNNG\tB_MOVIE',
#  '그녀는 요술쟁이\tNNG\tB_MOVIE',
#  '그녀를 믿지 마세요\tNNG\tB_MOVIE',
#  '그놈 목소리\tNNG\tB_MOVIE',
#  '그놈은 멋있었다\tNNG\tB_MOVIE',
#  '그놈이다\tNNG\tB_MOVIE',
#  '그는 당신에게 반하지 않았다\tNNG\tB_MOVIE',
#  '그대가 조국\tNNG\tB_MOVIE',
#  '그대를 사랑합니다\tNNG\tB_MOVIE',
#  '그때 그 사람들\tNNG\tB_MOVIE',
#  '그랑프리\tNNG\tB_MOVIE',
#  '그래비티\tNNG\tB_MOVIE',
#  '그랜 토리노\tNNG\tB_MOVIE',
#  '그랜드 부다페스트 호텔\tNNG\tB_MOVIE',
#  '그렇게 아버지가 된다\tNNG\tB_MOVIE',
#  '그레이스 오브 모나코\tNNG\tB_MOVIE',
#  '그레이의 50가지 그림자\tNNG\tB_MOVIE',
#  '그레이트 월\tNNG\tB_MOVIE',
#  '그루지\tNNG\tB_MOVIE',
#  '그루지 2\tNNG\tB_MOVIE',
#  '그린 북\tNNG\tB_MOVIE',
#  '그린 존\tNNG\tB_MOVIE',
#  '그린 호넷\tNNG\tB_MOVIE',
#  '그린랜드\tNNG\tB_MOVIE',
#  '그린랜턴: 반지의 선택\tNNG\tB_MOVIE',
#  '그린치\tNNG\tB_MOVIE',
#  '그림자 살인\tNNG\tB_MOVIE',
#  '그림형제 : 마르바덴 숲의 전설\tNNG\tB_MOVIE',
#  '그해 여름\tNNG\tB_MOVIE',
#  '극락도 살인사건\tNNG\tB_MOVIE',
#  '극비수사\tNNG\tB_MOVIE',
#  '극장판 공룡메카드: 타이니소어의 섬\tNNG\tB_MOVIE',
#  '극장판 귀멸의 칼날: 무한열차편\tNNG\tB_MOVIE',
#  '극장판 꼬마버스 타요의 에이스 구출작전\tNNG\tB_MOVIE',
#  '극장판 도라에몽 : 진구의 우주영웅기~스페이스 히어로즈~\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구와 기적의 섬 애니멀 어드벤처\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구와 철인군단 날아라 천사들\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 공룡대탐험\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 남극 꽁꽁 대모험\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 보물섬\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 비밀도구 박물관\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 아프리카 모험 ~베코와 5인의 탐험대~\tNNG\tB_MOVIE',
#  '극장판 도라에몽: 진구의 인어대해전\tNNG\tB_MOVIE',
#  '극장판 도라에몽:진구의 마계대모험 7인의 마법사\tNNG\tB_MOVIE',
#  '극장판 또봇: 로봇군단의 습격\tNNG\tB_MOVIE',
#  '극장판 루팡 3세 VS 명탐정 코난\tNNG\tB_MOVIE',
#  '극장판 뽀로로와 친구들: 바이러스를 없애줘!\tNNG\tB_MOVIE',
#  '극장판 소드 아트 온라인 -오디널 스케일-\tNNG\tB_MOVIE',
#  '극장판 아이엠스타 : 꿈의 오디션!\tNNG\tB_MOVIE',
#  '극장판 안녕 자두야\tNNG\tB_MOVIE',
#  '극장판 안녕 자두야: 제주도의 비밀\tNNG\tB_MOVIE',
#  '극장판 엄마 까투리: 도시로 간 까투리 가족\tNNG\tB_MOVIE',
#  '극장판 엉덩이 탐정: 수플레 섬의 비밀\tNNG\tB_MOVIE',
#  '극장판 엉덩이 탐정: 화려한 사건 수첩\tNNG\tB_MOVIE',
#  '극장판 에그엔젤 코코밍: 푸르밍과 두근두근 코코밍 세계\tNNG\tB_MOVIE',
#  '극장판 요괴워치 섀도사이드: 도깨비왕의 부활\tNNG\tB_MOVIE',
#  '극장판 요괴워치: 염라대왕과 5개의 이야기다냥!\tNNG\tB_MOVIE',
#  '극장판 요괴워치: 탄생의 비밀이다냥!\tNNG\tB_MOVIE',
#  '극장판 요괴워치: 하늘을 나는 고래와 더블세계다냥!\tNNG\tB_MOVIE',
#  '극장판 주술회전 0\tNNG\tB_MOVIE',
#  '극장판 짱구는 못말려 : 습격!! 외계인 덩덩이\tNNG\tB_MOVIE',
#  '극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들\tNNG\tB_MOVIE',
#  '극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교\tNNG\tB_MOVIE',
#  '극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!\tNNG\tB_MOVIE',
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~\tNNG\tB_MOVIE',
#  '극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~\tNNG\tB_MOVIE',
#  '극장판 파워레인저 트레인포스 VS 다이노포스 THE MOVIE\tNNG\tB_MOVIE',
#  '극장판 파워레인저: 캡틴포스 VS 미라클포스 199 히어로 대결전\tNNG\tB_MOVIE',
#  '극장판 포켓 몬스터 DP 「환영의 패왕 조로아크」\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 XY : 파괴의 포켓몬과 디안시\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 너로 정했다!\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 모두의 이야기\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 베스트위시: 신의 속도 게노세크트, 뮤츠의 각성\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 베스트위시「메로엣타의 반짝반짝 음악회」\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터: 정글의 아이, 코코\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이\tNNG\tB_MOVIE',
#  '극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미\tNNG\tB_MOVIE',
#  '극장판 헬로카봇 : 달나라를 구해줘!\tNNG\tB_MOVIE',
#  '극장판 헬로카봇 : 백악기 시대\tNNG\tB_MOVIE',
#  '극장판 헬로카봇: 수상한 마술단의 비밀\tNNG\tB_MOVIE',
#  '극장판 헬로카봇: 옴파로스 섬의 비밀\tNNG\tB_MOVIE',
#  '극장판파워레인저 엔진포스VS 와일드스피릿\tNNG\tB_MOVIE',
#  '극적인 하룻밤\tNNG\tB_MOVIE',
#  '극한직업\tNNG\tB_MOVIE',
#  '글래스\tNNG\tB_MOVIE',
#  '글러브\tNNG\tB_MOVIE',
#  '글로리데이\tNNG\tB_MOVIE',
#  '기기괴괴 성형수\tNNG\tB_MOVIE',
#  '기다리다 미쳐\tNNG\tB_MOVIE',
#  '기담\tNNG\tB_MOVIE',
#  '기묘한 가족\tNNG\tB_MOVIE',
#  '기방도령\tNNG\tB_MOVIE',
#  '기생수 파트1\tNNG\tB_MOVIE',
#  '기생충\tNNG\tB_MOVIE',
#  '기술자들\tNNG\tB_MOVIE',
#  '기억의 밤\tNNG\tB_MOVIE',
#  '기적\tNNG\tB_MOVIE',
#  '기프트\tNNG\tB_MOVIE',
#  '김관장 대 김관장 대 김관장\tNNG\tB_MOVIE',
#  '김복남 살인사건의 전말\tNNG\tB_MOVIE',
#  '김씨표류기\tNNG\tB_MOVIE',
#  '김종욱 찾기\tNNG\tB_MOVIE',
#  '까불지마\tNNG\tB_MOVIE',
#  '깡철이\tNNG\tB_MOVIE',
#  '꼬마 니콜라\tNNG\tB_MOVIE',
#  '꽃보다 남자\tNNG\tB_MOVIE',
#  '꽃피는 봄이 오면\tNNG\tB_MOVIE',
#  '꾸뻬씨의 행복여행\tNNG\tB_MOVIE',
#  '꾼\tNNG\tB_MOVIE',
#  '꿀벌대소동\tNNG\tB_MOVIE',
#  '꿈은 이루어진다\tNNG\tB_MOVIE',
#  '끝까지 간다\tNNG\tB_MOVIE',
#  '나, 다니엘 블레이크\tNNG\tB_MOVIE',
#  '나는 갈매기\tNNG\tB_MOVIE',
#  '나는 공무원이다\tNNG\tB_MOVIE',
#  '나는 내일, 어제의 너와 만난다\tNNG\tB_MOVIE',
#  '나는 비와 함께 간다\tNNG\tB_MOVIE',
#  '나는 아빠다\tNNG\tB_MOVIE',
#  '나는 왕이로소이다\tNNG\tB_MOVIE',
#  '나는 전설이다\tNNG\tB_MOVIE',
#  '나니아 연대기-사자,마녀 그리고 옷장\tNNG\tB_MOVIE',
#  '나니아 연대기: 새벽 출정호의 항해\tNNG\tB_MOVIE',
#  '나니아 연대기:캐스피언 왕자\tNNG\tB_MOVIE',
#  '나두야 간다\tNNG\tB_MOVIE',
#  '나랏말싸미\tNNG\tB_MOVIE',
#  '나를 기억해\tNNG\tB_MOVIE',
#  '나를 잊지 말아요\tNNG\tB_MOVIE',
#  '나를 차버린 스파이\tNNG\tB_MOVIE',
#  '나를 찾아줘\tNNG\tB_MOVIE',
#  '나미야 잡화점의 기적\tNNG\tB_MOVIE',
#  '나비효과\tNNG\tB_MOVIE',
#  '나쁜 녀석들: 더 무비\tNNG\tB_MOVIE',
#  '나쁜 녀석들: 포에버\tNNG\tB_MOVIE',
#  '나우 유 씨 미 2\tNNG\tB_MOVIE',
#  '나우 유 씨 미 : 마술사기단\tNNG\tB_MOVIE',
#  '나의 PS 파트너\tNNG\tB_MOVIE',
#  '나의 결혼원정기\tNNG\tB_MOVIE',
#  '나의 독재자\tNNG\tB_MOVIE',
#  '나의 사랑 나의 신부\tNNG\tB_MOVIE',
#  '나의 소녀시대\tNNG\tB_MOVIE',
#  '나의 절친 악당들\tNNG\tB_MOVIE',
#  '나의 특별한 사랑이야기\tNNG\tB_MOVIE',
#  '나의 특별한 형제\tNNG\tB_MOVIE',
#  '나이브스 아웃\tNNG\tB_MOVIE',
#  '나이트 플라이트\tNNG\tB_MOVIE',
#  '나이트메어\tNNG\tB_MOVIE',
#  '나인\tNNG\tB_MOVIE',
#  '나인 야드 2\tNNG\tB_MOVIE',
#  '나일 강의 죽음\tNNG\tB_MOVIE',
#  '나잇&데이\tNNG\tB_MOVIE',
#  '날 미치게하는 남자\tNNG\tB_MOVIE',
#  '날, 보러와요\tNNG\tB_MOVIE',
#  '날씨의 아이\tNNG\tB_MOVIE',
#  '날아라 허동구\tNNG\tB_MOVIE',
#  '남과 여\tNNG\tB_MOVIE',
#  '남극일기\tNNG\tB_MOVIE',
#  '남산의 부장들\tNNG\tB_MOVIE',
#  '남영동1985\tNNG\tB_MOVIE',
#  '남자가 사랑할 때\tNNG\tB_MOVIE',
#  '남자사용설명서\tNNG\tB_MOVIE',
#  '남쪽으로 튀어\tNNG\tB_MOVIE',
#  '남한산성\tNNG\tB_MOVIE',
#  '내 깡패 같은 애인\tNNG\tB_MOVIE',
#  '내 남자의 로맨스\tNNG\tB_MOVIE',
#  '내 머리 속의 지우개\tNNG\tB_MOVIE',
#  '내 사랑\tNNG\tB_MOVIE',
#  '내 사랑 내 곁에\tNNG\tB_MOVIE',
#  '내 생애 가장 아름다운 일주일\tNNG\tB_MOVIE',
#  '내 생애 최악의 남자\tNNG\tB_MOVIE',
#  '내 심장을 쏴라\tNNG\tB_MOVIE',
#  '내 아내의 모든 것\tNNG\tB_MOVIE',
#  '내 여자친구를 소개합니다\tNNG\tB_MOVIE',
#  '내 이름은 칸\tNNG\tB_MOVIE',
#  '내가 살인범이다\tNNG\tB_MOVIE',
#  '내가 숨쉬는 공기\tNNG\tB_MOVIE',
#  '내가 죽던 날\tNNG\tB_MOVIE',
#  '내니 다이어리\tNNG\tB_MOVIE',
#  '내니맥피 2: 유모와마법소동\tNNG\tB_MOVIE',
#  '내니맥피-우리 유모는 마법사\tNNG\tB_MOVIE',
#  '내부자들\tNNG\tB_MOVIE',
#  '내부자들: 디 오리지널\tNNG\tB_MOVIE',
#  '내사랑 싸가지\tNNG\tB_MOVIE',
#  '내셔널 트레져\tNNG\tB_MOVIE',
#  '내셔널 트레져:비밀의 책\tNNG\tB_MOVIE',
#  '내안의 그놈\tNNG\tB_MOVIE',
#  '내일의 기억\tNNG\tB_MOVIE',
#  '너는 내 운명\tNNG\tB_MOVIE',
#  '너는 펫\tNNG\tB_MOVIE',
#  '너의 결혼식\tNNG\tB_MOVIE',
#  '너의 이름은.\tNNG\tB_MOVIE',
#  '너의 췌장을 먹고 싶어\tNNG\tB_MOVIE',
#  '널 기다리며\tNNG\tB_MOVIE',
#  '넘버23\tNNG\tB_MOVIE',
#  '넛잡 2\tNNG\tB_MOVIE',
#  '넛잡: 땅콩 도둑들\tNNG\tB_MOVIE',
#  '네버랜드를 찾아서\tNNG\tB_MOVIE',
#  '네버엔딩 스토리\tNNG\tB_MOVIE',
#  '넥스트\tNNG\tB_MOVIE',
#  '노리개\tNNG\tB_MOVIE',
#  '노무현입니다\tNNG\tB_MOVIE',
#  '노미오와 줄리엣\tNNG\tB_MOVIE',
#  '노바디\tNNG\tB_MOVIE',
#  '노벰버 맨\tNNG\tB_MOVIE',
#  '노브레싱\tNNG\tB_MOVIE',
#  '노아\tNNG\tB_MOVIE',
#  '노아의 방주: 남겨진 녀석들\tNNG\tB_MOVIE',
#  '노예 12년\tNNG\tB_MOVIE',
#  '노잉\tNNG\tB_MOVIE',
#  '노크:낯선 자들의 방문\tNNG\tB_MOVIE',
#  '노트북\tNNG\tB_MOVIE',
#  '논스톱\tNNG\tB_MOVIE',
#  '놉\tNNG\tB_MOVIE',
#  '누가 그녀와 잤을까?\tNNG\tB_MOVIE',
#  '누구나 비밀은 있다\tNNG\tB_MOVIE',
#  '눈길\tNNG\tB_MOVIE',
#  '눈먼자들의 도시\tNNG\tB_MOVIE',
#  '눈물이 주룩주룩\tNNG\tB_MOVIE',
#  '눈부신 날에\tNNG\tB_MOVIE',
#  '눈에는 눈 이에는 이\tNNG\tB_MOVIE',
#  '눈의 여왕\tNNG\tB_MOVIE',
#  '눈의 여왕 2: 트롤의 마법거울\tNNG\tB_MOVIE',
#  '눈의 여왕 3: 눈과 불의 마법대결\tNNG\tB_MOVIE',
#  '눈의 여왕4\tNNG\tB_MOVIE',
#  '눈의 여왕5: 스노우 프린세스와 미러랜드의 비밀\tNNG\tB_MOVIE',
#  '뉴 문\tNNG\tB_MOVIE',
#  '뉴 폴리스 스토리\tNNG\tB_MOVIE',
#  '뉴욕은 언제나 사랑 중\tNNG\tB_MOVIE',
#  '늑대사냥\tNNG\tB_MOVIE',
#  '늑대소년\tNNG\tB_MOVIE',
#  '늑대소년-확장판\tNNG\tB_MOVIE',
#  '늑대아이\tNNG\tB_MOVIE',
#  '늑대의 유혹\tNNG\tB_MOVIE',
#  '니 부모 얼굴이 보고 싶다\tNNG\tB_MOVIE',
#  '니드 포 스피드\tNNG\tB_MOVIE',
#  '니코\tNNG\tB_MOVIE',
#  '니코: 산타비행단의 모험\tNNG\tB_MOVIE',
#  '닌자 어쌔신\tNNG\tB_MOVIE',
#  '닌자거북이 TMNT\tNNG\tB_MOVIE',
#  '닌자터틀\tNNG\tB_MOVIE',
#  '닌자터틀 : 어둠의 히어로\tNNG\tB_MOVIE',
#  '님스 아일랜드\tNNG\tB_MOVIE',
#  '님아, 그 강을 건너지 마오\tNNG\tB_MOVIE',
#  '님은 먼 곳에\tNNG\tB_MOVIE',
#  '다만 악에서 구하소서\tNNG\tB_MOVIE',
#  '다빈치 코드\tNNG\tB_MOVIE',
#  '다세포소녀\tNNG\tB_MOVIE',
#  '다운사이징\tNNG\tB_MOVIE',
#  '다이 하드 4 : 죽어도 산다\tNNG\tB_MOVIE',
#  '다이노 타임\tNNG\tB_MOVIE',
#  '다이노소어 어드벤처 3D\tNNG\tB_MOVIE',
#  '다이노소어 어드벤처 : 백악기 공룡대백과\tNNG\tB_MOVIE',
#  '다이버전트\tNNG\tB_MOVIE',
#  '다이버전트 시리즈: 얼리전트\tNNG\tB_MOVIE',
#  '다이하드: 굿 데이 투 다이\tNNG\tB_MOVIE',
#  '다찌마와리\tNNG\tB_MOVIE',
#  '다크 나이트\tNNG\tB_MOVIE',
#  '다크 나이트 라이즈\tNNG\tB_MOVIE',
#  '다크 섀도우\tNNG\tB_MOVIE',
#  '다크 워터스\tNNG\tB_MOVIE',
#  '다크아워\tNNG\tB_MOVIE',
#  '닥터 두리틀\tNNG\tB_MOVIE',
#  '닥터 스트레인지\tNNG\tB_MOVIE',
#  '닥터 스트레인지: 대혼돈의 멀티버스\tNNG\tB_MOVIE',
#  '달마야, 서울 가자\tNNG\tB_MOVIE',
#  '달빛궁궐\tNNG\tB_MOVIE',
#  '달콤, 살벌한 연인\tNNG\tB_MOVIE',
#  '달콤한 거짓말\tNNG\tB_MOVIE',
#  '달콤한 인생\tNNG\tB_MOVIE',
#  '담보\tNNG\tB_MOVIE',
#  '당갈\tNNG\tB_MOVIE',
#  '당신, 거기 있어줄래요\tNNG\tB_MOVIE',
#  '당신이 사랑하는 동안에\tNNG\tB_MOVIE',
#  '대니쉬 걸\tNNG\tB_MOVIE',
#  '대립군\tNNG\tB_MOVIE',
#  '대배우\tNNG\tB_MOVIE',
#  '대장 김창수\tNNG\tB_MOVIE',
#  '대한민국 1%\tNNG\tB_MOVIE',
#  '대한이, 민국씨\tNNG\tB_MOVIE',
#  '대호\tNNG\tB_MOVIE',
#  '댄 인 러브\tNNG\tB_MOVIE',
#  '댄서의 순정\tNNG\tB_MOVIE',
#  '댄싱퀸\tNNG\tB_MOVIE',
#  '더 건맨\tNNG\tB_MOVIE',
#  '더 게임\tNNG\tB_MOVIE',
#  '더 그레이\tNNG\tB_MOVIE',
#  '더 기버: 기억전달자\tNNG\tB_MOVIE',
#  '더 넌\tNNG\tB_MOVIE',
#  '더 독\tNNG\tB_MOVIE',
#  '더 레이븐\tNNG\tB_MOVIE',
#  '더 로드\tNNG\tB_MOVIE',
#  '더 리더: 책 읽어주는 남자\tNNG\tB_MOVIE',
#  '더 박스\tNNG\tB_MOVIE',
#  '더 배트맨\tNNG\tB_MOVIE',
#  '더 버터플라이\tNNG\tB_MOVIE',
#  '더 셰프\tNNG\tB_MOVIE',
#  '더 수어사이드 스쿼드\tNNG\tB_MOVIE',
#  '더 스파이\tNNG\tB_MOVIE',
#  '더 시그널\tNNG\tB_MOVIE',
#  '더 울버린\tNNG\tB_MOVIE',
#  '더 울프 오브 월스트리트\tNNG\tB_MOVIE',
#  '더 웹툰: 예고살인\tNNG\tB_MOVIE',
#  '더 임파서블\tNNG\tB_MOVIE',
#  '더 자이언트\tNNG\tB_MOVIE',
#  '더 콘서트\tNNG\tB_MOVIE',
#  '더 큐어\tNNG\tB_MOVIE',
#  '더 킹\tNNG\tB_MOVIE',
#  '더 테러 라이브\tNNG\tB_MOVIE',
#  '더 테이블\tNNG\tB_MOVIE',
#  '더 파이브\tNNG\tB_MOVIE',
#  '더 퍼지\tNNG\tB_MOVIE',
#  '더 페이버릿: 여왕의 여자\tNNG\tB_MOVIE',
#  '더 포스트\tNNG\tB_MOVIE',
#  '더 폰\tNNG\tB_MOVIE',
#  '더 프레데터\tNNG\tB_MOVIE',
#  '더블타겟\tNNG\tB_MOVIE',
#  '덕구\tNNG\tB_MOVIE',
#  '덕수리 5형제\tNNG\tB_MOVIE',
#  '덕혜옹주\tNNG\tB_MOVIE',
#  '덤 앤 더머 투\tNNG\tB_MOVIE',
#  '덤보\tNNG\tB_MOVIE',
#  '덩케르크\tNNG\tB_MOVIE',
#  '데드풀\tNNG\tB_MOVIE',
#  '데드풀 2\tNNG\tB_MOVIE',
#  '데블\tNNG\tB_MOVIE',
#  '데스 디파잉:어느 마술사의 사랑\tNNG\tB_MOVIE',
#  '데스 레이스\tNNG\tB_MOVIE',
#  '데스노트\tNNG\tB_MOVIE',
#  '데스노트 : 라스트 네임\tNNG\tB_MOVIE',
#  '데스노트 L: 새로운 시작\tNNG\tB_MOVIE',
#  '데시벨\tNNG\tB_MOVIE',
#  '데이브레이커스\tNNG\tB_MOVIE',
#  '데이지\tNNG\tB_MOVIE',
#  '데자뷰\tNNG\tB_MOVIE',
#  '도가니\tNNG\tB_MOVIE',
#  '도굴\tNNG\tB_MOVIE',
#  '도둑들\tNNG\tB_MOVIE',
#  '도라에몽 : 스탠 바이 미\tNNG\tB_MOVIE',
#  '도레미파솔라시도\tNNG\tB_MOVIE',
#  '도리를 찾아서\tNNG\tB_MOVIE',
#  '도리화가\tNNG\tB_MOVIE',
#  '도마뱀\tNNG\tB_MOVIE',
#  '도어락\tNNG\tB_MOVIE',
#  '도희야\tNNG\tB_MOVIE',
#  '독수리 에디\tNNG\tB_MOVIE',
#  '독전\tNNG\tB_MOVIE',
#  '독전: 익스텐디드 컷\tNNG\tB_MOVIE',
#  '돈\tNNG\tB_MOVIE',
#  '돈 크라이 마미\tNNG\tB_MOVIE',
#  '돈 텔 파파\tNNG\tB_MOVIE',
#  '돈의 맛\tNNG\tB_MOVIE',
#  '돌연변이\tNNG\tB_MOVIE',
#  '동감\tNNG\tB_MOVIE',
#  '동갑내기 과외하기 레슨 2\tNNG\tB_MOVIE',
#  '동네사람들\tNNG\tB_MOVIE',
#  '동주\tNNG\tB_MOVIE',
#  '동창생\tNNG\tB_MOVIE',
#  '동해물과 백두산이\tNNG\tB_MOVIE',
#  '두 개의 달\tNNG\tB_MOVIE',
#  '두 사람이다\tNNG\tB_MOVIE',
#  '두 얼굴의 여친\tNNG\tB_MOVIE',
#  '두 여자\tNNG\tB_MOVIE',
#  '두근두근 내 인생\tNNG\tB_MOVIE',
#  '두뇌유희프로젝트, 퍼즐\tNNG\tB_MOVIE',
#  '두번할까요\tNNG\tB_MOVIE',
#  '듄\tNNG\tB_MOVIE',
#  '드라큘라: 전설의 시작\tNNG\tB_MOVIE',
#  '드래곤 길들이기\tNNG\tB_MOVIE',
#  '드래곤 길들이기 2\tNNG\tB_MOVIE',
#  '드래곤 길들이기 3\tNNG\tB_MOVIE',
#  '드래곤볼 에볼루션\tNNG\tB_MOVIE',
#  '드래그 미 투 헬\tNNG\tB_MOVIE',
#  '드리머\tNNG\tB_MOVIE',
#  '드림 쏭\tNNG\tB_MOVIE',
#  '드림걸즈\tNNG\tB_MOVIE',
#  '들어는 봤니? 모건 부부\tNNG\tB_MOVIE',
#  '디 아이2\tNNG\tB_MOVIE',
#  '디바\tNNG\tB_MOVIE',
#  '디센트\tNNG\tB_MOVIE',
#  '디스 민즈 워\tNNG\tB_MOVIE',
#  '디스터비아\tNNG\tB_MOVIE',
#  '디스트릭트 9\tNNG\tB_MOVIE',
#  '디어 에반 핸슨\tNNG\tB_MOVIE',
#  '디어 존\tNNG\tB_MOVIE',
#  '디워\tNNG\tB_MOVIE',
#  '디파이언스\tNNG\tB_MOVIE',
#  '디파티드\tNNG\tB_MOVIE',
#  '딥\tNNG\tB_MOVIE',
#  '딥워터 호라이즌\tNNG\tB_MOVIE',
#  '또 하나의 약속\tNNG\tB_MOVIE',
#  '똥파리\tNNG\tB_MOVIE',
#  '뚝방전설\tNNG\tB_MOVIE',
#  '뜨거운 것이 좋아\tNNG\tB_MOVIE',
#  '뜨거운 피\tNNG\tB_MOVIE',
#  '라 비 앙 로즈\tNNG\tB_MOVIE',
#  '라듸오 데이즈\tNNG\tB_MOVIE',
#  '라디오 스타\tNNG\tB_MOVIE',
#  '라따뚜이\tNNG\tB_MOVIE',
#  '라라랜드\tNNG\tB_MOVIE',
#  '라스베가스에서만 생길 수 있는 일\tNNG\tB_MOVIE',
#  '라스트 갓파더\tNNG\tB_MOVIE',
#  '라스트 나잇\tNNG\tB_MOVIE',
#  '라스트 미션\tNNG\tB_MOVIE',
#  '라스트 사무라이\tNNG\tB_MOVIE',
#  '라스트 에어벤더\tNNG\tB_MOVIE',
#  '라스트 엑소시즘\tNNG\tB_MOVIE',
#  '라스트 위치 헌터\tNNG\tB_MOVIE',
#  '라스트 크리스마스\tNNG\tB_MOVIE',
#  '라스트베가스\tNNG\tB_MOVIE',
#  '라야와 마지막 드래곤\tNNG\tB_MOVIE',
#  '라이어\tNNG\tB_MOVIE',
#  '라이언\tNNG\tB_MOVIE',
#  '라이온 킹\tNNG\tB_MOVIE',
#  '라이트 아웃\tNNG\tB_MOVIE',
#  '라이프\tNNG\tB_MOVIE',
#  '라이프 오브 파이\tNNG\tB_MOVIE',
#  '라파예트\tNNG\tB_MOVIE',
#  '라푼젤\tNNG\tB_MOVIE',
#  '락아웃: 익스트림미션\tNNG\tB_MOVIE',
#  '람보 4 : 라스트 블러드\tNNG\tB_MOVIE',
#  '람보 : 라스트 워\tNNG\tB_MOVIE',
#  '랑종\tNNG\tB_MOVIE',
#  '램페이지\tNNG\tB_MOVIE',
#  '랭고\tNNG\tB_MOVIE',
#  '러브 & 드럭스\tNNG\tB_MOVIE',
#  '러브 & 트러블\tNNG\tB_MOVIE',
#  '러브 라이브! 더 스쿨 아이돌 무비\tNNG\tB_MOVIE',
#  '러브 액츄얼리\tNNG\tB_MOVIE',
#  '러브 앤 프렌즈\tNNG\tB_MOVIE',
#  '러브, 로지\tNNG\tB_MOVIE',
#  '러브레터\tNNG\tB_MOVIE',
#  '러브픽션\tNNG\tB_MOVIE',
#  '러블리 본즈\tNNG\tB_MOVIE',
#  '러빙 빈센트\tNNG\tB_MOVIE',
#  '러시 : 더 라이벌\tNNG\tB_MOVIE',
#  '러시 아워 3\tNNG\tB_MOVIE',
#  '럭키\tNNG\tB_MOVIE',
#  '럭키 넘버 슬레븐\tNNG\tB_MOVIE',
#  '런\tNNG\tB_MOVIE',
#  '런 올 나이트\tNNG\tB_MOVIE',
#  '런닝맨\tNNG\tB_MOVIE',
#  '런닝맨 : 풀룰루의 역습\tNNG\tB_MOVIE',
#  '런던 해즈 폴른\tNNG\tB_MOVIE',
#  '레고 닌자고 무비\tNNG\tB_MOVIE',
#  '레고 무비\tNNG\tB_MOVIE',
#  '레고 배트맨 무비\tNNG\tB_MOVIE',
#  '레드\tNNG\tB_MOVIE',
#  '레드 라이딩 후드\tNNG\tB_MOVIE',
#  '레드 스패로\tNNG\tB_MOVIE',
#  '레드 아이\tNNG\tB_MOVIE',
#  '레드: 더 레전드\tNNG\tB_MOVIE',
#  '레드슈즈\tNNG\tB_MOVIE',
#  '레드카펫\tNNG\tB_MOVIE',
#  '레디 플레이어 원\tNNG\tB_MOVIE',
#  '레모니 스니켓의 위험한 대결\tNNG\tB_MOVIE',
#  '레미제라블\tNNG\tB_MOVIE',
#  '레버넌트: 죽음에서 돌아온 자\tNNG\tB_MOVIE',
#  '레슬러\tNNG\tB_MOVIE',
#  '레이\tNNG\tB_MOVIE',
#  '레이디 버드\tNNG\tB_MOVIE',
#  '레이디 인 더 워터\tNNG\tB_MOVIE',
#  '레이크 하우스\tNNG\tB_MOVIE',
#  '레전드\tNNG\tB_MOVIE',
#  '레전드 오브 조로\tNNG\tB_MOVIE',
#  '레전드 오브 타잔\tNNG\tB_MOVIE',
#  '레지던트 이블 2-아포칼립스\tNNG\tB_MOVIE',
#  '레지던트 이블 3 - 인류의 멸망\tNNG\tB_MOVIE',
#  '레지던트 이블 4: 끝나지 않은 전쟁 3D\tNNG\tB_MOVIE',
#  '레지던트 이블 5 : 최후의 심판\tNNG\tB_MOVIE',
#  '레지던트 이블: 파멸의 날\tNNG\tB_MOVIE',
#  '레터스 투 줄리엣\tNNG\tB_MOVIE',
#  '렛 미 인\tNNG\tB_MOVIE',
#  '령\tNNG\tB_MOVIE',
#  '로건\tNNG\tB_MOVIE',
#  '로그 원: 스타워즈 스토리\tNNG\tB_MOVIE',
#  '로드 오브 워\tNNG\tB_MOVIE',
#  '로렉스\tNNG\tB_MOVIE',
#  '로마 위드 러브\tNNG\tB_MOVIE',
#  '로마의 휴일\tNNG\tB_MOVIE',
#  '로망스\tNNG\tB_MOVIE',
#  '로맨틱 아일랜드\tNNG\tB_MOVIE',
#  '로맨틱 크라운\tNNG\tB_MOVIE',
#  '로맨틱 홀리데이\tNNG\tB_MOVIE',
#  '로보캅\tNNG\tB_MOVIE',
#  '로봇(애니)\tNNG\tB_MOVIE',
#  '로봇, 소리\tNNG\tB_MOVIE',
#  '로빈 후드\tNNG\tB_MOVIE',
#  '로빈슨 가족\tNNG\tB_MOVIE',
#  '로빈슨 크루소\tNNG\tB_MOVIE',
#  '로스트 라이온즈\tNNG\tB_MOVIE',
#  '로스트 시티\tNNG\tB_MOVIE',
#  '로켓맨\tNNG\tB_MOVIE',
#  '록키 발보아\tNNG\tB_MOVIE',
#  '론 레인저\tNNG\tB_MOVIE',
#  '론 서바이버\tNNG\tB_MOVIE',
#  '롤러코스터\tNNG\tB_MOVIE',
#  '롱 리브 더 킹: 목포 영웅\tNNG\tB_MOVIE',
#  '롱 샷\tNNG\tB_MOVIE',
#  '루돌프와 많이있어\tNNG\tB_MOVIE',
#  '루시\tNNG\tB_MOVIE',
#  '루시드 드림\tNNG\tB_MOVIE',
#  '루카\tNNG\tB_MOVIE',
#  '루퍼\tNNG\tB_MOVIE',
#  '리딕\tNNG\tB_MOVIE',
#  '리딕 - 헬리온 최후의 빛\tNNG\tB_MOVIE',
#  '리멤버\tNNG\tB_MOVIE',
#  '리미트리스\tNNG\tB_MOVIE',
#  '리얼\tNNG\tB_MOVIE',
#  '리얼 스틸\tNNG\tB_MOVIE',
#  '리오\tNNG\tB_MOVIE',
#  '리오 2\tNNG\tB_MOVIE',
#  '리턴\tNNG\tB_MOVIE',
#  '리틀 비버\tNNG\tB_MOVIE',
#  '리틀 포레스트\tNNG\tB_MOVIE',
#  '리핑 10개의 재앙\tNNG\tB_MOVIE',
#  '링2(2005)\tNNG\tB_MOVIE',
#  '링스 어드벤처\tNNG\tB_MOVIE',
#  '링컨\tNNG\tB_MOVIE',
#  '링컨 차를 타는 변호사\tNNG\tB_MOVIE',
#  '링컨: 뱀파이어 헌터\tNNG\tB_MOVIE',
#  '마강호텔\tNNG\tB_MOVIE',
#  '마고리엄의 장난감 백화점\tNNG\tB_MOVIE',
#  '마녀\tNNG\tB_MOVIE',
#  '마녀(魔女) Part2. The Other One\tNNG\tB_MOVIE',
#  '마다가스카\tNNG\tB_MOVIE',
#  '마다가스카 2\tNNG\tB_MOVIE',
#  '마다가스카3 : 이번엔 서커스다!\tNNG\tB_MOVIE',
#  '마다가스카의 펭귄\tNNG\tB_MOVIE',
#  '마담 뺑덕\tNNG\tB_MOVIE',
#  '마담 프루스트의 비밀정원\tNNG\tB_MOVIE',
#  '마당을 나온 암탉\tNNG\tB_MOVIE',
#  '마더\tNNG\tB_MOVIE',
#  '마루 밑 아리에티\tNNG\tB_MOVIE',
#  '마린보이\tNNG\tB_MOVIE',
#  '마마\tNNG\tB_MOVIE',
#  '마법사의 제자\tNNG\tB_MOVIE',
#  '마법에 걸린 사랑\tNNG\tB_MOVIE',
#  '마법천자문: 대마왕의 부활을 막아라\tNNG\tB_MOVIE',
#  '마션\tNNG\tB_MOVIE',
#  '마스터\tNNG\tB_MOVIE',
#  '마야\tNNG\tB_MOVIE',
#  '마약왕\tNNG\tB_MOVIE',
#  '마을금고 연쇄습격사건\tNNG\tB_MOVIE',
#  '마음이...\tNNG\tB_MOVIE',
#  '마음이2\tNNG\tB_MOVIE',
#  '마이 뉴 파트너\tNNG\tB_MOVIE',
#  '마이 리틀 자이언트\tNNG\tB_MOVIE',
#  '마이 리틀 히어로\tNNG\tB_MOVIE',
#  '마이 블랙 미니드레스\tNNG\tB_MOVIE',
#  '마이 블루베리 나이츠\tNNG\tB_MOVIE',
#  '마이 시스터즈 키퍼\tNNG\tB_MOVIE',
#  '마이 웨이\tNNG\tB_MOVIE',
#  '마이 캡틴 김대출\tNNG\tB_MOVIE',
#  '마이 파더\tNNG\tB_MOVIE',
#  '마이애미 바이스\tNNG\tB_MOVIE',
#  '마이클 잭슨의 디스 이즈 잇\tNNG\tB_MOVIE',
#  '마이클 클레이튼\tNNG\tB_MOVIE',
#  '마이펫 오지\tNNG\tB_MOVIE',
#  '마이펫의 이중생활\tNNG\tB_MOVIE',
#  '마이펫의 이중생활 2\tNNG\tB_MOVIE',
#  '마지막 4중주\tNNG\tB_MOVIE',
#  '마지막 선물\tNNG\tB_MOVIE',
#  '마파도\tNNG\tB_MOVIE',
#  '마파도2\tNNG\tB_MOVIE',
#  '만남의 광장\tNNG\tB_MOVIE',
#  '만추\tNNG\tB_MOVIE',
#  '말레피센트\tNNG\tB_MOVIE',
#  '말레피센트 2\tNNG\tB_MOVIE',
#  '말리와 나\tNNG\tB_MOVIE',
#  '말모이\tNNG\tB_MOVIE',
#  '말아톤\tNNG\tB_MOVIE',
#  '말죽거리 잔혹사\tNNG\tB_MOVIE',
#  '말할 수 없는 비밀\tNNG\tB_MOVIE',
#  '맘마미아!\tNNG\tB_MOVIE',
#  '맘마미아!2\tNNG\tB_MOVIE',
#  '매그니피센트 7\tNNG\tB_MOVIE',
#  '매드 맥스: 분노의 도로\tNNG\tB_MOVIE',
#  '매직브러시\tNNG\tB_MOVIE',
#  '매치 포인트\tNNG\tB_MOVIE',
#  '매트릭스: 리저렉션\tNNG\tB_MOVIE',
#  '맥스 페인\tNNG\tB_MOVIE',
#  '맨 오브 스틸\tNNG\tB_MOVIE',
#  '맨 온 렛지\tNNG\tB_MOVIE',
#  '맨 온 파이어\tNNG\tB_MOVIE',
#  '맨 인 더 다크\tNNG\tB_MOVIE',
#  '맨 인 블랙 3\tNNG\tB_MOVIE',
#  '맨 인 블랙: 인터내셔널\tNNG\tB_MOVIE',
#  '맨 프롬 UNCLE\tNNG\tB_MOVIE',
#  '맨발의 기봉이\tNNG\tB_MOVIE',
#  '맨발의 꿈\tNNG\tB_MOVIE',
#  '맨홀\tNNG\tB_MOVIE',
#  '맹부삼천지교\tNNG\tB_MOVIE',
#  '머니볼\tNNG\tB_MOVIE',
#  '먹고 기도하고 사랑하라\tNNG\tB_MOVIE',
#  '멋진 하루\tNNG\tB_MOVIE',
#  '메가로돈\tNNG\tB_MOVIE',
#  '메가마인드\tNNG\tB_MOVIE',
#  '메리 포핀스 리턴즈\tNNG\tB_MOVIE',
#  '메리다와 마법의 숲\tNNG\tB_MOVIE',
#  '메리와 마녀의 꽃\tNNG\tB_MOVIE',
#  '메신져 - 죽은자들의 경고\tNNG\tB_MOVIE',
#  '메이즈 러너\tNNG\tB_MOVIE',
#  '메이즈 러너: 데스 큐어\tNNG\tB_MOVIE',
#  '메이즈 러너: 스코치 트라이얼\tNNG\tB_MOVIE',
#  '메카닉\tNNG\tB_MOVIE',
#  '메카닉: 리크루트\tNNG\tB_MOVIE',
#  '명당\tNNG\tB_MOVIE',
#  '명량\tNNG\tB_MOVIE',
#  '명장\tNNG\tB_MOVIE',
#  '명탐정 코난 : 수평선상의 음모\tNNG\tB_MOVIE',
#  '명탐정 코난 : 이차원의 저격수\tNNG\tB_MOVIE',
#  '명탐정 코난 : 제로의 집행인\tNNG\tB_MOVIE',
#  '명탐정 코난 : 칠흑의 추적자\tNNG\tB_MOVIE',
#  '명탐정 코난 : 침묵의 15분\tNNG\tB_MOVIE',
#  '명탐정 코난 : 코난 실종사건 - 사상 최악의 이틀\tNNG\tB_MOVIE',
#  '명탐정 코난 : 탐정들의 진혼가\tNNG\tB_MOVIE',
#  '명탐정 코난 : 화염의 해바라기\tNNG\tB_MOVIE',
#  '명탐정 코난: 11번째 스트라이커\tNNG\tB_MOVIE',
#  '명탐정 코난: 감청의 권\tNNG\tB_MOVIE',
#  '명탐정 코난: 비색의 탄환\tNNG\tB_MOVIE',
#  '명탐정 코난: 순흑의 악몽\tNNG\tB_MOVIE',
#  '명탐정 코난: 에피소드 원-작아진 명탐정\tNNG\tB_MOVIE',
#  '명탐정 코난: 천공의 난파선\tNNG\tB_MOVIE',
#  '명탐정 코난: 할로윈의 신부\tNNG\tB_MOVIE',
#  '명탐정 코난:감벽의 관\tNNG\tB_MOVIE',
#  '명탐정 코난:베이커가의 망령\tNNG\tB_MOVIE',
#  '명탐정 코난:은빛 날개의 마술사\tNNG\tB_MOVIE',
#  '명탐정 코난:전율의 악보\tNNG\tB_MOVIE',
#  '명탐정 코난:진홍의 연가\tNNG\tB_MOVIE',
#  '명탐정 피카츄\tNNG\tB_MOVIE',
#  '모가디슈\tNNG\tB_MOVIE',
#  '모노폴리\tNNG\tB_MOVIE',
#  '모던보이\tNNG\tB_MOVIE',
#  '모모와 다락방의 수상한 요괴들\tNNG\tB_MOVIE',
#  '모범시민\tNNG\tB_MOVIE',
#  '모비딕\tNNG\tB_MOVIE',
#  '모비우스\tNNG\tB_MOVIE',
#  '모아나\tNNG\tB_MOVIE',
#  '모털 엔진\tNNG\tB_MOVIE',
#  '목격자\tNNG\tB_MOVIE',
#  '목소리의 형태\tNNG\tB_MOVIE',
#  '목포는 항구다\tNNG\tB_MOVIE',
#  '몬스터\tNNG\tB_MOVIE',
#  '몬스터 vs 에이리언\tNNG\tB_MOVIE',
#  '몬스터 대학교\tNNG\tB_MOVIE',
#  '몬스터 패밀리\tNNG\tB_MOVIE',
#  ...]

# %%
txt = txts[0].split('\t')
txt
# Out:
# ['0시', 'NNG', 'B_DT']

# %%
# new_user_dict.append(txt[0]+'\t'+txt[1])
# new_user_dict

# %%
for txt in txts:
    t = txt.split('\t')
    new_user_dict.append(t[0]+'\t'+t[1])

# %%
print(len(new_user_dict))
new_user_dict
# Out:
# 17565
# ['0시\tNNG',
#  '1시\tNNG',
#  '2시\tNNG',
#  '3시\tNNG',
#  '4시\tNNG',
#  '5시\tNNG',
#  '6시\tNNG',
#  '7시\tNNG',
#  '8시\tNNG',
#  '9시\tNNG',
#  '10시\tNNG',
#  '11시\tNNG',
#  '12시\tNNG',
#  '13시\tNNG',
#  '14시\tNNG',
#  '15시\tNNG',
#  '16시\tNNG',
#  '17시\tNNG',
#  '18시\tNNG',
#  '19시\tNNG',
#  '20시\tNNG',
#  '21시\tNNG',
#  '22시\tNNG',
#  '23시\tNNG',
#  '24시\tNNG',
#  '0분\tNNG',
#  '1분\tNNG',
#  '2분\tNNG',
#  '3분\tNNG',
#  '4분\tNNG',
#  '5분\tNNG',
#  '6분\tNNG',
#  '7분\tNNG',
#  '8분\tNNG',
#  '9분\tNNG',
#  '10분\tNNG',
#  '11분\tNNG',
#  '12분\tNNG',
#  '13분\tNNG',
#  '14분\tNNG',
#  '15분\tNNG',
#  '16분\tNNG',
#  '17분\tNNG',
#  '18분\tNNG',
#  '19분\tNNG',
#  '20분\tNNG',
#  '21분\tNNG',
#  '22분\tNNG',
#  '23분\tNNG',
#  '24분\tNNG',
#  '25분\tNNG',
#  '26분\tNNG',
#  '27분\tNNG',
#  '28분\tNNG',
#  '29분\tNNG',
#  '30분\tNNG',
#  '31분\tNNG',
#  '32분\tNNG',
#  '33분\tNNG',
#  '34분\tNNG',
#  '35분\tNNG',
#  '36분\tNNG',
#  '37분\tNNG',
#  '38분\tNNG',
#  '39분\tNNG',
#  '40분\tNNG',
#  '41분\tNNG',
#  '42분\tNNG',
#  '43분\tNNG',
#  '44분\tNNG',
#  '45분\tNNG',
#  '46분\tNNG',
#  '47분\tNNG',
#  '48분\tNNG',
#  '49분\tNNG',
#  '50분\tNNG',
#  '51분\tNNG',
#  '52분\tNNG',
#  '53분\tNNG',
#  '54분\tNNG',
#  '55분\tNNG',
#  '56분\tNNG',
#  '57분\tNNG',
#  '58분\tNNG',
#  '59분\tNNG',
#  '60분\tNNG',
#  '1월\tNNG',
#  '2월\tNNG',
#  '3월\tNNG',
#  '4월\tNNG',
#  '5월\tNNG',
#  '6월\tNNG',
#  '7월\tNNG',
#  '8월\tNNG',
#  '9월\tNNG',
#  '10월\tNNG',
#  '11월\tNNG',
#  '12월\tNNG',
#  '1일\tNNG',
#  '2일\tNNG',
#  '3일\tNNG',
#  '4일\tNNG',
#  '5일\tNNG',
#  '6일\tNNG',
#  '7일\tNNG',
#  '8일\tNNG',
#  '9일\tNNG',
#  '10일\tNNG',
#  '11일\tNNG',
#  '12일\tNNG',
#  '13일\tNNG',
#  '14일\tNNG',
#  '15일\tNNG',
#  '16일\tNNG',
#  '17일\tNNG',
#  '18일\tNNG',
#  '19일\tNNG',
#  '20일\tNNG',
#  '21일\tNNG',
#  '22일\tNNG',
#  '23일\tNNG',
#  '24일\tNNG',
#  '25일\tNNG',
#  '26일\tNNG',
#  '27일\tNNG',
#  '28일\tNNG',
#  '29일\tNNG',
#  '30일\tNNG',
#  '31일\tNNG',
#  '월요일\tNNG',
#  '화요일\tNNG',
#  '수요일\tNNG',
#  '목요일\tNNG',
#  '금요일\tNNG',
#  '토요일\tNNG',
#  '일요일\tNNG',
#  '#살아있다\tNNG',
#  '0.0MHz\tNNG',
#  '007 노 타임 투 다이\tNNG',
#  '007 스카이폴\tNNG',
#  '007 스펙터\tNNG',
#  '007 카지노 로얄\tNNG',
#  '007 퀀텀 오브 솔러스\tNNG',
#  '10,000 BC\tNNG',
#  '10억\tNNG',
#  '12 솔져스\tNNG',
#  '127시간\tNNG',
#  '13구역\tNNG',
#  '13구역: 얼티메이텀\tNNG',
#  '13시간\tNNG',
#  '13일의 금요일\tNNG',
#  '1408\tNNG',
#  '1724 기방난동사건\tNNG',
#  '1917\tNNG',
#  '1987\tNNG',
#  '19곰 테드\tNNG',
#  '19곰 테드 2\tNNG',
#  '1급기밀\tNNG',
#  '1번가의 기적\tNNG',
#  '2012\tNNG',
#  '2046\tNNG',
#  '20세기 소년\tNNG',
#  '21\tNNG',
#  '21 브릿지: 테러 셧다운\tNNG',
#  '22 블렛\tNNG',
#  '23 아이덴티티\tNNG',
#  '26년\tNNG',
#  '27번의 결혼리허설\tNNG',
#  '300\tNNG',
#  '300: 제국의 부활\tNNG',
#  '4.4.4\tNNG',
#  '47 미터\tNNG',
#  '47미터 2\tNNG',
#  '50/50\tNNG',
#  '500일의 썸머\tNNG',
#  '50가지 그림자: 심연\tNNG',
#  '50가지 그림자: 해방\tNNG',
#  '5백만불의 사나이\tNNG',
#  '6년째 연애중\tNNG',
#  '6월의 일기\tNNG',
#  '7광구\tNNG',
#  '7급 공무원\tNNG',
#  '7년의 밤\tNNG',
#  '7번방의 선물\tNNG',
#  '7호실\tNNG',
#  '80일간의 세계 일주\tNNG',
#  '82년생 김지영\tNNG',
#  '88분\tNNG',
#  '8인: 최후의 결사단\tNNG',
#  'A-특공대\tNNG',
#  'BB프로젝트\tNNG',
#  'B형 남자친구\tNNG',
#  'CJ7:장강7호\tNNG',
#  'DC 리그 오브 슈퍼-펫\tNNG',
#  'DMZ, 비무장지대\tNNG',
#  'DOA\tNNG',
#  'GP 506\tNNG',
#  'Mr.로빈 꼬시기\tNNG',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG',
#  'P.S. 아이 러브 유\tNNG',
#  'PMC: 더 벙커\tNNG',
#  'R.I.P.D. : 알.아이.피.디.\tNNG',
#  'R2B: 리턴투베이스\tNNG',
#  'S 다이어리\tNNG',
#  'pm 11:14\tNNG',
#  '가디언\tNNG',
#  '가디언의 전설\tNNG',
#  '가디언즈\tNNG',
#  '가디언즈 오브 갤럭시\tNNG',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG',
#  '가려진 시간\tNNG',
#  '가루지기\tNNG',
#  '가면\tNNG',
#  '가문의 부활 - 가문의 영광3\tNNG',
#  '가문의 영광4 - 가문의 수난\tNNG',
#  '가문의 영광5 - 가문의 귀환\tNNG',
#  '가문의 위기(가문의 영광2)\tNNG',
#  '가발\tNNG',
#  '가버나움\tNNG',
#  '가부와 메이 이야기\tNNG',
#  '가비\tNNG',
#  '가시\tNNG',
#  '가을로\tNNG',
#  '가장 보통의 연애\tNNG',
#  '가족\tNNG',
#  '가족의 탄생\tNNG',
#  '가필드\tNNG',
#  '가필드 2\tNNG',
#  '각설탕\tNNG',
#  '간 큰 가족\tNNG',
#  '간기남\tNNG',
#  '간신\tNNG',
#  '간첩\tNNG',
#  '감기\tNNG',
#  '감바의 대모험\tNNG',
#  '감시자들\tNNG',
#  '감쪽같은 그녀\tNNG',
#  '갓 오브 이집트\tNNG',
#  '강남 1970\tNNG',
#  '강력 3반\tNNG',
#  '강릉\tNNG',
#  '강적\tNNG',
#  '강철대오:구국의 철가방\tNNG',
#  '강철비\tNNG',
#  '강철비2: 정상회담\tNNG',
#  '강철중: 공공의 적 1-1\tNNG',
#  '개구쟁이 스머프\tNNG',
#  '개구쟁이 스머프 2\tNNG',
#  '개를 훔치는 완벽한 방법\tNNG',
#  '거룩한 계보\tNNG',
#  '거북이 달린다\tNNG',
#  '거울나라의 앨리스\tNNG',
#  '건축학개론\tNNG',
#  '걸리버 여행기\tNNG',
#  '걸스카우트\tNNG',
#  '걸캅스\tNNG',
#  '걸프렌즈\tNNG',
#  '검객\tNNG',
#  '검사외전\tNNG',
#  '검우강호\tNNG',
#  '검은 사제들\tNNG',
#  '검은 집\tNNG',
#  '겁나는 여친의 완벽한 비밀\tNNG',
#  '게드전기 : 어스시의 전설\tNNG',
#  '게스후\tNNG',
#  '게이머\tNNG',
#  '게이샤의 추억\tNNG',
#  '게이트\tNNG',
#  '겟 스마트\tNNG',
#  '겟 썸\tNNG',
#  '겟 아웃\tNNG',
#  '겨울왕국\tNNG',
#  '겨울왕국 2\tNNG',
#  '결백\tNNG',
#  '결혼전야\tNNG',
#  '경관의 피\tNNG',
#  '경성학교: 사라진 소녀들\tNNG',
#  '계춘할망\tNNG',
#  '고死 : 피의 중간고사\tNNG',
#  '고死 두 번째 이야기: 교생실습\tNNG',
#  '고고 70\tNNG',
#  '고령화 가족\tNNG',
#  '고산자, 대동여지도\tNNG',
#  '고스트 라이더\tNNG',
#  '고스트 라이더 : 복수의 화신\tNNG',
#  '고스트버스터즈\tNNG',
#  '고스트버스터즈 라이즈\tNNG',
#  '고양이: 죽음을 보는 두 개의 눈\tNNG',
#  '고장난 론\tNNG',
#  '고지전\tNNG',
#  '고질라\tNNG',
#  '고질라 VS. 콩\tNNG',
#  '고질라: 킹 오브 몬스터\tNNG',
#  '곡성\tNNG',
#  '곤지암\tNNG',
#  '골든 에이지\tNNG',
#  '골든슬럼버\tNNG',
#  '곰돌이 푸 다시 만나 행복해\tNNG',
#  '공각기동대 : 고스트 인 더 쉘\tNNG',
#  '공공의 적 2\tNNG',
#  '공기살인\tNNG',
#  '공모자들\tNNG',
#  '공범\tNNG',
#  '공범자들\tNNG',
#  '공자 춘추전국시대\tNNG',
#  '공작\tNNG',
#  '공작부인:세기의 스캔들\tNNG',
#  '공조\tNNG',
#  '공조2: 인터내셔날\tNNG',
#  '공주와 개구리\tNNG',
#  '공포의 묘지\tNNG',
#  '공필두\tNNG',
#  '과속스캔들\tNNG',
#  '관능의 법칙\tNNG',
#  '관상\tNNG',
#  '광대들: 풍문조작단\tNNG',
#  '광식이 동생 광태\tNNG',
#  '광해, 왕이 된 남자\tNNG',
#  '괴물\tNNG',
#  '괴물의 아이\tNNG',
#  '교회오빠\tNNG',
#  '구르믈 버서난 달처럼\tNNG',
#  '구미호 가족\tNNG',
#  '구세주\tNNG',
#  '구세주 2\tNNG',
#  '구스범스\tNNG',
#  '구타유발자들\tNNG',
#  '국가대표\tNNG',
#  '국가대표 2\tNNG',
#  '국가대표 완결판-못 다한 이야기\tNNG',
#  '국가부도의 날\tNNG',
#  '국경의 남쪽\tNNG',
#  '국제수사\tNNG',
#  '국제시장\tNNG',
#  '군도: 민란의 시대\tNNG',
#  '군함도\tNNG',
#  '굿 다이노\tNNG',
#  '굿모닝 에브리원\tNNG',
#  '굿모닝 프레지던트\tNNG',
#  '굿바이\tNNG',
#  '굿바이 싱글\tNNG',
#  '궁녀\tNNG',
#  '궁합\tNNG',
#  '권순분여사 납치사건\tNNG',
#  '귀신이 산다\tNNG',
#  '귀향\tNNG',
#  '그 여자 작사 그 남자 작곡\tNNG',
#  '그것\tNNG',
#  '그것: 두 번째 이야기\tNNG',
#  '그것만이 내 세상\tNNG',
#  '그날, 바다\tNNG',
#  '그날의 분위기\tNNG',
#  '그녀\tNNG',
#  '그녀는 요술쟁이\tNNG',
#  '그녀를 믿지 마세요\tNNG',
#  '그놈 목소리\tNNG',
#  '그놈은 멋있었다\tNNG',
#  '그놈이다\tNNG',
#  '그는 당신에게 반하지 않았다\tNNG',
#  '그대가 조국\tNNG',
#  '그대를 사랑합니다\tNNG',
#  '그때 그 사람들\tNNG',
#  '그랑프리\tNNG',
#  '그래비티\tNNG',
#  '그랜 토리노\tNNG',
#  '그랜드 부다페스트 호텔\tNNG',
#  '그렇게 아버지가 된다\tNNG',
#  '그레이스 오브 모나코\tNNG',
#  '그레이의 50가지 그림자\tNNG',
#  '그레이트 월\tNNG',
#  '그루지\tNNG',
#  '그루지 2\tNNG',
#  '그린 북\tNNG',
#  '그린 존\tNNG',
#  '그린 호넷\tNNG',
#  '그린랜드\tNNG',
#  '그린랜턴: 반지의 선택\tNNG',
#  '그린치\tNNG',
#  '그림자 살인\tNNG',
#  '그림형제 : 마르바덴 숲의 전설\tNNG',
#  '그해 여름\tNNG',
#  '극락도 살인사건\tNNG',
#  '극비수사\tNNG',
#  '극장판 공룡메카드: 타이니소어의 섬\tNNG',
#  '극장판 귀멸의 칼날: 무한열차편\tNNG',
#  '극장판 꼬마버스 타요의 에이스 구출작전\tNNG',
#  '극장판 도라에몽 : 진구의 우주영웅기~스페이스 히어로즈~\tNNG',
#  '극장판 도라에몽: 진구와 기적의 섬 애니멀 어드벤처\tNNG',
#  '극장판 도라에몽: 진구와 철인군단 날아라 천사들\tNNG',
#  '극장판 도라에몽: 진구의 공룡대탐험\tNNG',
#  '극장판 도라에몽: 진구의 남극 꽁꽁 대모험\tNNG',
#  '극장판 도라에몽: 진구의 보물섬\tNNG',
#  '극장판 도라에몽: 진구의 비밀도구 박물관\tNNG',
#  '극장판 도라에몽: 진구의 아프리카 모험 ~베코와 5인의 탐험대~\tNNG',
#  '극장판 도라에몽: 진구의 인어대해전\tNNG',
#  '극장판 도라에몽:진구의 마계대모험 7인의 마법사\tNNG',
#  '극장판 또봇: 로봇군단의 습격\tNNG',
#  '극장판 루팡 3세 VS 명탐정 코난\tNNG',
#  '극장판 뽀로로와 친구들: 바이러스를 없애줘!\tNNG',
#  '극장판 소드 아트 온라인 -오디널 스케일-\tNNG',
#  '극장판 아이엠스타 : 꿈의 오디션!\tNNG',
#  '극장판 안녕 자두야\tNNG',
#  '극장판 안녕 자두야: 제주도의 비밀\tNNG',
#  '극장판 엄마 까투리: 도시로 간 까투리 가족\tNNG',
#  '극장판 엉덩이 탐정: 수플레 섬의 비밀\tNNG',
#  '극장판 엉덩이 탐정: 화려한 사건 수첩\tNNG',
#  '극장판 에그엔젤 코코밍: 푸르밍과 두근두근 코코밍 세계\tNNG',
#  '극장판 요괴워치 섀도사이드: 도깨비왕의 부활\tNNG',
#  '극장판 요괴워치: 염라대왕과 5개의 이야기다냥!\tNNG',
#  '극장판 요괴워치: 탄생의 비밀이다냥!\tNNG',
#  '극장판 요괴워치: 하늘을 나는 고래와 더블세계다냥!\tNNG',
#  '극장판 주술회전 0\tNNG',
#  '극장판 짱구는 못말려 : 습격!! 외계인 덩덩이\tNNG',
#  '극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들\tNNG',
#  '극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교\tNNG',
#  '극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!\tNNG',
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~\tNNG',
#  '극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~\tNNG',
#  '극장판 파워레인저 트레인포스 VS 다이노포스 THE MOVIE\tNNG',
#  '극장판 파워레인저: 캡틴포스 VS 미라클포스 199 히어로 대결전\tNNG',
#  '극장판 포켓 몬스터 DP 「환영의 패왕 조로아크」\tNNG',
#  '극장판 포켓몬스터 XY : 파괴의 포켓몬과 디안시\tNNG',
#  '극장판 포켓몬스터 너로 정했다!\tNNG',
#  '극장판 포켓몬스터 모두의 이야기\tNNG',
#  '극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」\tNNG',
#  '극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」\tNNG',
#  '극장판 포켓몬스터 베스트위시: 신의 속도 게노세크트, 뮤츠의 각성\tNNG',
#  '극장판 포켓몬스터 베스트위시「메로엣타의 반짝반짝 음악회」\tNNG',
#  '극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」\tNNG',
#  '극장판 포켓몬스터: 정글의 아이, 코코\tNNG',
#  '극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이\tNNG',
#  '극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미\tNNG',
#  '극장판 헬로카봇 : 달나라를 구해줘!\tNNG',
#  '극장판 헬로카봇 : 백악기 시대\tNNG',
#  '극장판 헬로카봇: 수상한 마술단의 비밀\tNNG',
#  '극장판 헬로카봇: 옴파로스 섬의 비밀\tNNG',
#  '극장판파워레인저 엔진포스VS 와일드스피릿\tNNG',
#  '극적인 하룻밤\tNNG',
#  '극한직업\tNNG',
#  '글래스\tNNG',
#  '글러브\tNNG',
#  '글로리데이\tNNG',
#  '기기괴괴 성형수\tNNG',
#  '기다리다 미쳐\tNNG',
#  '기담\tNNG',
#  '기묘한 가족\tNNG',
#  '기방도령\tNNG',
#  '기생수 파트1\tNNG',
#  '기생충\tNNG',
#  '기술자들\tNNG',
#  '기억의 밤\tNNG',
#  '기적\tNNG',
#  '기프트\tNNG',
#  '김관장 대 김관장 대 김관장\tNNG',
#  '김복남 살인사건의 전말\tNNG',
#  '김씨표류기\tNNG',
#  '김종욱 찾기\tNNG',
#  '까불지마\tNNG',
#  '깡철이\tNNG',
#  '꼬마 니콜라\tNNG',
#  '꽃보다 남자\tNNG',
#  '꽃피는 봄이 오면\tNNG',
#  '꾸뻬씨의 행복여행\tNNG',
#  '꾼\tNNG',
#  '꿀벌대소동\tNNG',
#  '꿈은 이루어진다\tNNG',
#  '끝까지 간다\tNNG',
#  '나, 다니엘 블레이크\tNNG',
#  '나는 갈매기\tNNG',
#  '나는 공무원이다\tNNG',
#  '나는 내일, 어제의 너와 만난다\tNNG',
#  '나는 비와 함께 간다\tNNG',
#  '나는 아빠다\tNNG',
#  '나는 왕이로소이다\tNNG',
#  '나는 전설이다\tNNG',
#  '나니아 연대기-사자,마녀 그리고 옷장\tNNG',
#  '나니아 연대기: 새벽 출정호의 항해\tNNG',
#  '나니아 연대기:캐스피언 왕자\tNNG',
#  '나두야 간다\tNNG',
#  '나랏말싸미\tNNG',
#  '나를 기억해\tNNG',
#  '나를 잊지 말아요\tNNG',
#  '나를 차버린 스파이\tNNG',
#  '나를 찾아줘\tNNG',
#  '나미야 잡화점의 기적\tNNG',
#  '나비효과\tNNG',
#  '나쁜 녀석들: 더 무비\tNNG',
#  '나쁜 녀석들: 포에버\tNNG',
#  '나우 유 씨 미 2\tNNG',
#  '나우 유 씨 미 : 마술사기단\tNNG',
#  '나의 PS 파트너\tNNG',
#  '나의 결혼원정기\tNNG',
#  '나의 독재자\tNNG',
#  '나의 사랑 나의 신부\tNNG',
#  '나의 소녀시대\tNNG',
#  '나의 절친 악당들\tNNG',
#  '나의 특별한 사랑이야기\tNNG',
#  '나의 특별한 형제\tNNG',
#  '나이브스 아웃\tNNG',
#  '나이트 플라이트\tNNG',
#  '나이트메어\tNNG',
#  '나인\tNNG',
#  '나인 야드 2\tNNG',
#  '나일 강의 죽음\tNNG',
#  '나잇&데이\tNNG',
#  '날 미치게하는 남자\tNNG',
#  '날, 보러와요\tNNG',
#  '날씨의 아이\tNNG',
#  '날아라 허동구\tNNG',
#  '남과 여\tNNG',
#  '남극일기\tNNG',
#  '남산의 부장들\tNNG',
#  '남영동1985\tNNG',
#  '남자가 사랑할 때\tNNG',
#  '남자사용설명서\tNNG',
#  '남쪽으로 튀어\tNNG',
#  '남한산성\tNNG',
#  '내 깡패 같은 애인\tNNG',
#  '내 남자의 로맨스\tNNG',
#  '내 머리 속의 지우개\tNNG',
#  '내 사랑\tNNG',
#  '내 사랑 내 곁에\tNNG',
#  '내 생애 가장 아름다운 일주일\tNNG',
#  '내 생애 최악의 남자\tNNG',
#  '내 심장을 쏴라\tNNG',
#  '내 아내의 모든 것\tNNG',
#  '내 여자친구를 소개합니다\tNNG',
#  '내 이름은 칸\tNNG',
#  '내가 살인범이다\tNNG',
#  '내가 숨쉬는 공기\tNNG',
#  '내가 죽던 날\tNNG',
#  '내니 다이어리\tNNG',
#  '내니맥피 2: 유모와마법소동\tNNG',
#  '내니맥피-우리 유모는 마법사\tNNG',
#  '내부자들\tNNG',
#  '내부자들: 디 오리지널\tNNG',
#  '내사랑 싸가지\tNNG',
#  '내셔널 트레져\tNNG',
#  '내셔널 트레져:비밀의 책\tNNG',
#  '내안의 그놈\tNNG',
#  '내일의 기억\tNNG',
#  '너는 내 운명\tNNG',
#  '너는 펫\tNNG',
#  '너의 결혼식\tNNG',
#  '너의 이름은.\tNNG',
#  '너의 췌장을 먹고 싶어\tNNG',
#  '널 기다리며\tNNG',
#  '넘버23\tNNG',
#  '넛잡 2\tNNG',
#  '넛잡: 땅콩 도둑들\tNNG',
#  '네버랜드를 찾아서\tNNG',
#  '네버엔딩 스토리\tNNG',
#  '넥스트\tNNG',
#  '노리개\tNNG',
#  '노무현입니다\tNNG',
#  '노미오와 줄리엣\tNNG',
#  '노바디\tNNG',
#  '노벰버 맨\tNNG',
#  '노브레싱\tNNG',
#  '노아\tNNG',
#  '노아의 방주: 남겨진 녀석들\tNNG',
#  '노예 12년\tNNG',
#  '노잉\tNNG',
#  '노크:낯선 자들의 방문\tNNG',
#  '노트북\tNNG',
#  '논스톱\tNNG',
#  '놉\tNNG',
#  '누가 그녀와 잤을까?\tNNG',
#  '누구나 비밀은 있다\tNNG',
#  '눈길\tNNG',
#  '눈먼자들의 도시\tNNG',
#  '눈물이 주룩주룩\tNNG',
#  '눈부신 날에\tNNG',
#  '눈에는 눈 이에는 이\tNNG',
#  '눈의 여왕\tNNG',
#  '눈의 여왕 2: 트롤의 마법거울\tNNG',
#  '눈의 여왕 3: 눈과 불의 마법대결\tNNG',
#  '눈의 여왕4\tNNG',
#  '눈의 여왕5: 스노우 프린세스와 미러랜드의 비밀\tNNG',
#  '뉴 문\tNNG',
#  '뉴 폴리스 스토리\tNNG',
#  '뉴욕은 언제나 사랑 중\tNNG',
#  '늑대사냥\tNNG',
#  '늑대소년\tNNG',
#  '늑대소년-확장판\tNNG',
#  '늑대아이\tNNG',
#  '늑대의 유혹\tNNG',
#  '니 부모 얼굴이 보고 싶다\tNNG',
#  '니드 포 스피드\tNNG',
#  '니코\tNNG',
#  '니코: 산타비행단의 모험\tNNG',
#  '닌자 어쌔신\tNNG',
#  '닌자거북이 TMNT\tNNG',
#  '닌자터틀\tNNG',
#  '닌자터틀 : 어둠의 히어로\tNNG',
#  '님스 아일랜드\tNNG',
#  '님아, 그 강을 건너지 마오\tNNG',
#  '님은 먼 곳에\tNNG',
#  '다만 악에서 구하소서\tNNG',
#  '다빈치 코드\tNNG',
#  '다세포소녀\tNNG',
#  '다운사이징\tNNG',
#  '다이 하드 4 : 죽어도 산다\tNNG',
#  '다이노 타임\tNNG',
#  '다이노소어 어드벤처 3D\tNNG',
#  '다이노소어 어드벤처 : 백악기 공룡대백과\tNNG',
#  '다이버전트\tNNG',
#  '다이버전트 시리즈: 얼리전트\tNNG',
#  '다이하드: 굿 데이 투 다이\tNNG',
#  '다찌마와리\tNNG',
#  '다크 나이트\tNNG',
#  '다크 나이트 라이즈\tNNG',
#  '다크 섀도우\tNNG',
#  '다크 워터스\tNNG',
#  '다크아워\tNNG',
#  '닥터 두리틀\tNNG',
#  '닥터 스트레인지\tNNG',
#  '닥터 스트레인지: 대혼돈의 멀티버스\tNNG',
#  '달마야, 서울 가자\tNNG',
#  '달빛궁궐\tNNG',
#  '달콤, 살벌한 연인\tNNG',
#  '달콤한 거짓말\tNNG',
#  '달콤한 인생\tNNG',
#  '담보\tNNG',
#  '당갈\tNNG',
#  '당신, 거기 있어줄래요\tNNG',
#  '당신이 사랑하는 동안에\tNNG',
#  '대니쉬 걸\tNNG',
#  '대립군\tNNG',
#  '대배우\tNNG',
#  '대장 김창수\tNNG',
#  '대한민국 1%\tNNG',
#  '대한이, 민국씨\tNNG',
#  '대호\tNNG',
#  '댄 인 러브\tNNG',
#  '댄서의 순정\tNNG',
#  '댄싱퀸\tNNG',
#  '더 건맨\tNNG',
#  '더 게임\tNNG',
#  '더 그레이\tNNG',
#  '더 기버: 기억전달자\tNNG',
#  '더 넌\tNNG',
#  '더 독\tNNG',
#  '더 레이븐\tNNG',
#  '더 로드\tNNG',
#  '더 리더: 책 읽어주는 남자\tNNG',
#  '더 박스\tNNG',
#  '더 배트맨\tNNG',
#  '더 버터플라이\tNNG',
#  '더 셰프\tNNG',
#  '더 수어사이드 스쿼드\tNNG',
#  '더 스파이\tNNG',
#  '더 시그널\tNNG',
#  '더 울버린\tNNG',
#  '더 울프 오브 월스트리트\tNNG',
#  '더 웹툰: 예고살인\tNNG',
#  '더 임파서블\tNNG',
#  '더 자이언트\tNNG',
#  '더 콘서트\tNNG',
#  '더 큐어\tNNG',
#  '더 킹\tNNG',
#  '더 테러 라이브\tNNG',
#  '더 테이블\tNNG',
#  '더 파이브\tNNG',
#  '더 퍼지\tNNG',
#  '더 페이버릿: 여왕의 여자\tNNG',
#  '더 포스트\tNNG',
#  '더 폰\tNNG',
#  '더 프레데터\tNNG',
#  '더블타겟\tNNG',
#  '덕구\tNNG',
#  '덕수리 5형제\tNNG',
#  '덕혜옹주\tNNG',
#  '덤 앤 더머 투\tNNG',
#  '덤보\tNNG',
#  '덩케르크\tNNG',
#  '데드풀\tNNG',
#  '데드풀 2\tNNG',
#  '데블\tNNG',
#  '데스 디파잉:어느 마술사의 사랑\tNNG',
#  '데스 레이스\tNNG',
#  '데스노트\tNNG',
#  '데스노트 : 라스트 네임\tNNG',
#  '데스노트 L: 새로운 시작\tNNG',
#  '데시벨\tNNG',
#  '데이브레이커스\tNNG',
#  '데이지\tNNG',
#  '데자뷰\tNNG',
#  '도가니\tNNG',
#  '도굴\tNNG',
#  '도둑들\tNNG',
#  '도라에몽 : 스탠 바이 미\tNNG',
#  '도레미파솔라시도\tNNG',
#  '도리를 찾아서\tNNG',
#  '도리화가\tNNG',
#  '도마뱀\tNNG',
#  '도어락\tNNG',
#  '도희야\tNNG',
#  '독수리 에디\tNNG',
#  '독전\tNNG',
#  '독전: 익스텐디드 컷\tNNG',
#  '돈\tNNG',
#  '돈 크라이 마미\tNNG',
#  '돈 텔 파파\tNNG',
#  '돈의 맛\tNNG',
#  '돌연변이\tNNG',
#  '동감\tNNG',
#  '동갑내기 과외하기 레슨 2\tNNG',
#  '동네사람들\tNNG',
#  '동주\tNNG',
#  '동창생\tNNG',
#  '동해물과 백두산이\tNNG',
#  '두 개의 달\tNNG',
#  '두 사람이다\tNNG',
#  '두 얼굴의 여친\tNNG',
#  '두 여자\tNNG',
#  '두근두근 내 인생\tNNG',
#  '두뇌유희프로젝트, 퍼즐\tNNG',
#  '두번할까요\tNNG',
#  '듄\tNNG',
#  '드라큘라: 전설의 시작\tNNG',
#  '드래곤 길들이기\tNNG',
#  '드래곤 길들이기 2\tNNG',
#  '드래곤 길들이기 3\tNNG',
#  '드래곤볼 에볼루션\tNNG',
#  '드래그 미 투 헬\tNNG',
#  '드리머\tNNG',
#  '드림 쏭\tNNG',
#  '드림걸즈\tNNG',
#  '들어는 봤니? 모건 부부\tNNG',
#  '디 아이2\tNNG',
#  '디바\tNNG',
#  '디센트\tNNG',
#  '디스 민즈 워\tNNG',
#  '디스터비아\tNNG',
#  '디스트릭트 9\tNNG',
#  '디어 에반 핸슨\tNNG',
#  '디어 존\tNNG',
#  '디워\tNNG',
#  '디파이언스\tNNG',
#  '디파티드\tNNG',
#  '딥\tNNG',
#  '딥워터 호라이즌\tNNG',
#  '또 하나의 약속\tNNG',
#  '똥파리\tNNG',
#  '뚝방전설\tNNG',
#  '뜨거운 것이 좋아\tNNG',
#  '뜨거운 피\tNNG',
#  '라 비 앙 로즈\tNNG',
#  '라듸오 데이즈\tNNG',
#  '라디오 스타\tNNG',
#  '라따뚜이\tNNG',
#  '라라랜드\tNNG',
#  '라스베가스에서만 생길 수 있는 일\tNNG',
#  '라스트 갓파더\tNNG',
#  '라스트 나잇\tNNG',
#  '라스트 미션\tNNG',
#  '라스트 사무라이\tNNG',
#  '라스트 에어벤더\tNNG',
#  '라스트 엑소시즘\tNNG',
#  '라스트 위치 헌터\tNNG',
#  '라스트 크리스마스\tNNG',
#  '라스트베가스\tNNG',
#  '라야와 마지막 드래곤\tNNG',
#  '라이어\tNNG',
#  '라이언\tNNG',
#  '라이온 킹\tNNG',
#  '라이트 아웃\tNNG',
#  '라이프\tNNG',
#  '라이프 오브 파이\tNNG',
#  '라파예트\tNNG',
#  '라푼젤\tNNG',
#  '락아웃: 익스트림미션\tNNG',
#  '람보 4 : 라스트 블러드\tNNG',
#  '람보 : 라스트 워\tNNG',
#  '랑종\tNNG',
#  '램페이지\tNNG',
#  '랭고\tNNG',
#  '러브 & 드럭스\tNNG',
#  '러브 & 트러블\tNNG',
#  '러브 라이브! 더 스쿨 아이돌 무비\tNNG',
#  '러브 액츄얼리\tNNG',
#  '러브 앤 프렌즈\tNNG',
#  '러브, 로지\tNNG',
#  '러브레터\tNNG',
#  '러브픽션\tNNG',
#  '러블리 본즈\tNNG',
#  '러빙 빈센트\tNNG',
#  '러시 : 더 라이벌\tNNG',
#  '러시 아워 3\tNNG',
#  '럭키\tNNG',
#  '럭키 넘버 슬레븐\tNNG',
#  '런\tNNG',
#  '런 올 나이트\tNNG',
#  '런닝맨\tNNG',
#  '런닝맨 : 풀룰루의 역습\tNNG',
#  '런던 해즈 폴른\tNNG',
#  '레고 닌자고 무비\tNNG',
#  '레고 무비\tNNG',
#  '레고 배트맨 무비\tNNG',
#  '레드\tNNG',
#  '레드 라이딩 후드\tNNG',
#  '레드 스패로\tNNG',
#  '레드 아이\tNNG',
#  '레드: 더 레전드\tNNG',
#  '레드슈즈\tNNG',
#  '레드카펫\tNNG',
#  '레디 플레이어 원\tNNG',
#  '레모니 스니켓의 위험한 대결\tNNG',
#  '레미제라블\tNNG',
#  '레버넌트: 죽음에서 돌아온 자\tNNG',
#  '레슬러\tNNG',
#  '레이\tNNG',
#  '레이디 버드\tNNG',
#  '레이디 인 더 워터\tNNG',
#  '레이크 하우스\tNNG',
#  '레전드\tNNG',
#  '레전드 오브 조로\tNNG',
#  '레전드 오브 타잔\tNNG',
#  '레지던트 이블 2-아포칼립스\tNNG',
#  '레지던트 이블 3 - 인류의 멸망\tNNG',
#  '레지던트 이블 4: 끝나지 않은 전쟁 3D\tNNG',
#  '레지던트 이블 5 : 최후의 심판\tNNG',
#  '레지던트 이블: 파멸의 날\tNNG',
#  '레터스 투 줄리엣\tNNG',
#  '렛 미 인\tNNG',
#  '령\tNNG',
#  '로건\tNNG',
#  '로그 원: 스타워즈 스토리\tNNG',
#  '로드 오브 워\tNNG',
#  '로렉스\tNNG',
#  '로마 위드 러브\tNNG',
#  '로마의 휴일\tNNG',
#  '로망스\tNNG',
#  '로맨틱 아일랜드\tNNG',
#  '로맨틱 크라운\tNNG',
#  '로맨틱 홀리데이\tNNG',
#  '로보캅\tNNG',
#  '로봇(애니)\tNNG',
#  '로봇, 소리\tNNG',
#  '로빈 후드\tNNG',
#  '로빈슨 가족\tNNG',
#  '로빈슨 크루소\tNNG',
#  '로스트 라이온즈\tNNG',
#  '로스트 시티\tNNG',
#  '로켓맨\tNNG',
#  '록키 발보아\tNNG',
#  '론 레인저\tNNG',
#  '론 서바이버\tNNG',
#  '롤러코스터\tNNG',
#  '롱 리브 더 킹: 목포 영웅\tNNG',
#  '롱 샷\tNNG',
#  '루돌프와 많이있어\tNNG',
#  '루시\tNNG',
#  '루시드 드림\tNNG',
#  '루카\tNNG',
#  '루퍼\tNNG',
#  '리딕\tNNG',
#  '리딕 - 헬리온 최후의 빛\tNNG',
#  '리멤버\tNNG',
#  '리미트리스\tNNG',
#  '리얼\tNNG',
#  '리얼 스틸\tNNG',
#  '리오\tNNG',
#  '리오 2\tNNG',
#  '리턴\tNNG',
#  '리틀 비버\tNNG',
#  '리틀 포레스트\tNNG',
#  '리핑 10개의 재앙\tNNG',
#  '링2(2005)\tNNG',
#  '링스 어드벤처\tNNG',
#  '링컨\tNNG',
#  '링컨 차를 타는 변호사\tNNG',
#  '링컨: 뱀파이어 헌터\tNNG',
#  '마강호텔\tNNG',
#  '마고리엄의 장난감 백화점\tNNG',
#  '마녀\tNNG',
#  '마녀(魔女) Part2. The Other One\tNNG',
#  '마다가스카\tNNG',
#  '마다가스카 2\tNNG',
#  '마다가스카3 : 이번엔 서커스다!\tNNG',
#  '마다가스카의 펭귄\tNNG',
#  '마담 뺑덕\tNNG',
#  '마담 프루스트의 비밀정원\tNNG',
#  '마당을 나온 암탉\tNNG',
#  '마더\tNNG',
#  '마루 밑 아리에티\tNNG',
#  '마린보이\tNNG',
#  '마마\tNNG',
#  '마법사의 제자\tNNG',
#  '마법에 걸린 사랑\tNNG',
#  '마법천자문: 대마왕의 부활을 막아라\tNNG',
#  '마션\tNNG',
#  '마스터\tNNG',
#  '마야\tNNG',
#  '마약왕\tNNG',
#  '마을금고 연쇄습격사건\tNNG',
#  '마음이...\tNNG',
#  '마음이2\tNNG',
#  '마이 뉴 파트너\tNNG',
#  '마이 리틀 자이언트\tNNG',
#  '마이 리틀 히어로\tNNG',
#  '마이 블랙 미니드레스\tNNG',
#  '마이 블루베리 나이츠\tNNG',
#  '마이 시스터즈 키퍼\tNNG',
#  '마이 웨이\tNNG',
#  '마이 캡틴 김대출\tNNG',
#  '마이 파더\tNNG',
#  '마이애미 바이스\tNNG',
#  '마이클 잭슨의 디스 이즈 잇\tNNG',
#  '마이클 클레이튼\tNNG',
#  '마이펫 오지\tNNG',
#  '마이펫의 이중생활\tNNG',
#  '마이펫의 이중생활 2\tNNG',
#  '마지막 4중주\tNNG',
#  '마지막 선물\tNNG',
#  '마파도\tNNG',
#  '마파도2\tNNG',
#  '만남의 광장\tNNG',
#  '만추\tNNG',
#  '말레피센트\tNNG',
#  '말레피센트 2\tNNG',
#  '말리와 나\tNNG',
#  '말모이\tNNG',
#  '말아톤\tNNG',
#  '말죽거리 잔혹사\tNNG',
#  '말할 수 없는 비밀\tNNG',
#  '맘마미아!\tNNG',
#  '맘마미아!2\tNNG',
#  '매그니피센트 7\tNNG',
#  '매드 맥스: 분노의 도로\tNNG',
#  '매직브러시\tNNG',
#  '매치 포인트\tNNG',
#  '매트릭스: 리저렉션\tNNG',
#  '맥스 페인\tNNG',
#  '맨 오브 스틸\tNNG',
#  '맨 온 렛지\tNNG',
#  '맨 온 파이어\tNNG',
#  '맨 인 더 다크\tNNG',
#  '맨 인 블랙 3\tNNG',
#  '맨 인 블랙: 인터내셔널\tNNG',
#  '맨 프롬 UNCLE\tNNG',
#  '맨발의 기봉이\tNNG',
#  '맨발의 꿈\tNNG',
#  '맨홀\tNNG',
#  '맹부삼천지교\tNNG',
#  '머니볼\tNNG',
#  '먹고 기도하고 사랑하라\tNNG',
#  '멋진 하루\tNNG',
#  '메가로돈\tNNG',
#  '메가마인드\tNNG',
#  '메리 포핀스 리턴즈\tNNG',
#  '메리다와 마법의 숲\tNNG',
#  '메리와 마녀의 꽃\tNNG',
#  '메신져 - 죽은자들의 경고\tNNG',
#  '메이즈 러너\tNNG',
#  '메이즈 러너: 데스 큐어\tNNG',
#  '메이즈 러너: 스코치 트라이얼\tNNG',
#  '메카닉\tNNG',
#  '메카닉: 리크루트\tNNG',
#  '명당\tNNG',
#  '명량\tNNG',
#  '명장\tNNG',
#  '명탐정 코난 : 수평선상의 음모\tNNG',
#  '명탐정 코난 : 이차원의 저격수\tNNG',
#  '명탐정 코난 : 제로의 집행인\tNNG',
#  '명탐정 코난 : 칠흑의 추적자\tNNG',
#  '명탐정 코난 : 침묵의 15분\tNNG',
#  '명탐정 코난 : 코난 실종사건 - 사상 최악의 이틀\tNNG',
#  '명탐정 코난 : 탐정들의 진혼가\tNNG',
#  '명탐정 코난 : 화염의 해바라기\tNNG',
#  '명탐정 코난: 11번째 스트라이커\tNNG',
#  '명탐정 코난: 감청의 권\tNNG',
#  '명탐정 코난: 비색의 탄환\tNNG',
#  '명탐정 코난: 순흑의 악몽\tNNG',
#  '명탐정 코난: 에피소드 원-작아진 명탐정\tNNG',
#  '명탐정 코난: 천공의 난파선\tNNG',
#  '명탐정 코난: 할로윈의 신부\tNNG',
#  '명탐정 코난:감벽의 관\tNNG',
#  '명탐정 코난:베이커가의 망령\tNNG',
#  '명탐정 코난:은빛 날개의 마술사\tNNG',
#  '명탐정 코난:전율의 악보\tNNG',
#  '명탐정 코난:진홍의 연가\tNNG',
#  '명탐정 피카츄\tNNG',
#  '모가디슈\tNNG',
#  '모노폴리\tNNG',
#  '모던보이\tNNG',
#  '모모와 다락방의 수상한 요괴들\tNNG',
#  '모범시민\tNNG',
#  '모비딕\tNNG',
#  '모비우스\tNNG',
#  '모아나\tNNG',
#  '모털 엔진\tNNG',
#  '목격자\tNNG',
#  '목소리의 형태\tNNG',
#  '목포는 항구다\tNNG',
#  '몬스터\tNNG',
#  '몬스터 vs 에이리언\tNNG',
#  '몬스터 대학교\tNNG',
#  '몬스터 패밀리\tNNG',
#  ...]

# %%
# new_user_dict = list(set(new_user_dict))
# new_user_dict

# %%
# print(len(new_user_dict))
# new_user_dict

# %%
# from collections import OrderedDict

# new_user_dict = list(OrderedDict.fromkeys(new_user_dict))
# new_user_dict

# %%
print(len(new_user_dict))
new_user_dict
# Out:
# 17565
# ['0시\tNNG',
#  '1시\tNNG',
#  '2시\tNNG',
#  '3시\tNNG',
#  '4시\tNNG',
#  '5시\tNNG',
#  '6시\tNNG',
#  '7시\tNNG',
#  '8시\tNNG',
#  '9시\tNNG',
#  '10시\tNNG',
#  '11시\tNNG',
#  '12시\tNNG',
#  '13시\tNNG',
#  '14시\tNNG',
#  '15시\tNNG',
#  '16시\tNNG',
#  '17시\tNNG',
#  '18시\tNNG',
#  '19시\tNNG',
#  '20시\tNNG',
#  '21시\tNNG',
#  '22시\tNNG',
#  '23시\tNNG',
#  '24시\tNNG',
#  '0분\tNNG',
#  '1분\tNNG',
#  '2분\tNNG',
#  '3분\tNNG',
#  '4분\tNNG',
#  '5분\tNNG',
#  '6분\tNNG',
#  '7분\tNNG',
#  '8분\tNNG',
#  '9분\tNNG',
#  '10분\tNNG',
#  '11분\tNNG',
#  '12분\tNNG',
#  '13분\tNNG',
#  '14분\tNNG',
#  '15분\tNNG',
#  '16분\tNNG',
#  '17분\tNNG',
#  '18분\tNNG',
#  '19분\tNNG',
#  '20분\tNNG',
#  '21분\tNNG',
#  '22분\tNNG',
#  '23분\tNNG',
#  '24분\tNNG',
#  '25분\tNNG',
#  '26분\tNNG',
#  '27분\tNNG',
#  '28분\tNNG',
#  '29분\tNNG',
#  '30분\tNNG',
#  '31분\tNNG',
#  '32분\tNNG',
#  '33분\tNNG',
#  '34분\tNNG',
#  '35분\tNNG',
#  '36분\tNNG',
#  '37분\tNNG',
#  '38분\tNNG',
#  '39분\tNNG',
#  '40분\tNNG',
#  '41분\tNNG',
#  '42분\tNNG',
#  '43분\tNNG',
#  '44분\tNNG',
#  '45분\tNNG',
#  '46분\tNNG',
#  '47분\tNNG',
#  '48분\tNNG',
#  '49분\tNNG',
#  '50분\tNNG',
#  '51분\tNNG',
#  '52분\tNNG',
#  '53분\tNNG',
#  '54분\tNNG',
#  '55분\tNNG',
#  '56분\tNNG',
#  '57분\tNNG',
#  '58분\tNNG',
#  '59분\tNNG',
#  '60분\tNNG',
#  '1월\tNNG',
#  '2월\tNNG',
#  '3월\tNNG',
#  '4월\tNNG',
#  '5월\tNNG',
#  '6월\tNNG',
#  '7월\tNNG',
#  '8월\tNNG',
#  '9월\tNNG',
#  '10월\tNNG',
#  '11월\tNNG',
#  '12월\tNNG',
#  '1일\tNNG',
#  '2일\tNNG',
#  '3일\tNNG',
#  '4일\tNNG',
#  '5일\tNNG',
#  '6일\tNNG',
#  '7일\tNNG',
#  '8일\tNNG',
#  '9일\tNNG',
#  '10일\tNNG',
#  '11일\tNNG',
#  '12일\tNNG',
#  '13일\tNNG',
#  '14일\tNNG',
#  '15일\tNNG',
#  '16일\tNNG',
#  '17일\tNNG',
#  '18일\tNNG',
#  '19일\tNNG',
#  '20일\tNNG',
#  '21일\tNNG',
#  '22일\tNNG',
#  '23일\tNNG',
#  '24일\tNNG',
#  '25일\tNNG',
#  '26일\tNNG',
#  '27일\tNNG',
#  '28일\tNNG',
#  '29일\tNNG',
#  '30일\tNNG',
#  '31일\tNNG',
#  '월요일\tNNG',
#  '화요일\tNNG',
#  '수요일\tNNG',
#  '목요일\tNNG',
#  '금요일\tNNG',
#  '토요일\tNNG',
#  '일요일\tNNG',
#  '#살아있다\tNNG',
#  '0.0MHz\tNNG',
#  '007 노 타임 투 다이\tNNG',
#  '007 스카이폴\tNNG',
#  '007 스펙터\tNNG',
#  '007 카지노 로얄\tNNG',
#  '007 퀀텀 오브 솔러스\tNNG',
#  '10,000 BC\tNNG',
#  '10억\tNNG',
#  '12 솔져스\tNNG',
#  '127시간\tNNG',
#  '13구역\tNNG',
#  '13구역: 얼티메이텀\tNNG',
#  '13시간\tNNG',
#  '13일의 금요일\tNNG',
#  '1408\tNNG',
#  '1724 기방난동사건\tNNG',
#  '1917\tNNG',
#  '1987\tNNG',
#  '19곰 테드\tNNG',
#  '19곰 테드 2\tNNG',
#  '1급기밀\tNNG',
#  '1번가의 기적\tNNG',
#  '2012\tNNG',
#  '2046\tNNG',
#  '20세기 소년\tNNG',
#  '21\tNNG',
#  '21 브릿지: 테러 셧다운\tNNG',
#  '22 블렛\tNNG',
#  '23 아이덴티티\tNNG',
#  '26년\tNNG',
#  '27번의 결혼리허설\tNNG',
#  '300\tNNG',
#  '300: 제국의 부활\tNNG',
#  '4.4.4\tNNG',
#  '47 미터\tNNG',
#  '47미터 2\tNNG',
#  '50/50\tNNG',
#  '500일의 썸머\tNNG',
#  '50가지 그림자: 심연\tNNG',
#  '50가지 그림자: 해방\tNNG',
#  '5백만불의 사나이\tNNG',
#  '6년째 연애중\tNNG',
#  '6월의 일기\tNNG',
#  '7광구\tNNG',
#  '7급 공무원\tNNG',
#  '7년의 밤\tNNG',
#  '7번방의 선물\tNNG',
#  '7호실\tNNG',
#  '80일간의 세계 일주\tNNG',
#  '82년생 김지영\tNNG',
#  '88분\tNNG',
#  '8인: 최후의 결사단\tNNG',
#  'A-특공대\tNNG',
#  'BB프로젝트\tNNG',
#  'B형 남자친구\tNNG',
#  'CJ7:장강7호\tNNG',
#  'DC 리그 오브 슈퍼-펫\tNNG',
#  'DMZ, 비무장지대\tNNG',
#  'DOA\tNNG',
#  'GP 506\tNNG',
#  'Mr.로빈 꼬시기\tNNG',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG',
#  'P.S. 아이 러브 유\tNNG',
#  'PMC: 더 벙커\tNNG',
#  'R.I.P.D. : 알.아이.피.디.\tNNG',
#  'R2B: 리턴투베이스\tNNG',
#  'S 다이어리\tNNG',
#  'pm 11:14\tNNG',
#  '가디언\tNNG',
#  '가디언의 전설\tNNG',
#  '가디언즈\tNNG',
#  '가디언즈 오브 갤럭시\tNNG',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG',
#  '가려진 시간\tNNG',
#  '가루지기\tNNG',
#  '가면\tNNG',
#  '가문의 부활 - 가문의 영광3\tNNG',
#  '가문의 영광4 - 가문의 수난\tNNG',
#  '가문의 영광5 - 가문의 귀환\tNNG',
#  '가문의 위기(가문의 영광2)\tNNG',
#  '가발\tNNG',
#  '가버나움\tNNG',
#  '가부와 메이 이야기\tNNG',
#  '가비\tNNG',
#  '가시\tNNG',
#  '가을로\tNNG',
#  '가장 보통의 연애\tNNG',
#  '가족\tNNG',
#  '가족의 탄생\tNNG',
#  '가필드\tNNG',
#  '가필드 2\tNNG',
#  '각설탕\tNNG',
#  '간 큰 가족\tNNG',
#  '간기남\tNNG',
#  '간신\tNNG',
#  '간첩\tNNG',
#  '감기\tNNG',
#  '감바의 대모험\tNNG',
#  '감시자들\tNNG',
#  '감쪽같은 그녀\tNNG',
#  '갓 오브 이집트\tNNG',
#  '강남 1970\tNNG',
#  '강력 3반\tNNG',
#  '강릉\tNNG',
#  '강적\tNNG',
#  '강철대오:구국의 철가방\tNNG',
#  '강철비\tNNG',
#  '강철비2: 정상회담\tNNG',
#  '강철중: 공공의 적 1-1\tNNG',
#  '개구쟁이 스머프\tNNG',
#  '개구쟁이 스머프 2\tNNG',
#  '개를 훔치는 완벽한 방법\tNNG',
#  '거룩한 계보\tNNG',
#  '거북이 달린다\tNNG',
#  '거울나라의 앨리스\tNNG',
#  '건축학개론\tNNG',
#  '걸리버 여행기\tNNG',
#  '걸스카우트\tNNG',
#  '걸캅스\tNNG',
#  '걸프렌즈\tNNG',
#  '검객\tNNG',
#  '검사외전\tNNG',
#  '검우강호\tNNG',
#  '검은 사제들\tNNG',
#  '검은 집\tNNG',
#  '겁나는 여친의 완벽한 비밀\tNNG',
#  '게드전기 : 어스시의 전설\tNNG',
#  '게스후\tNNG',
#  '게이머\tNNG',
#  '게이샤의 추억\tNNG',
#  '게이트\tNNG',
#  '겟 스마트\tNNG',
#  '겟 썸\tNNG',
#  '겟 아웃\tNNG',
#  '겨울왕국\tNNG',
#  '겨울왕국 2\tNNG',
#  '결백\tNNG',
#  '결혼전야\tNNG',
#  '경관의 피\tNNG',
#  '경성학교: 사라진 소녀들\tNNG',
#  '계춘할망\tNNG',
#  '고死 : 피의 중간고사\tNNG',
#  '고死 두 번째 이야기: 교생실습\tNNG',
#  '고고 70\tNNG',
#  '고령화 가족\tNNG',
#  '고산자, 대동여지도\tNNG',
#  '고스트 라이더\tNNG',
#  '고스트 라이더 : 복수의 화신\tNNG',
#  '고스트버스터즈\tNNG',
#  '고스트버스터즈 라이즈\tNNG',
#  '고양이: 죽음을 보는 두 개의 눈\tNNG',
#  '고장난 론\tNNG',
#  '고지전\tNNG',
#  '고질라\tNNG',
#  '고질라 VS. 콩\tNNG',
#  '고질라: 킹 오브 몬스터\tNNG',
#  '곡성\tNNG',
#  '곤지암\tNNG',
#  '골든 에이지\tNNG',
#  '골든슬럼버\tNNG',
#  '곰돌이 푸 다시 만나 행복해\tNNG',
#  '공각기동대 : 고스트 인 더 쉘\tNNG',
#  '공공의 적 2\tNNG',
#  '공기살인\tNNG',
#  '공모자들\tNNG',
#  '공범\tNNG',
#  '공범자들\tNNG',
#  '공자 춘추전국시대\tNNG',
#  '공작\tNNG',
#  '공작부인:세기의 스캔들\tNNG',
#  '공조\tNNG',
#  '공조2: 인터내셔날\tNNG',
#  '공주와 개구리\tNNG',
#  '공포의 묘지\tNNG',
#  '공필두\tNNG',
#  '과속스캔들\tNNG',
#  '관능의 법칙\tNNG',
#  '관상\tNNG',
#  '광대들: 풍문조작단\tNNG',
#  '광식이 동생 광태\tNNG',
#  '광해, 왕이 된 남자\tNNG',
#  '괴물\tNNG',
#  '괴물의 아이\tNNG',
#  '교회오빠\tNNG',
#  '구르믈 버서난 달처럼\tNNG',
#  '구미호 가족\tNNG',
#  '구세주\tNNG',
#  '구세주 2\tNNG',
#  '구스범스\tNNG',
#  '구타유발자들\tNNG',
#  '국가대표\tNNG',
#  '국가대표 2\tNNG',
#  '국가대표 완결판-못 다한 이야기\tNNG',
#  '국가부도의 날\tNNG',
#  '국경의 남쪽\tNNG',
#  '국제수사\tNNG',
#  '국제시장\tNNG',
#  '군도: 민란의 시대\tNNG',
#  '군함도\tNNG',
#  '굿 다이노\tNNG',
#  '굿모닝 에브리원\tNNG',
#  '굿모닝 프레지던트\tNNG',
#  '굿바이\tNNG',
#  '굿바이 싱글\tNNG',
#  '궁녀\tNNG',
#  '궁합\tNNG',
#  '권순분여사 납치사건\tNNG',
#  '귀신이 산다\tNNG',
#  '귀향\tNNG',
#  '그 여자 작사 그 남자 작곡\tNNG',
#  '그것\tNNG',
#  '그것: 두 번째 이야기\tNNG',
#  '그것만이 내 세상\tNNG',
#  '그날, 바다\tNNG',
#  '그날의 분위기\tNNG',
#  '그녀\tNNG',
#  '그녀는 요술쟁이\tNNG',
#  '그녀를 믿지 마세요\tNNG',
#  '그놈 목소리\tNNG',
#  '그놈은 멋있었다\tNNG',
#  '그놈이다\tNNG',
#  '그는 당신에게 반하지 않았다\tNNG',
#  '그대가 조국\tNNG',
#  '그대를 사랑합니다\tNNG',
#  '그때 그 사람들\tNNG',
#  '그랑프리\tNNG',
#  '그래비티\tNNG',
#  '그랜 토리노\tNNG',
#  '그랜드 부다페스트 호텔\tNNG',
#  '그렇게 아버지가 된다\tNNG',
#  '그레이스 오브 모나코\tNNG',
#  '그레이의 50가지 그림자\tNNG',
#  '그레이트 월\tNNG',
#  '그루지\tNNG',
#  '그루지 2\tNNG',
#  '그린 북\tNNG',
#  '그린 존\tNNG',
#  '그린 호넷\tNNG',
#  '그린랜드\tNNG',
#  '그린랜턴: 반지의 선택\tNNG',
#  '그린치\tNNG',
#  '그림자 살인\tNNG',
#  '그림형제 : 마르바덴 숲의 전설\tNNG',
#  '그해 여름\tNNG',
#  '극락도 살인사건\tNNG',
#  '극비수사\tNNG',
#  '극장판 공룡메카드: 타이니소어의 섬\tNNG',
#  '극장판 귀멸의 칼날: 무한열차편\tNNG',
#  '극장판 꼬마버스 타요의 에이스 구출작전\tNNG',
#  '극장판 도라에몽 : 진구의 우주영웅기~스페이스 히어로즈~\tNNG',
#  '극장판 도라에몽: 진구와 기적의 섬 애니멀 어드벤처\tNNG',
#  '극장판 도라에몽: 진구와 철인군단 날아라 천사들\tNNG',
#  '극장판 도라에몽: 진구의 공룡대탐험\tNNG',
#  '극장판 도라에몽: 진구의 남극 꽁꽁 대모험\tNNG',
#  '극장판 도라에몽: 진구의 보물섬\tNNG',
#  '극장판 도라에몽: 진구의 비밀도구 박물관\tNNG',
#  '극장판 도라에몽: 진구의 아프리카 모험 ~베코와 5인의 탐험대~\tNNG',
#  '극장판 도라에몽: 진구의 인어대해전\tNNG',
#  '극장판 도라에몽:진구의 마계대모험 7인의 마법사\tNNG',
#  '극장판 또봇: 로봇군단의 습격\tNNG',
#  '극장판 루팡 3세 VS 명탐정 코난\tNNG',
#  '극장판 뽀로로와 친구들: 바이러스를 없애줘!\tNNG',
#  '극장판 소드 아트 온라인 -오디널 스케일-\tNNG',
#  '극장판 아이엠스타 : 꿈의 오디션!\tNNG',
#  '극장판 안녕 자두야\tNNG',
#  '극장판 안녕 자두야: 제주도의 비밀\tNNG',
#  '극장판 엄마 까투리: 도시로 간 까투리 가족\tNNG',
#  '극장판 엉덩이 탐정: 수플레 섬의 비밀\tNNG',
#  '극장판 엉덩이 탐정: 화려한 사건 수첩\tNNG',
#  '극장판 에그엔젤 코코밍: 푸르밍과 두근두근 코코밍 세계\tNNG',
#  '극장판 요괴워치 섀도사이드: 도깨비왕의 부활\tNNG',
#  '극장판 요괴워치: 염라대왕과 5개의 이야기다냥!\tNNG',
#  '극장판 요괴워치: 탄생의 비밀이다냥!\tNNG',
#  '극장판 요괴워치: 하늘을 나는 고래와 더블세계다냥!\tNNG',
#  '극장판 주술회전 0\tNNG',
#  '극장판 짱구는 못말려 : 습격!! 외계인 덩덩이\tNNG',
#  '극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들\tNNG',
#  '극장판 짱구는 못말려: 수수께끼! 꽃피는 천하떡잎학교\tNNG',
#  '극장판 짱구는 못말려: 신혼여행 허리케인~ 사라진 아빠!\tNNG',
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~\tNNG',
#  '극장판 파워레인저 다이노포스VS고버스터즈 공룡 대결전! ~안녕, 영원한 친구여!~\tNNG',
#  '극장판 파워레인저 트레인포스 VS 다이노포스 THE MOVIE\tNNG',
#  '극장판 파워레인저: 캡틴포스 VS 미라클포스 199 히어로 대결전\tNNG',
#  '극장판 포켓 몬스터 DP 「환영의 패왕 조로아크」\tNNG',
#  '극장판 포켓몬스터 XY : 파괴의 포켓몬과 디안시\tNNG',
#  '극장판 포켓몬스터 너로 정했다!\tNNG',
#  '극장판 포켓몬스터 모두의 이야기\tNNG',
#  '극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」\tNNG',
#  '극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」\tNNG',
#  '극장판 포켓몬스터 베스트위시: 신의 속도 게노세크트, 뮤츠의 각성\tNNG',
#  '극장판 포켓몬스터 베스트위시「메로엣타의 반짝반짝 음악회」\tNNG',
#  '극장판 포켓몬스터 베스트위시「큐레무 VS 성검사 케르디오」\tNNG',
#  '극장판 포켓몬스터: 정글의 아이, 코코\tNNG',
#  '극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이\tNNG',
#  '극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미\tNNG',
#  '극장판 헬로카봇 : 달나라를 구해줘!\tNNG',
#  '극장판 헬로카봇 : 백악기 시대\tNNG',
#  '극장판 헬로카봇: 수상한 마술단의 비밀\tNNG',
#  '극장판 헬로카봇: 옴파로스 섬의 비밀\tNNG',
#  '극장판파워레인저 엔진포스VS 와일드스피릿\tNNG',
#  '극적인 하룻밤\tNNG',
#  '극한직업\tNNG',
#  '글래스\tNNG',
#  '글러브\tNNG',
#  '글로리데이\tNNG',
#  '기기괴괴 성형수\tNNG',
#  '기다리다 미쳐\tNNG',
#  '기담\tNNG',
#  '기묘한 가족\tNNG',
#  '기방도령\tNNG',
#  '기생수 파트1\tNNG',
#  '기생충\tNNG',
#  '기술자들\tNNG',
#  '기억의 밤\tNNG',
#  '기적\tNNG',
#  '기프트\tNNG',
#  '김관장 대 김관장 대 김관장\tNNG',
#  '김복남 살인사건의 전말\tNNG',
#  '김씨표류기\tNNG',
#  '김종욱 찾기\tNNG',
#  '까불지마\tNNG',
#  '깡철이\tNNG',
#  '꼬마 니콜라\tNNG',
#  '꽃보다 남자\tNNG',
#  '꽃피는 봄이 오면\tNNG',
#  '꾸뻬씨의 행복여행\tNNG',
#  '꾼\tNNG',
#  '꿀벌대소동\tNNG',
#  '꿈은 이루어진다\tNNG',
#  '끝까지 간다\tNNG',
#  '나, 다니엘 블레이크\tNNG',
#  '나는 갈매기\tNNG',
#  '나는 공무원이다\tNNG',
#  '나는 내일, 어제의 너와 만난다\tNNG',
#  '나는 비와 함께 간다\tNNG',
#  '나는 아빠다\tNNG',
#  '나는 왕이로소이다\tNNG',
#  '나는 전설이다\tNNG',
#  '나니아 연대기-사자,마녀 그리고 옷장\tNNG',
#  '나니아 연대기: 새벽 출정호의 항해\tNNG',
#  '나니아 연대기:캐스피언 왕자\tNNG',
#  '나두야 간다\tNNG',
#  '나랏말싸미\tNNG',
#  '나를 기억해\tNNG',
#  '나를 잊지 말아요\tNNG',
#  '나를 차버린 스파이\tNNG',
#  '나를 찾아줘\tNNG',
#  '나미야 잡화점의 기적\tNNG',
#  '나비효과\tNNG',
#  '나쁜 녀석들: 더 무비\tNNG',
#  '나쁜 녀석들: 포에버\tNNG',
#  '나우 유 씨 미 2\tNNG',
#  '나우 유 씨 미 : 마술사기단\tNNG',
#  '나의 PS 파트너\tNNG',
#  '나의 결혼원정기\tNNG',
#  '나의 독재자\tNNG',
#  '나의 사랑 나의 신부\tNNG',
#  '나의 소녀시대\tNNG',
#  '나의 절친 악당들\tNNG',
#  '나의 특별한 사랑이야기\tNNG',
#  '나의 특별한 형제\tNNG',
#  '나이브스 아웃\tNNG',
#  '나이트 플라이트\tNNG',
#  '나이트메어\tNNG',
#  '나인\tNNG',
#  '나인 야드 2\tNNG',
#  '나일 강의 죽음\tNNG',
#  '나잇&데이\tNNG',
#  '날 미치게하는 남자\tNNG',
#  '날, 보러와요\tNNG',
#  '날씨의 아이\tNNG',
#  '날아라 허동구\tNNG',
#  '남과 여\tNNG',
#  '남극일기\tNNG',
#  '남산의 부장들\tNNG',
#  '남영동1985\tNNG',
#  '남자가 사랑할 때\tNNG',
#  '남자사용설명서\tNNG',
#  '남쪽으로 튀어\tNNG',
#  '남한산성\tNNG',
#  '내 깡패 같은 애인\tNNG',
#  '내 남자의 로맨스\tNNG',
#  '내 머리 속의 지우개\tNNG',
#  '내 사랑\tNNG',
#  '내 사랑 내 곁에\tNNG',
#  '내 생애 가장 아름다운 일주일\tNNG',
#  '내 생애 최악의 남자\tNNG',
#  '내 심장을 쏴라\tNNG',
#  '내 아내의 모든 것\tNNG',
#  '내 여자친구를 소개합니다\tNNG',
#  '내 이름은 칸\tNNG',
#  '내가 살인범이다\tNNG',
#  '내가 숨쉬는 공기\tNNG',
#  '내가 죽던 날\tNNG',
#  '내니 다이어리\tNNG',
#  '내니맥피 2: 유모와마법소동\tNNG',
#  '내니맥피-우리 유모는 마법사\tNNG',
#  '내부자들\tNNG',
#  '내부자들: 디 오리지널\tNNG',
#  '내사랑 싸가지\tNNG',
#  '내셔널 트레져\tNNG',
#  '내셔널 트레져:비밀의 책\tNNG',
#  '내안의 그놈\tNNG',
#  '내일의 기억\tNNG',
#  '너는 내 운명\tNNG',
#  '너는 펫\tNNG',
#  '너의 결혼식\tNNG',
#  '너의 이름은.\tNNG',
#  '너의 췌장을 먹고 싶어\tNNG',
#  '널 기다리며\tNNG',
#  '넘버23\tNNG',
#  '넛잡 2\tNNG',
#  '넛잡: 땅콩 도둑들\tNNG',
#  '네버랜드를 찾아서\tNNG',
#  '네버엔딩 스토리\tNNG',
#  '넥스트\tNNG',
#  '노리개\tNNG',
#  '노무현입니다\tNNG',
#  '노미오와 줄리엣\tNNG',
#  '노바디\tNNG',
#  '노벰버 맨\tNNG',
#  '노브레싱\tNNG',
#  '노아\tNNG',
#  '노아의 방주: 남겨진 녀석들\tNNG',
#  '노예 12년\tNNG',
#  '노잉\tNNG',
#  '노크:낯선 자들의 방문\tNNG',
#  '노트북\tNNG',
#  '논스톱\tNNG',
#  '놉\tNNG',
#  '누가 그녀와 잤을까?\tNNG',
#  '누구나 비밀은 있다\tNNG',
#  '눈길\tNNG',
#  '눈먼자들의 도시\tNNG',
#  '눈물이 주룩주룩\tNNG',
#  '눈부신 날에\tNNG',
#  '눈에는 눈 이에는 이\tNNG',
#  '눈의 여왕\tNNG',
#  '눈의 여왕 2: 트롤의 마법거울\tNNG',
#  '눈의 여왕 3: 눈과 불의 마법대결\tNNG',
#  '눈의 여왕4\tNNG',
#  '눈의 여왕5: 스노우 프린세스와 미러랜드의 비밀\tNNG',
#  '뉴 문\tNNG',
#  '뉴 폴리스 스토리\tNNG',
#  '뉴욕은 언제나 사랑 중\tNNG',
#  '늑대사냥\tNNG',
#  '늑대소년\tNNG',
#  '늑대소년-확장판\tNNG',
#  '늑대아이\tNNG',
#  '늑대의 유혹\tNNG',
#  '니 부모 얼굴이 보고 싶다\tNNG',
#  '니드 포 스피드\tNNG',
#  '니코\tNNG',
#  '니코: 산타비행단의 모험\tNNG',
#  '닌자 어쌔신\tNNG',
#  '닌자거북이 TMNT\tNNG',
#  '닌자터틀\tNNG',
#  '닌자터틀 : 어둠의 히어로\tNNG',
#  '님스 아일랜드\tNNG',
#  '님아, 그 강을 건너지 마오\tNNG',
#  '님은 먼 곳에\tNNG',
#  '다만 악에서 구하소서\tNNG',
#  '다빈치 코드\tNNG',
#  '다세포소녀\tNNG',
#  '다운사이징\tNNG',
#  '다이 하드 4 : 죽어도 산다\tNNG',
#  '다이노 타임\tNNG',
#  '다이노소어 어드벤처 3D\tNNG',
#  '다이노소어 어드벤처 : 백악기 공룡대백과\tNNG',
#  '다이버전트\tNNG',
#  '다이버전트 시리즈: 얼리전트\tNNG',
#  '다이하드: 굿 데이 투 다이\tNNG',
#  '다찌마와리\tNNG',
#  '다크 나이트\tNNG',
#  '다크 나이트 라이즈\tNNG',
#  '다크 섀도우\tNNG',
#  '다크 워터스\tNNG',
#  '다크아워\tNNG',
#  '닥터 두리틀\tNNG',
#  '닥터 스트레인지\tNNG',
#  '닥터 스트레인지: 대혼돈의 멀티버스\tNNG',
#  '달마야, 서울 가자\tNNG',
#  '달빛궁궐\tNNG',
#  '달콤, 살벌한 연인\tNNG',
#  '달콤한 거짓말\tNNG',
#  '달콤한 인생\tNNG',
#  '담보\tNNG',
#  '당갈\tNNG',
#  '당신, 거기 있어줄래요\tNNG',
#  '당신이 사랑하는 동안에\tNNG',
#  '대니쉬 걸\tNNG',
#  '대립군\tNNG',
#  '대배우\tNNG',
#  '대장 김창수\tNNG',
#  '대한민국 1%\tNNG',
#  '대한이, 민국씨\tNNG',
#  '대호\tNNG',
#  '댄 인 러브\tNNG',
#  '댄서의 순정\tNNG',
#  '댄싱퀸\tNNG',
#  '더 건맨\tNNG',
#  '더 게임\tNNG',
#  '더 그레이\tNNG',
#  '더 기버: 기억전달자\tNNG',
#  '더 넌\tNNG',
#  '더 독\tNNG',
#  '더 레이븐\tNNG',
#  '더 로드\tNNG',
#  '더 리더: 책 읽어주는 남자\tNNG',
#  '더 박스\tNNG',
#  '더 배트맨\tNNG',
#  '더 버터플라이\tNNG',
#  '더 셰프\tNNG',
#  '더 수어사이드 스쿼드\tNNG',
#  '더 스파이\tNNG',
#  '더 시그널\tNNG',
#  '더 울버린\tNNG',
#  '더 울프 오브 월스트리트\tNNG',
#  '더 웹툰: 예고살인\tNNG',
#  '더 임파서블\tNNG',
#  '더 자이언트\tNNG',
#  '더 콘서트\tNNG',
#  '더 큐어\tNNG',
#  '더 킹\tNNG',
#  '더 테러 라이브\tNNG',
#  '더 테이블\tNNG',
#  '더 파이브\tNNG',
#  '더 퍼지\tNNG',
#  '더 페이버릿: 여왕의 여자\tNNG',
#  '더 포스트\tNNG',
#  '더 폰\tNNG',
#  '더 프레데터\tNNG',
#  '더블타겟\tNNG',
#  '덕구\tNNG',
#  '덕수리 5형제\tNNG',
#  '덕혜옹주\tNNG',
#  '덤 앤 더머 투\tNNG',
#  '덤보\tNNG',
#  '덩케르크\tNNG',
#  '데드풀\tNNG',
#  '데드풀 2\tNNG',
#  '데블\tNNG',
#  '데스 디파잉:어느 마술사의 사랑\tNNG',
#  '데스 레이스\tNNG',
#  '데스노트\tNNG',
#  '데스노트 : 라스트 네임\tNNG',
#  '데스노트 L: 새로운 시작\tNNG',
#  '데시벨\tNNG',
#  '데이브레이커스\tNNG',
#  '데이지\tNNG',
#  '데자뷰\tNNG',
#  '도가니\tNNG',
#  '도굴\tNNG',
#  '도둑들\tNNG',
#  '도라에몽 : 스탠 바이 미\tNNG',
#  '도레미파솔라시도\tNNG',
#  '도리를 찾아서\tNNG',
#  '도리화가\tNNG',
#  '도마뱀\tNNG',
#  '도어락\tNNG',
#  '도희야\tNNG',
#  '독수리 에디\tNNG',
#  '독전\tNNG',
#  '독전: 익스텐디드 컷\tNNG',
#  '돈\tNNG',
#  '돈 크라이 마미\tNNG',
#  '돈 텔 파파\tNNG',
#  '돈의 맛\tNNG',
#  '돌연변이\tNNG',
#  '동감\tNNG',
#  '동갑내기 과외하기 레슨 2\tNNG',
#  '동네사람들\tNNG',
#  '동주\tNNG',
#  '동창생\tNNG',
#  '동해물과 백두산이\tNNG',
#  '두 개의 달\tNNG',
#  '두 사람이다\tNNG',
#  '두 얼굴의 여친\tNNG',
#  '두 여자\tNNG',
#  '두근두근 내 인생\tNNG',
#  '두뇌유희프로젝트, 퍼즐\tNNG',
#  '두번할까요\tNNG',
#  '듄\tNNG',
#  '드라큘라: 전설의 시작\tNNG',
#  '드래곤 길들이기\tNNG',
#  '드래곤 길들이기 2\tNNG',
#  '드래곤 길들이기 3\tNNG',
#  '드래곤볼 에볼루션\tNNG',
#  '드래그 미 투 헬\tNNG',
#  '드리머\tNNG',
#  '드림 쏭\tNNG',
#  '드림걸즈\tNNG',
#  '들어는 봤니? 모건 부부\tNNG',
#  '디 아이2\tNNG',
#  '디바\tNNG',
#  '디센트\tNNG',
#  '디스 민즈 워\tNNG',
#  '디스터비아\tNNG',
#  '디스트릭트 9\tNNG',
#  '디어 에반 핸슨\tNNG',
#  '디어 존\tNNG',
#  '디워\tNNG',
#  '디파이언스\tNNG',
#  '디파티드\tNNG',
#  '딥\tNNG',
#  '딥워터 호라이즌\tNNG',
#  '또 하나의 약속\tNNG',
#  '똥파리\tNNG',
#  '뚝방전설\tNNG',
#  '뜨거운 것이 좋아\tNNG',
#  '뜨거운 피\tNNG',
#  '라 비 앙 로즈\tNNG',
#  '라듸오 데이즈\tNNG',
#  '라디오 스타\tNNG',
#  '라따뚜이\tNNG',
#  '라라랜드\tNNG',
#  '라스베가스에서만 생길 수 있는 일\tNNG',
#  '라스트 갓파더\tNNG',
#  '라스트 나잇\tNNG',
#  '라스트 미션\tNNG',
#  '라스트 사무라이\tNNG',
#  '라스트 에어벤더\tNNG',
#  '라스트 엑소시즘\tNNG',
#  '라스트 위치 헌터\tNNG',
#  '라스트 크리스마스\tNNG',
#  '라스트베가스\tNNG',
#  '라야와 마지막 드래곤\tNNG',
#  '라이어\tNNG',
#  '라이언\tNNG',
#  '라이온 킹\tNNG',
#  '라이트 아웃\tNNG',
#  '라이프\tNNG',
#  '라이프 오브 파이\tNNG',
#  '라파예트\tNNG',
#  '라푼젤\tNNG',
#  '락아웃: 익스트림미션\tNNG',
#  '람보 4 : 라스트 블러드\tNNG',
#  '람보 : 라스트 워\tNNG',
#  '랑종\tNNG',
#  '램페이지\tNNG',
#  '랭고\tNNG',
#  '러브 & 드럭스\tNNG',
#  '러브 & 트러블\tNNG',
#  '러브 라이브! 더 스쿨 아이돌 무비\tNNG',
#  '러브 액츄얼리\tNNG',
#  '러브 앤 프렌즈\tNNG',
#  '러브, 로지\tNNG',
#  '러브레터\tNNG',
#  '러브픽션\tNNG',
#  '러블리 본즈\tNNG',
#  '러빙 빈센트\tNNG',
#  '러시 : 더 라이벌\tNNG',
#  '러시 아워 3\tNNG',
#  '럭키\tNNG',
#  '럭키 넘버 슬레븐\tNNG',
#  '런\tNNG',
#  '런 올 나이트\tNNG',
#  '런닝맨\tNNG',
#  '런닝맨 : 풀룰루의 역습\tNNG',
#  '런던 해즈 폴른\tNNG',
#  '레고 닌자고 무비\tNNG',
#  '레고 무비\tNNG',
#  '레고 배트맨 무비\tNNG',
#  '레드\tNNG',
#  '레드 라이딩 후드\tNNG',
#  '레드 스패로\tNNG',
#  '레드 아이\tNNG',
#  '레드: 더 레전드\tNNG',
#  '레드슈즈\tNNG',
#  '레드카펫\tNNG',
#  '레디 플레이어 원\tNNG',
#  '레모니 스니켓의 위험한 대결\tNNG',
#  '레미제라블\tNNG',
#  '레버넌트: 죽음에서 돌아온 자\tNNG',
#  '레슬러\tNNG',
#  '레이\tNNG',
#  '레이디 버드\tNNG',
#  '레이디 인 더 워터\tNNG',
#  '레이크 하우스\tNNG',
#  '레전드\tNNG',
#  '레전드 오브 조로\tNNG',
#  '레전드 오브 타잔\tNNG',
#  '레지던트 이블 2-아포칼립스\tNNG',
#  '레지던트 이블 3 - 인류의 멸망\tNNG',
#  '레지던트 이블 4: 끝나지 않은 전쟁 3D\tNNG',
#  '레지던트 이블 5 : 최후의 심판\tNNG',
#  '레지던트 이블: 파멸의 날\tNNG',
#  '레터스 투 줄리엣\tNNG',
#  '렛 미 인\tNNG',
#  '령\tNNG',
#  '로건\tNNG',
#  '로그 원: 스타워즈 스토리\tNNG',
#  '로드 오브 워\tNNG',
#  '로렉스\tNNG',
#  '로마 위드 러브\tNNG',
#  '로마의 휴일\tNNG',
#  '로망스\tNNG',
#  '로맨틱 아일랜드\tNNG',
#  '로맨틱 크라운\tNNG',
#  '로맨틱 홀리데이\tNNG',
#  '로보캅\tNNG',
#  '로봇(애니)\tNNG',
#  '로봇, 소리\tNNG',
#  '로빈 후드\tNNG',
#  '로빈슨 가족\tNNG',
#  '로빈슨 크루소\tNNG',
#  '로스트 라이온즈\tNNG',
#  '로스트 시티\tNNG',
#  '로켓맨\tNNG',
#  '록키 발보아\tNNG',
#  '론 레인저\tNNG',
#  '론 서바이버\tNNG',
#  '롤러코스터\tNNG',
#  '롱 리브 더 킹: 목포 영웅\tNNG',
#  '롱 샷\tNNG',
#  '루돌프와 많이있어\tNNG',
#  '루시\tNNG',
#  '루시드 드림\tNNG',
#  '루카\tNNG',
#  '루퍼\tNNG',
#  '리딕\tNNG',
#  '리딕 - 헬리온 최후의 빛\tNNG',
#  '리멤버\tNNG',
#  '리미트리스\tNNG',
#  '리얼\tNNG',
#  '리얼 스틸\tNNG',
#  '리오\tNNG',
#  '리오 2\tNNG',
#  '리턴\tNNG',
#  '리틀 비버\tNNG',
#  '리틀 포레스트\tNNG',
#  '리핑 10개의 재앙\tNNG',
#  '링2(2005)\tNNG',
#  '링스 어드벤처\tNNG',
#  '링컨\tNNG',
#  '링컨 차를 타는 변호사\tNNG',
#  '링컨: 뱀파이어 헌터\tNNG',
#  '마강호텔\tNNG',
#  '마고리엄의 장난감 백화점\tNNG',
#  '마녀\tNNG',
#  '마녀(魔女) Part2. The Other One\tNNG',
#  '마다가스카\tNNG',
#  '마다가스카 2\tNNG',
#  '마다가스카3 : 이번엔 서커스다!\tNNG',
#  '마다가스카의 펭귄\tNNG',
#  '마담 뺑덕\tNNG',
#  '마담 프루스트의 비밀정원\tNNG',
#  '마당을 나온 암탉\tNNG',
#  '마더\tNNG',
#  '마루 밑 아리에티\tNNG',
#  '마린보이\tNNG',
#  '마마\tNNG',
#  '마법사의 제자\tNNG',
#  '마법에 걸린 사랑\tNNG',
#  '마법천자문: 대마왕의 부활을 막아라\tNNG',
#  '마션\tNNG',
#  '마스터\tNNG',
#  '마야\tNNG',
#  '마약왕\tNNG',
#  '마을금고 연쇄습격사건\tNNG',
#  '마음이...\tNNG',
#  '마음이2\tNNG',
#  '마이 뉴 파트너\tNNG',
#  '마이 리틀 자이언트\tNNG',
#  '마이 리틀 히어로\tNNG',
#  '마이 블랙 미니드레스\tNNG',
#  '마이 블루베리 나이츠\tNNG',
#  '마이 시스터즈 키퍼\tNNG',
#  '마이 웨이\tNNG',
#  '마이 캡틴 김대출\tNNG',
#  '마이 파더\tNNG',
#  '마이애미 바이스\tNNG',
#  '마이클 잭슨의 디스 이즈 잇\tNNG',
#  '마이클 클레이튼\tNNG',
#  '마이펫 오지\tNNG',
#  '마이펫의 이중생활\tNNG',
#  '마이펫의 이중생활 2\tNNG',
#  '마지막 4중주\tNNG',
#  '마지막 선물\tNNG',
#  '마파도\tNNG',
#  '마파도2\tNNG',
#  '만남의 광장\tNNG',
#  '만추\tNNG',
#  '말레피센트\tNNG',
#  '말레피센트 2\tNNG',
#  '말리와 나\tNNG',
#  '말모이\tNNG',
#  '말아톤\tNNG',
#  '말죽거리 잔혹사\tNNG',
#  '말할 수 없는 비밀\tNNG',
#  '맘마미아!\tNNG',
#  '맘마미아!2\tNNG',
#  '매그니피센트 7\tNNG',
#  '매드 맥스: 분노의 도로\tNNG',
#  '매직브러시\tNNG',
#  '매치 포인트\tNNG',
#  '매트릭스: 리저렉션\tNNG',
#  '맥스 페인\tNNG',
#  '맨 오브 스틸\tNNG',
#  '맨 온 렛지\tNNG',
#  '맨 온 파이어\tNNG',
#  '맨 인 더 다크\tNNG',
#  '맨 인 블랙 3\tNNG',
#  '맨 인 블랙: 인터내셔널\tNNG',
#  '맨 프롬 UNCLE\tNNG',
#  '맨발의 기봉이\tNNG',
#  '맨발의 꿈\tNNG',
#  '맨홀\tNNG',
#  '맹부삼천지교\tNNG',
#  '머니볼\tNNG',
#  '먹고 기도하고 사랑하라\tNNG',
#  '멋진 하루\tNNG',
#  '메가로돈\tNNG',
#  '메가마인드\tNNG',
#  '메리 포핀스 리턴즈\tNNG',
#  '메리다와 마법의 숲\tNNG',
#  '메리와 마녀의 꽃\tNNG',
#  '메신져 - 죽은자들의 경고\tNNG',
#  '메이즈 러너\tNNG',
#  '메이즈 러너: 데스 큐어\tNNG',
#  '메이즈 러너: 스코치 트라이얼\tNNG',
#  '메카닉\tNNG',
#  '메카닉: 리크루트\tNNG',
#  '명당\tNNG',
#  '명량\tNNG',
#  '명장\tNNG',
#  '명탐정 코난 : 수평선상의 음모\tNNG',
#  '명탐정 코난 : 이차원의 저격수\tNNG',
#  '명탐정 코난 : 제로의 집행인\tNNG',
#  '명탐정 코난 : 칠흑의 추적자\tNNG',
#  '명탐정 코난 : 침묵의 15분\tNNG',
#  '명탐정 코난 : 코난 실종사건 - 사상 최악의 이틀\tNNG',
#  '명탐정 코난 : 탐정들의 진혼가\tNNG',
#  '명탐정 코난 : 화염의 해바라기\tNNG',
#  '명탐정 코난: 11번째 스트라이커\tNNG',
#  '명탐정 코난: 감청의 권\tNNG',
#  '명탐정 코난: 비색의 탄환\tNNG',
#  '명탐정 코난: 순흑의 악몽\tNNG',
#  '명탐정 코난: 에피소드 원-작아진 명탐정\tNNG',
#  '명탐정 코난: 천공의 난파선\tNNG',
#  '명탐정 코난: 할로윈의 신부\tNNG',
#  '명탐정 코난:감벽의 관\tNNG',
#  '명탐정 코난:베이커가의 망령\tNNG',
#  '명탐정 코난:은빛 날개의 마술사\tNNG',
#  '명탐정 코난:전율의 악보\tNNG',
#  '명탐정 코난:진홍의 연가\tNNG',
#  '명탐정 피카츄\tNNG',
#  '모가디슈\tNNG',
#  '모노폴리\tNNG',
#  '모던보이\tNNG',
#  '모모와 다락방의 수상한 요괴들\tNNG',
#  '모범시민\tNNG',
#  '모비딕\tNNG',
#  '모비우스\tNNG',
#  '모아나\tNNG',
#  '모털 엔진\tNNG',
#  '목격자\tNNG',
#  '목소리의 형태\tNNG',
#  '목포는 항구다\tNNG',
#  '몬스터\tNNG',
#  '몬스터 vs 에이리언\tNNG',
#  '몬스터 대학교\tNNG',
#  '몬스터 패밀리\tNNG',
#  ...]

# %%
with open('c:/2nd_project/Data/new_user_dic_10.txt', 'w', encoding='utf8') as f:
    for item in new_user_dict:
        f.write("%s\n" % item)
