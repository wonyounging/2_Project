# %% [markdown]
# # 새로운 user_dic 만들기

# %%
import pandas as pd

# %%
new_user_dict = []

# %%
# 파일 경로
file_path = 'd:/2nd_project/Data/ner_tag_data.txt'

# 파일 열기
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

txts = []
# 파일 내용 줄 단위로 출력
for line in lines:
    txts.append(line.strip())

txts
# Out:
# ['0시\tNNG\tB_DT',
#  '1시\tNNG\tB_DT',
#  '2시\tNNG\tB_DT',
#  '3시\tNNG\tB_DT',
#  '4시\tNNG\tB_DT',
#  '5시\tNNG\tB_DT',
#  '6시\tNNG\tB_DT',
#  '7시\tNNG\tB_DT',
#  '8시\tNNG\tB_DT',
#  '9시\tNNG\tB_DT',
#  '10시\tNNG\tB_DT',
#  '11시\tNNG\tB_DT',
#  '12시\tNNG\tB_DT',
#  '13시\tNNG\tB_DT',
#  '14시\tNNG\tB_DT',
#  '15시\tNNG\tB_DT',
#  '16시\tNNG\tB_DT',
#  '17시\tNNG\tB_DT',
#  '18시\tNNG\tB_DT',
#  '19시\tNNG\tB_DT',
#  '20시\tNNG\tB_DT',
#  '21시\tNNG\tB_DT',
#  '22시\tNNG\tB_DT',
#  '23시\tNNG\tB_DT',
#  '24시\tNNG\tB_DT',
#  '0분\tNNG\tB_DT',
#  '1분\tNNG\tB_DT',
#  '2분\tNNG\tB_DT',
#  '3분\tNNG\tB_DT',
#  '4분\tNNG\tB_DT',
#  '5분\tNNG\tB_DT',
#  '6분\tNNG\tB_DT',
#  '7분\tNNG\tB_DT',
#  '8분\tNNG\tB_DT',
#  '9분\tNNG\tB_DT',
#  '10분\tNNG\tB_DT',
#  '11분\tNNG\tB_DT',
#  '12분\tNNG\tB_DT',
#  '13분\tNNG\tB_DT',
#  '14분\tNNG\tB_DT',
#  '15분\tNNG\tB_DT',
#  '16분\tNNG\tB_DT',
#  '17분\tNNG\tB_DT',
#  '18분\tNNG\tB_DT',
#  '19분\tNNG\tB_DT',
#  '20분\tNNG\tB_DT',
#  '21분\tNNG\tB_DT',
#  '22분\tNNG\tB_DT',
#  '23분\tNNG\tB_DT',
#  '24분\tNNG\tB_DT',
#  '25분\tNNG\tB_DT',
#  '26분\tNNG\tB_DT',
#  '27분\tNNG\tB_DT',
#  '28분\tNNG\tB_DT',
#  '29분\tNNG\tB_DT',
#  '30분\tNNG\tB_DT',
#  '31분\tNNG\tB_DT',
#  '32분\tNNG\tB_DT',
#  '33분\tNNG\tB_DT',
#  '34분\tNNG\tB_DT',
#  '35분\tNNG\tB_DT',
#  '36분\tNNG\tB_DT',
#  '37분\tNNG\tB_DT',
#  '38분\tNNG\tB_DT',
#  '39분\tNNG\tB_DT',
#  '40분\tNNG\tB_DT',
#  '41분\tNNG\tB_DT',
#  '42분\tNNG\tB_DT',
#  '43분\tNNG\tB_DT',
#  '44분\tNNG\tB_DT',
#  '45분\tNNG\tB_DT',
#  '46분\tNNG\tB_DT',
#  '47분\tNNG\tB_DT',
#  '48분\tNNG\tB_DT',
#  '49분\tNNG\tB_DT',
#  '50분\tNNG\tB_DT',
#  '51분\tNNG\tB_DT',
#  '52분\tNNG\tB_DT',
#  '53분\tNNG\tB_DT',
#  '54분\tNNG\tB_DT',
#  '55분\tNNG\tB_DT',
#  '56분\tNNG\tB_DT',
#  '57분\tNNG\tB_DT',
#  '58분\tNNG\tB_DT',
#  '59분\tNNG\tB_DT',
#  '60분\tNNG\tB_DT',
#  '1월\tNNG\tB_DT',
#  '2월\tNNG\tB_DT',
#  '3월\tNNG\tB_DT',
#  '4월\tNNG\tB_DT',
#  '5월\tNNG\tB_DT',
#  '6월\tNNG\tB_DT',
#  '7월\tNNG\tB_DT',
#  '8월\tNNG\tB_DT',
#  '9월\tNNG\tB_DT',
#  '10월\tNNG\tB_DT',
#  '11월\tNNG\tB_DT',
#  '12월\tNNG\tB_DT',
#  '1일\tNNG\tB_DT',
#  '2일\tNNG\tB_DT',
#  '3일\tNNG\tB_DT',
#  '4일\tNNG\tB_DT',
#  '5일\tNNG\tB_DT',
#  '6일\tNNG\tB_DT',
#  '7일\tNNG\tB_DT',
#  '8일\tNNG\tB_DT',
#  '9일\tNNG\tB_DT',
#  '10일\tNNG\tB_DT',
#  '11일\tNNG\tB_DT',
#  '12일\tNNG\tB_DT',
#  '13일\tNNG\tB_DT',
#  '14일\tNNG\tB_DT',
#  '15일\tNNG\tB_DT',
#  '16일\tNNG\tB_DT',
#  '17일\tNNG\tB_DT',
#  '18일\tNNG\tB_DT',
#  '19일\tNNG\tB_DT',
#  '20일\tNNG\tB_DT',
#  '21일\tNNG\tB_DT',
#  '22일\tNNG\tB_DT',
#  '23일\tNNG\tB_DT',
#  '24일\tNNG\tB_DT',
#  '25일\tNNG\tB_DT',
#  '26일\tNNG\tB_DT',
#  '27일\tNNG\tB_DT',
#  '28일\tNNG\tB_DT',
#  '29일\tNNG\tB_DT',
#  '30일\tNNG\tB_DT',
#  '31일\tNNG\tB_DT',
#  '월요일\tNNG\tB_DT',
#  '화요일\tNNG\tB_DT',
#  '수요일\tNNG\tB_DT',
#  '목요일\tNNG\tB_DT',
#  '금요일\tNNG\tB_DT',
#  '토요일\tNNG\tB_DT',
#  '일요일\tNNG\tB_DT',
#  '#살아있다\tNNG\tB_MOVIE',
#  '#아이엠히어\tNNG\tB_MOVIE',
#  '#위왓치유\tNNG\tB_MOVIE',
#  '...ing\tNNG\tB_MOVIE',
#  '0.0MHz\tNNG\tB_MOVIE',
#  '007 노 타임 투 다이\tNNG\tB_MOVIE',
#  '007 북경특급 2\tNNG\tB_MOVIE',
#  '007 스카이폴\tNNG\tB_MOVIE',
#  '007 스펙터\tNNG\tB_MOVIE',
#  '007 제2편 : 위기일발\tNNG\tB_MOVIE',
#  '007 카지노 로얄\tNNG\tB_MOVIE',
#  '007 퀀텀 오브 솔러스\tNNG\tB_MOVIE',
#  '007 퀀텀 오브 솔러스+굿 바이+뱅크 잡\tNNG\tB_MOVIE',
#  '007 퀀텀 오브 솔러스+굿 바이+순정만화\tNNG\tB_MOVIE',
#  '009 사이보그\tNNG\tB_MOVIE',
#  '10 미니츠 곤\tNNG\tB_MOVIE',
#  '10 바이 10\tNNG\tB_MOVIE',
#  '10 아이템 오어 레스\tNNG\tB_MOVIE',
#  '10,000 BC\tNNG\tB_MOVIE',
#  '10,000 BC + 어메이징 그레이스 + 댄 인 러브\tNNG\tB_MOVIE',
#  '10,000BC+마이 블루베리 나이츠+연을 쫓는 아이\tNNG\tB_MOVIE',
#  '10,000BC+연을 쫓는 아이+마이 블루베리 나이츠\tNNG\tB_MOVIE',
#  '10,000km(만 킬로미터)\tNNG\tB_MOVIE',
#  '100 피트\tNNG\tB_MOVIE',
#  '100% 울프: 푸들이 될 순 없어\tNNG\tB_MOVIE',
#  '1000 : 최후의 전사들\tNNG\tB_MOVIE',
#  '100년 동안의 히틀러\tNNG\tB_MOVIE',
#  '100미터\tNNG\tB_MOVIE',
#  '100일 동안 100가지로 100퍼센트 행복찾기\tNNG\tB_MOVIE',
#  '10년\tNNG\tB_MOVIE',
#  '10분\tNNG\tB_MOVIE',
#  '10억\tNNG\tB_MOVIE',
#  '10일간의 원나잇 스탠드\tNNG\tB_MOVIE',
#  '10층의 모기\tNNG\tB_MOVIE',
#  '117편의 러브레터\tNNG\tB_MOVIE',
#  '11월 실험영화 정기 상영회\tNNG\tB_MOVIE',
#  '11인의 카우보이\tNNG\tB_MOVIE',
#  '12 솔져스\tNNG\tB_MOVIE',
#  '120 BPM\tNNG\tB_MOVIE',
#  '125 전승철\tNNG\tB_MOVIE',
#  '127시간\tNNG\tB_MOVIE',
#  '12번째 솔저\tNNG\tB_MOVIE',
#  '12시에 열리는 쾌락의 문\tNNG\tB_MOVIE',
#  '12월실험영화상영회-야수토 유라 특별전\tNNG\tB_MOVIE',
#  '12인의 하숙생\tNNG\tB_MOVIE',
#  '12피트\tNNG\tB_MOVIE',
#  '13 이어리\tNNG\tB_MOVIE',
#  '13 자메티\tNNG\tB_MOVIE',
#  '13구역\tNNG\tB_MOVIE',
#  '13구역: 얼티메이텀\tNNG\tB_MOVIE',
#  '13년의 공백\tNNG\tB_MOVIE',
#  '13번째 전사\tNNG\tB_MOVIE',
#  '13시간\tNNG\tB_MOVIE',
#  '13인의 자객\tNNG\tB_MOVIE',
#  '13일의 금요일\tNNG\tB_MOVIE',
#  '13일의 금요일: 더 파이널\tNNG\tB_MOVIE',
#  '1408\tNNG\tB_MOVIE',
#  '1492 콜럼버스\tNNG\tB_MOVIE',
#  '14인의 여걸\tNNG\tB_MOVIE',
#  '15소년 우주 표류기\tNNG\tB_MOVIE',
#  '15소년 표류기: 해적섬을 탈출하라\tNNG\tB_MOVIE',
#  '16세의 사운드트랙\tNNG\tB_MOVIE',
#  '1724 기방난동사건\tNNG\tB_MOVIE',
#  '17인의사자들\tNNG\tB_MOVIE',
#  '18 BJ 하연의 화려한 테크닉\tNNG\tB_MOVIE',
#  '18 걸그룹 승하의 눈치게임\tNNG\tB_MOVIE',
#  '18 모델 리카의 화려한 외출\tNNG\tB_MOVIE',
#  '18 성인배우 이수의 섹스 판타지\tNNG\tB_MOVIE',
#  '18 섹시퀸 유진의 섹스 스캔들\tNNG\tB_MOVIE',
#  '18 승하의 누워서 떡 먹기\tNNG\tB_MOVIE',
#  '18 여대생 소라의 순결상실\tNNG\tB_MOVIE',
#  '18 주아의 뜨거운 하루\tNNG\tB_MOVIE',
#  '18 출사녀 화진의 미친 섹스\tNNG\tB_MOVIE',
#  '18 하라의 맛있는 수업\tNNG\tB_MOVIE',
#  '1812 나폴레옹 대전투\tNNG\tB_MOVIE',
#  '1820: 잃어버린 제국의 비밀\tNNG\tB_MOVIE',
#  '1850 길로틴 트레지디\tNNG\tB_MOVIE',
#  '18: 우리들의 성장 느와르\tNNG\tB_MOVIE',
#  '18금 아이돌 승하의 섹스 스캔들\tNNG\tB_MOVIE',
#  '18금 아이돌 승하의 화려한 외출\tNNG\tB_MOVIE',
#  '19 섹스 맛있는 속 궁합\tNNG\tB_MOVIE',
#  '19-Nineteen\tNNG\tB_MOVIE',
#  '1900년\tNNG\tB_MOVIE',
#  '1917\tNNG\tB_MOVIE',
#  '1919 유관순\tNNG\tB_MOVIE',
#  '1940: 최강의 독일 전차부대\tNNG\tB_MOVIE',
#  '1941\tNNG\tB_MOVIE',
#  '1941: 세바스토폴 상륙작전\tNNG\tB_MOVIE',
#  '1942: 언노운 배틀\tNNG\tB_MOVIE',
#  '1942: 최정예특수부대 스페츠나츠\tNNG\tB_MOVIE',
#  '1944\tNNG\tB_MOVIE',
#  '1944 대전투\tNNG\tB_MOVIE',
#  '1944 워 히어로\tNNG\tB_MOVIE',
#  '1944: 인간병기\tNNG\tB_MOVIE',
#  '1945 그레이트 워\tNNG\tB_MOVIE',
#  '1945: 포인트 오브 노 리턴\tNNG\tB_MOVIE',
#  '1975 킬링필드, 푸난\tNNG\tB_MOVIE',
#  '1984 최동원\tNNG\tB_MOVIE',
#  '1987\tNNG\tB_MOVIE',
#  '1991, 봄\tNNG\tB_MOVIE',
#  '1999, 면회\tNNG\tB_MOVIE',
#  '19곰 테드\tNNG\tB_MOVIE',
#  '19곰 테드 2\tNNG\tB_MOVIE',
#  '19금 만남의 목적\tNNG\tB_MOVIE',
#  '19금 불륜소설\tNNG\tB_MOVIE',
#  '19금 불륜소설 무삭제판\tNNG\tB_MOVIE',
#  '19금 비밀과외\tNNG\tB_MOVIE',
#  '19금 섹스비디오\tNNG\tB_MOVIE',
#  '19금 섹스비디오 무삭제 감독판\tNNG\tB_MOVIE',
#  '19금 섹스의 늪 무삭특별판\tNNG\tB_MOVIE',
#  '19금 연애소설\tNNG\tB_MOVIE',
#  '19금 연애소설 무삭제판\tNNG\tB_MOVIE',
#  '19금 절대섹스\tNNG\tB_MOVIE',
#  '19금 정사: 말할 수 없는 비밀\tNNG\tB_MOVIE',
#  '19금 특별한 정사\tNNG\tB_MOVIE',
#  '19금 특별한 정사 무삭제 특별판\tNNG\tB_MOVIE',
#  '19번가물많은여자친구\tNNG\tB_MOVIE',
#  '1급기밀\tNNG\tB_MOVIE',
#  '1박2일 소개팅\tNNG\tB_MOVIE',
#  '1번가의 기적\tNNG\tB_MOVIE',
#  '1번국도\tNNG\tB_MOVIE',
#  '1월 단편 상상극장\tNNG\tB_MOVIE',
#  '1월의 두 얼굴\tNNG\tB_MOVIE',
#  '2 데이즈 인 뉴욕\tNNG\tB_MOVIE',
#  '2%필름페스티발\tNNG\tB_MOVIE',
#  '20 30 40\tNNG\tB_MOVIE',
#  '2007 시네바캉스 서울\tNNG\tB_MOVIE',
#  '2007 아시아나국제단편영화제\tNNG\tB_MOVIE',
#  '2007 인디애니페스트\tNNG\tB_MOVIE',
#  '2007 칸국제광고제 수상작 필름 페스티벌\tNNG\tB_MOVIE',
#  '2007CJ중국영화제\tNNG\tB_MOVIE',
#  '2008 광주국제영화제\tNNG\tB_MOVIE',
#  '2008 음악 영화제\tNNG\tB_MOVIE',
#  '2008 최강애니전\tNNG\tB_MOVIE',
#  '2008년 시네마테크의 친구들 영화제\tNNG\tB_MOVIE',
#  '2010 3D한국국제영화제\tNNG\tB_MOVIE',
#  '2010 AISFF-개막식\tNNG\tB_MOVIE',
#  '2010 AISFF-거장들의 패션필름\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁1\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁2\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁3\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁4\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁5\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁6\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁7\tNNG\tB_MOVIE',
#  '2010 AISFF-국제경쟁8\tNNG\tB_MOVIE',
#  '2010 AISFF-메이드 바이 커머셜 디렉터스\tNNG\tB_MOVIE',
#  '2010 AISFF-시상식\tNNG\tB_MOVIE',
#  '2010 AISFF-여자는 두 번 플레이 한다\tNNG\tB_MOVIE',
#  '2010 AISFF-트래블링 쇼츠 인 저팬\tNNG\tB_MOVIE',
#  '2010 AISFF-트래블링 쇼츠 인 코리아\tNNG\tB_MOVIE',
#  '2010 시네바캉스 서울\tNNG\tB_MOVIE',
#  '2010 한-EU단편영화 교류전\tNNG\tB_MOVIE',
#  '2010 한국영화아카데미 영화제\tNNG\tB_MOVIE',
#  '2010년 시네마테크의 친구들 영화제\tNNG\tB_MOVIE',
#  '2010칸국제광고제 수상작페스티벌\tNNG\tB_MOVIE',
#  '2012\tNNG\tB_MOVIE',
#  '2014 지구 최후의 날\tNNG\tB_MOVIE',
#  '2017 동명이인 프로젝트\tNNG\tB_MOVIE',
#  '2017복상사\tNNG\tB_MOVIE',
#  '2020년 마지막 섹스\tNNG\tB_MOVIE',
#  '2021 첫 섹스\tNNG\tB_MOVIE',
#  '2023-09-11 00:00:00\tNNG\tB_MOVIE',
#  '2025 지구전쟁: 얼리전스 오브 파워\tNNG\tB_MOVIE',
#  '2035 매드 레이스\tNNG\tB_MOVIE',
#  '2046\tNNG\tB_MOVIE',
#  '2047 버추얼 레볼루션\tNNG\tB_MOVIE',
#  '2047: 지구 최후의 날\tNNG\tB_MOVIE',
#  '2067\tNNG\tB_MOVIE',
#  '20대 같은 40대 미시녀\tNNG\tB_MOVIE',
#  '20세기 소년\tNNG\tB_MOVIE',
#  '20세기 소년 ; 최종장 - 우리들의 깃발\tNNG\tB_MOVIE',
#  '20세기 소년+맘마미아+방콕 데인저러스\tNNG\tB_MOVIE',
#  '20세기 소년-제2장: 마지막 희망\tNNG\tB_MOVIE',
#  '20일밤, 그리고 비 오는 하루\tNNG\tB_MOVIE',
#  '21\tNNG\tB_MOVIE',
#  '21 그램\tNNG\tB_MOVIE',
#  '21 브릿지: 테러 셧다운\tNNG\tB_MOVIE',
#  '21 앤드 오버\tNNG\tB_MOVIE',
#  '21살승하의아이돌비밀일기\tNNG\tB_MOVIE',
#  '21살승하의아이돌비밀일기-무삭제\tNNG\tB_MOVIE',
#  '21세기 우리 시대의 영화 특별전\tNNG\tB_MOVIE',
#  '21세기의 기원\tNNG\tB_MOVIE',
#  '22\tNNG\tB_MOVIE',
#  '22 블렛\tNNG\tB_MOVIE',
#  '22년 후의 고백\tNNG\tB_MOVIE',
#  '22분: 아덴만 구출작전\tNNG\tB_MOVIE',
#  '23 아이덴티티\tNNG\tB_MOVIE',
#  '24 시티\tNNG\tB_MOVIE',
#  '24살윤율의섹시한젖가슴\tNNG\tB_MOVIE',
#  '24살윤율의섹시한젖가슴-무삭제\tNNG\tB_MOVIE',
#  '24시간 달리는 쾌락 버스\tNNG\tB_MOVIE',
#  '24주\tNNG\tB_MOVIE',
#  '25시\tNNG\tB_MOVIE',
#  '26년\tNNG\tB_MOVIE',
#  '27번의 결혼리허설\tNNG\tB_MOVIE',
#  '27번의 결혼리허설 + 마이 뉴 파트너 + 마이 블루베리 나이츠\tNNG\tB_MOVIE',
#  '27번의 결혼리허설+10,000BC+밴티지 포인트\tNNG\tB_MOVIE',
#  '28세 미성년\tNNG\tB_MOVIE',
#  '28일 후\tNNG\tB_MOVIE',
#  '2솔져스: 배틀필드\tNNG\tB_MOVIE',
#  '2월 29일 - 어느날 갑자기 첫번째 이야기\tNNG\tB_MOVIE',
#  '2차 노출\tNNG\tB_MOVIE',
#  '2차 세계대전 타임트랙\tNNG\tB_MOVIE',
#  '2차 송환\tNNG\tB_MOVIE',
#  '2회 브라질 영화제: 시네마 노보 회고전\tNNG\tB_MOVIE',
#  '3-4X10월\tNNG\tB_MOVIE',
#  '3.5교시\tNNG\tB_MOVIE',
#  '300\tNNG\tB_MOVIE',
#  '300: 전사의 귀환\tNNG\tB_MOVIE',
#  '300: 제국의 부활\tNNG\tB_MOVIE',
#  '301, 302\tNNG\tB_MOVIE',
#  '3022: 지구 대폭발\tNNG\tB_MOVIE',
#  '3096일\tNNG\tB_MOVIE',
#  '30년만의 대결\tNNG\tB_MOVIE',
#  '33\tNNG\tB_MOVIE',
#  '33리\tNNG\tB_MOVIE',
#  '355\tNNG\tB_MOVIE',
#  '365일: 비밀의 여자\tNNG\tB_MOVIE',
#  '3:10 투 유마\tNNG\tB_MOVIE',
#  '3:10 투 유마 + 주노 + 어톤먼트\tNNG\tB_MOVIE',
#  '3xFTM\tNNG\tB_MOVIE',
#  '3개의 얼굴들\tNNG\tB_MOVIE',
#  '3데이즈: 라스트 서바이벌\tNNG\tB_MOVIE',
#  '3류들의 사랑\tNNG\tB_MOVIE',
#  '3분 파트너\tNNG\tB_MOVIE',
#  '3분 파트너-무삭제\tNNG\tB_MOVIE',
#  '3인3색 여성감독 특별전\tNNG\tB_MOVIE',
#  '3인의 사기단: 진범을 찾아라\tNNG\tB_MOVIE',
#  '3인조\tNNG\tB_MOVIE',
#  '4 브라더스\tNNG\tB_MOVIE',
#  '4.4.4\tNNG\tB_MOVIE',
#  '400 데이즈\tNNG\tB_MOVIE',
#  '400: 제국의 부활\tNNG\tB_MOVIE',
#  '400번의 구타\tNNG\tB_MOVIE',
#  '40살까지 못해본 사람\tNNG\tB_MOVIE',
#  '438일\tNNG\tB_MOVIE',
#  '45년 후\tNNG\tB_MOVIE',
#  '47 미터\tNNG\tB_MOVIE',
#  '47미터 2\tNNG\tB_MOVIE',
#  '48미터\tNNG\tB_MOVIE',
#  '48시간: 지구 최후의 날\tNNG\tB_MOVIE',
#  '4DX 문유\tNNG\tB_MOVIE',
#  '4개월, 3주... 그리고 2일\tNNG\tB_MOVIE',
#  '4교시 추리영역\tNNG\tB_MOVIE',
#  '4등\tNNG\tB_MOVIE',
#  '4명의 암살자\tNNG\tB_MOVIE',
#  '4요일: 자살을 부르는 요일\tNNG\tB_MOVIE',
#  '4월 실험영화 정기상영회\tNNG\tB_MOVIE',
#  '4월 이야기\tNNG\tB_MOVIE',
#  '4월은 너의 거짓말\tNNG\tB_MOVIE',
#  '4인용 식탁\tNNG\tB_MOVIE',
#  '4인의 무뢰한\tNNG\tB_MOVIE',
#  '5 데이즈 오브 워\tNNG\tB_MOVIE',
#  '5 투 7\tNNG\tB_MOVIE',
#  '5.18 힌츠페터 스토리\tNNG\tB_MOVIE',
#  '50/50\tNNG\tB_MOVIE',
#  '500일의 썸머\tNNG\tB_MOVIE',
#  '500일의 썸머+들어는 봤니? 모건 부부+의형제\tNNG\tB_MOVIE',
#  '500일의 썸머+들어는봤니? 모건 부부+하모니\tNNG\tB_MOVIE',
#  '500일의 썸머+용서는 없다+주유소 습격사건2\tNNG\tB_MOVIE',
#  '50가지 그림자: 심연\tNNG\tB_MOVIE',
#  '50가지 그림자: 해방\tNNG\tB_MOVIE',
#  '50가지 욕망의 그림자\tNNG\tB_MOVIE',
#  '50대 장모님의 불타는 사위사랑\tNNG\tB_MOVIE',
#  '51구역\tNNG\tB_MOVIE',
#  '577 프로젝트\tNNG\tB_MOVIE',
#  '5x2\tNNG\tB_MOVIE',
#  '5백만불의 사나이\tNNG\tB_MOVIE',
#  '5분 운동 30분 섹스\tNNG\tB_MOVIE',
#  '5월 1일\tNNG\tB_MOVIE',
#  '5월 실험영화 정기상영회-브루스 엘더\tNNG\tB_MOVIE',
#  '5월의 구름\tNNG\tB_MOVIE',
#  '5일의 마중\tNNG\tB_MOVIE',
#  '5쿼터\tNNG\tB_MOVIE',
#  '6 웨이 투 다이\tNNG\tB_MOVIE',
#  '600 마일\tNNG\tB_MOVIE',
#  '60년전, 사선에서\tNNG\tB_MOVIE',
#  '60만번의 트라이\tNNG\tB_MOVIE',
#  '60일의 썸머\tNNG\tB_MOVIE',
#  '69 식스티 나인\tNNG\tB_MOVIE',
#  '69번가육덕진가정교사\tNNG\tB_MOVIE',
#  '69세\tNNG\tB_MOVIE',
#  '6년째 연애중\tNNG\tB_MOVIE',
#  '6솔져스\tNNG\tB_MOVIE',
#  '6시간: 원전대폭발\tNNG\tB_MOVIE',
#  '6월 독립애니메이션 정기상영회-밥 좀 먹자,잠 좀 자자\tNNG\tB_MOVIE',
#  '6월 실험영화 정기상영회-칼 브라운-감각의 응축\tNNG\tB_MOVIE',
#  '6월의 뱀\tNNG\tB_MOVIE',
#  '6월의 일기\tNNG\tB_MOVIE',
#  '71 : 벨파스트의 눈물\tNNG\tB_MOVIE',
#  '7공주 대리운전\tNNG\tB_MOVIE',
#  '7광구\tNNG\tB_MOVIE',
#  '7급 공무원\tNNG\tB_MOVIE',
#  '7년-그들이 없는 언론\tNNG\tB_MOVIE',
#  '7년의 밤\tNNG\tB_MOVIE',
#  '7번방의 선물\tNNG\tB_MOVIE',
#  '7번째 내가 죽던 날\tNNG\tB_MOVIE',
#  '7번째 아들\tNNG\tB_MOVIE',
#  '7월 32일\tNNG\tB_MOVIE',
#  '7월7일\tNNG\tB_MOVIE',
#  '7인의 말괄량이\tNNG\tB_MOVIE',
#  '7인의 신부\tNNG\tB_MOVIE',
#  '7인의 악인전\tNNG\tB_MOVIE',
#  '7호실\tNNG\tB_MOVIE',
#  '8 마일\tNNG\tB_MOVIE',
#  '800\tNNG\tB_MOVIE',
#  '800 블렛\tNNG\tB_MOVIE',
#  '80일간의 세계 일주\tNNG\tB_MOVIE',
#  '82년생 김지영\tNNG\tB_MOVIE',
#  '84 태권 V\tNNG\tB_MOVIE',
#  '88분\tNNG\tB_MOVIE',
#  '8광구: 몬스터의 부활\tNNG\tB_MOVIE',
#  '8년 전쟁: 이란 vs 이라크\tNNG\tB_MOVIE',
#  '8년을 뛰어넘은 신부\tNNG\tB_MOVIE',
#  '8명의 여인들\tNNG\tB_MOVIE',
#  '8월 실험영화정기상영회-타수아오키\tNNG\tB_MOVIE',
#  '8월의 일요일들\tNNG\tB_MOVIE',
#  '8월의 크리스마스\tNNG\tB_MOVIE',
#  '8월의 크리스마스(일본판)\tNNG\tB_MOVIE',
#  '8인: 최후의 결사단\tNNG\tB_MOVIE',
#  '8인의 수상한 신사들\tNNG\tB_MOVIE',
#  '90분\tNNG\tB_MOVIE',
#  '9:나인\tNNG\tB_MOVIE',
#  '9명의 번역가\tNNG\tB_MOVIE',
#  '9월 실험영화정기상영회\tNNG\tB_MOVIE',
#  '9월의 어느날\tNNG\tB_MOVIE',
#  'A 계획 속집\tNNG\tB_MOVIE',
#  'A-특공대\tNNG\tB_MOVIE',
#  'A-특공대+베스트 키드+유령작가\tNNG\tB_MOVIE',
#  'A.I.\tNNG\tB_MOVIE',
#  'AISFF 프로그램1\tNNG\tB_MOVIE',
#  'AISFF 프로그램2\tNNG\tB_MOVIE',
#  'AISFF 프로그램3\tNNG\tB_MOVIE',
#  'AS센터 대신맨\tNNG\tB_MOVIE',
#  'AV 아이돌\tNNG\tB_MOVIE',
#  'AV 아이돌 일본제일전 도전기\tNNG\tB_MOVIE',
#  'AV 여배우의 직장 체험기\tNNG\tB_MOVIE',
#  'AV스타: 과거를 지워주세요\tNNG\tB_MOVIE',
#  'AV스타납치사건\tNNG\tB_MOVIE',
#  'AV스타의 질펀한 실습\tNNG\tB_MOVIE',
#  'AV제작사의 여직원\tNNG\tB_MOVIE',
#  'A형젖큰여자친구\tNNG\tB_MOVIE',
#  'BB프로젝트\tNNG\tB_MOVIE',
#  'BJ노는이모\tNNG\tB_MOVIE',
#  'BJ노는이모2\tNNG\tB_MOVIE',
#  'B급 며느리\tNNG\tB_MOVIE',
#  'B급 청춘\tNNG\tB_MOVIE',
#  'B컷\tNNG\tB_MOVIE',
#  'B형 남자친구\tNNG\tB_MOVIE',
#  'B형물많고화끈한처제\tNNG\tB_MOVIE',
#  'B형물많고화끈한처제-무삭제\tNNG\tB_MOVIE',
#  'C+ 탐정\tNNG\tB_MOVIE',
#  'CCTV\tNNG\tB_MOVIE',
#  'CJ7:장강7호\tNNG\tB_MOVIE',
#  'CQN 한국영화앵콜전\tNNG\tB_MOVIE',
#  'CQN 할로윈 무비 파티\tNNG\tB_MOVIE',
#  'D-day-어느날 갑자기 세번째 이야기\tNNG\tB_MOVIE',
#  'DC 리그 오브 슈퍼-펫\tNNG\tB_MOVIE',
#  'DMZ, 비무장지대\tNNG\tB_MOVIE',
#  'DOA\tNNG\tB_MOVIE',
#  'D컵 여형사-가슴으로 느껴져요\tNNG\tB_MOVIE',
#  'D컵여자친구\tNNG\tB_MOVIE',
#  'D컵여자친구-무삭제\tNNG\tB_MOVIE',
#  'EBS친구들 씽씽 댄스파티\tNNG\tB_MOVIE',
#  'EIDF-다큐멘터리 정신상 수상작\tNNG\tB_MOVIE',
#  'EIDF-대상수상작\tNNG\tB_MOVIE',
#  'EIDF-시청자상 수상작\tNNG\tB_MOVIE',
#  'EIDF-심사위원 특별상 수상작\tNNG\tB_MOVIE',
#  'EX-Choice 1 소_극\tNNG\tB_MOVIE',
#  'EX-Choice 2 비_극\tNNG\tB_MOVIE',
#  'EX-Choice 3 소비극\tNNG\tB_MOVIE',
#  'EX-Choice 4 선택극\tNNG\tB_MOVIE',
#  'EX-Live 1-무비 콘서트 III\tNNG\tB_MOVIE',
#  'EX-Live 2 존 케이지 스페셜 : 퍼포먼스\tNNG\tB_MOVIE',
#  'EX-Now 경쟁 1\tNNG\tB_MOVIE',
#  'EX-Now 경쟁 2\tNNG\tB_MOVIE',
#  'EX-Now 경쟁 4\tNNG\tB_MOVIE',
#  'EX-Now 경쟁 5\tNNG\tB_MOVIE',
#  'EX-Now 경쟁 6\tNNG\tB_MOVIE',
#  'EX-Retro 에비게일 차일드 1\tNNG\tB_MOVIE',
#  'EX-Retro 에비게일 차일드 2\tNNG\tB_MOVIE',
#  'EX-Retro 에비게일 차일드 3\tNNG\tB_MOVIE',
#  'F.O.E.: 에프.오.이.\tNNG\tB_MOVIE',
#  'F20\tNNG\tB_MOVIE',
#  'FBI 데스트랩\tNNG\tB_MOVIE',
#  'Full Moon day 씨네큐브 영화축제\tNNG\tB_MOVIE',
#  'F컵 거유녀의 이중 생활: 매춘\tNNG\tB_MOVIE',
#  'F컵 거유녀의 잠입 수사\tNNG\tB_MOVIE',
#  'F컵 거유의 육덕녀\tNNG\tB_MOVIE',
#  'F컵 거유의 육덕녀 무삭제판\tNNG\tB_MOVIE',
#  'F컵 옆집 부인의 질펀한 하루\tNNG\tB_MOVIE',
#  'G-포스: 기니피그 특공대\tNNG\tB_MOVIE',
#  'GP 506\tNNG\tB_MOVIE',
#  'GROW: 인피니트의 리얼 청춘 라이프\tNNG\tB_MOVIE',
#  'G컵 새 엄마:달아오른 날\tNNG\tB_MOVIE',
#  'H2: 어느 살인마의 가족이야기\tNNG\tB_MOVIE',
#  'H컵 이상 거유 여배우\tNNG\tB_MOVIE',
#  'I AM\tNNG\tB_MOVIE',
#  'IS 탈출\tNNG\tB_MOVIE',
#  'Indi-Visual 제이 로젠블라트 1\tNNG\tB_MOVIE',
#  'Indi-Visual 제이 로젠블라트 2\tNNG\tB_MOVIE',
#  'Indi-Visual 진 리오타\tNNG\tB_MOVIE',
#  'J-무비페스티벌 (버라이어티 나인 J - 무비페스티벌)\tNNG\tB_MOVIE',
#  'JLG/JLG 고다르의 자화상 특별전-사랑의 찬가\tNNG\tB_MOVIE',
#  'JSA 남북공동초등학교\tNNG\tB_MOVIE',
#  'Jam Docu 강정\tNNG\tB_MOVIE',
#  'K 미싱 킹즈\tNNG\tB_MOVIE',
#  'K-19\tNNG\tB_MOVIE',
#  'K-20 괴도가면\tNNG\tB_MOVIE',
#  'K2\tNNG\tB_MOVIE',
#  'KBS 프리미어 영화 페스티벌\tNNG\tB_MOVIE',
#  'K클래식 제너레이션\tNNG\tB_MOVIE',
#  'LA 대지진\tNNG\tB_MOVIE',
#  'LA: 볼케이노칼립스\tNNG\tB_MOVIE',
#  'Lab Program 1\tNNG\tB_MOVIE',
#  'Lab Program 2\tNNG\tB_MOVIE',
#  'Lab Program 3\tNNG\tB_MOVIE',
#  'M 버터 플라이\tNNG\tB_MOVIE',
#  'MB의 추억\tNNG\tB_MOVIE',
#  'MR. 후아유\tNNG\tB_MOVIE',
#  'Mr.로빈 꼬시기\tNNG\tB_MOVIE',
#  'Mr.스타벅\tNNG\tB_MOVIE',
#  'Mr.아이돌\tNNG\tB_MOVIE',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG\tB_MOVIE',
#  'NCN Cinema 특별전\tNNG\tB_MOVIE',
#  'O.J. 심슨 사건 파일\tNNG\tB_MOVIE',
#  'OL의 성\tNNG\tB_MOVIE',
#  'O형수박가슴가정부\tNNG\tB_MOVIE',
#  'O형수박가슴가정부-무삭제\tNNG\tB_MOVIE',
#  'P.S 온리 유\tNNG\tB_MOVIE',
#  'P.S. 걸\tNNG\tB_MOVIE',
#  'P.S. 걸 무삭제\tNNG\tB_MOVIE',
#  'P.S. 아이 러브 유\tNNG\tB_MOVIE',
#  'PMC: 더 벙커\tNNG\tB_MOVIE',
#  'R.I.P.D. : 알.아이.피.디.\tNNG\tB_MOVIE',
#  'R2B: 리턴투베이스\tNNG\tB_MOVIE',
#  'REC 알이씨\tNNG\tB_MOVIE',
#  'S 다이어리\tNNG\tB_MOVIE',
#  'S 중독자의 고백\tNNG\tB_MOVIE',
#  'SICAF2007서울국제만화애니페스티벌\tNNG\tB_MOVIE',
#  'SIFF2008_다큐멘터리 특별초청\tNNG\tB_MOVIE',
#  'SIFF2008_해외초청1\tNNG\tB_MOVIE',
#  'SIFF2008_해외초청2\tNNG\tB_MOVIE',
#  'SIFF2008_해외초청3\tNNG\tB_MOVIE',
#  'SIFF2008_해외초청4\tNNG\tB_MOVIE',
#  'SM_음탕한 욕망\tNNG\tB_MOVIE',
#  'SM작가\tNNG\tB_MOVIE',
#  'SNS 러브\tNNG\tB_MOVIE',
#  'SNS 불륜 집착 유부녀\tNNG\tB_MOVIE',
#  'SX 테잎\tNNG\tB_MOVIE',
#  'S걸의 덫\tNNG\tB_MOVIE',
#  'S러버\tNNG\tB_MOVIE',
#  'T-34\tNNG\tB_MOVIE',
#  'U.F.O.\tNNG\tB_MOVIE',
#  'UFO 스케치\tNNG\tB_MOVIE',
#  'V/H/S/2: 악마를 부르는 비디오\tNNG\tB_MOVIE',
#  'V/H/S:죽음을 부르는 비디오\tNNG\tB_MOVIE',
#  'VJ의 은밀한 사생활\tNNG\tB_MOVIE',
#  '[EIDF2011]마리아가 사는 방법+태양 아래 흐르는 소리\tNNG\tB_MOVIE',
#  '[EIDF2011]비바 마리아+사운드 라이트 레볼루션\tNNG\tB_MOVIE',
#  '[EIDF2011]펠란케의 사람들+잔인한 계절\tNNG\tB_MOVIE',
#  '[EXiS2010]EX-Now 1\tNNG\tB_MOVIE',
#  '[EXiS2010]EX-Now 2\tNNG\tB_MOVIE',
#  '[EXiS2010]EX-Now 4\tNNG\tB_MOVIE',
#  '[EXiS2010]EX-Now 5\tNNG\tB_MOVIE',
#  '[EXiS2010]EX-Now 6\tNNG\tB_MOVIE',
#  '[EXiS2010]비바 페스티벌 1\tNNG\tB_MOVIE',
#  'n번째 이별 중\tNNG\tB_MOVIE',
#  'pm 11:14\tNNG\tB_MOVIE',
#  '新극장판 이니셜D: 레전드3 -몽현-\tNNG\tB_MOVIE',
#  '犬견 : 버려진 아이들\tNNG\tB_MOVIE',
#  '가가린\tNNG\tB_MOVIE',
#  '가구야공주 이야기\tNNG\tB_MOVIE',
#  '가까이서 본 기차\tNNG\tB_MOVIE',
#  '가나의 혼인잔치: 언약\tNNG\tB_MOVIE',
#  '가난한 새댁 : 몸으로 내는 월세\tNNG\tB_MOVIE',
#  '가능한 변화들\tNNG\tB_MOVIE',
#  '가든\tNNG\tB_MOVIE',
#  '가디언\tNNG\tB_MOVIE',
#  '가디언스\tNNG\tB_MOVIE',
#  '가디언의 전설\tNNG\tB_MOVIE',
#  '가디언즈\tNNG\tB_MOVIE',
#  '가디언즈 오브 갤럭시\tNNG\tB_MOVIE',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG\tB_MOVIE',
#  '가라, 가라 두 번째 처녀\tNNG\tB_MOVIE',
#  '가라데 파이터\tNNG\tB_MOVIE',
#  '가라데로 죽여라\tNNG\tB_MOVIE',
#  '가래떡의 맛: 감독판\tNNG\tB_MOVIE',
#  '가려진 시간\tNNG\tB_MOVIE',
#  '가루지기\tNNG\tB_MOVIE',
#  '가루지기: 변강쇠 더 비기닝\tNNG\tB_MOVIE',
#  '가루지기: 변강쇠 더 비기닝 - 무삭제판\tNNG\tB_MOVIE',
#  '가르시아\tNNG\tB_MOVIE',
#  '가름워즈: 마지막 예언자\tNNG\tB_MOVIE',
#  '가면\tNNG\tB_MOVIE',
#  '가면-감춰진 진실\tNNG\tB_MOVIE',
#  '가면속의 아리아\tNNG\tB_MOVIE',
#  '가면의 정사\tNNG\tB_MOVIE',
#  '가문의 부활 - 가문의 영광3\tNNG\tB_MOVIE',
#  '가문의 영광4 - 가문의 수난\tNNG\tB_MOVIE',
#  '가문의 영광5 - 가문의 귀환\tNNG\tB_MOVIE',
#  '가문의 위기(가문의 영광2)\tNNG\tB_MOVIE',
#  '가미카제\tNNG\tB_MOVIE',
#  '가발\tNNG\tB_MOVIE',
#  '가버나움\tNNG\tB_MOVIE',
#  '가베\tNNG\tB_MOVIE',
#  '가벼운 잠\tNNG\tB_MOVIE',
#  '가부와 메이 이야기\tNNG\tB_MOVIE',
#  '가비\tNNG\tB_MOVIE',
#  '가슴 노출을 허하라!\tNNG\tB_MOVIE',
#  '가슴 배구단\tNNG\tB_MOVIE',
#  '가슴 큰 가인\tNNG\tB_MOVIE',
#  '가슴 큰 가인 - 무삭제판\tNNG\tB_MOVIE',
#  '가슴 큰 그녀:질펀한 마사지\tNNG\tB_MOVIE',
#  '가슴 큰 뒷집소녀\tNNG\tB_MOVIE',
#  '가슴 큰 새 누나\tNNG\tB_MOVIE',
#  '가슴 큰 새 누나 2\tNNG\tB_MOVIE',
#  '가슴 큰 새엄마 루미\tNNG\tB_MOVIE',
#  '가슴 큰 앞집 소녀\tNNG\tB_MOVIE',
#  '가슴 큰 여대생\tNNG\tB_MOVIE',
#  '가슴 큰 여동생\tNNG\tB_MOVIE',
#  '가슴 큰 여자선배\tNNG\tB_MOVIE',
#  '가슴 큰 여자선배 무삭제\tNNG\tB_MOVIE',
#  '가슴 큰 여자친구\tNNG\tB_MOVIE',
#  '가슴 큰 여자친구 무삭제판\tNNG\tB_MOVIE',
#  '가슴 큰 연주\tNNG\tB_MOVIE',
#  '가슴 큰 옆집 소녀\tNNG\tB_MOVIE',
#  '가슴 큰 울 엄마\tNNG\tB_MOVIE',
#  '가슴 큰 울 엄마 2\tNNG\tB_MOVIE',
#  '가슴 큰 처제\tNNG\tB_MOVIE',
#  '가슴 큰 처제-무삭제판\tNNG\tB_MOVIE',
#  '가슴 큰 초희\tNNG\tB_MOVIE',
#  '가슴 큰 초희 - 무삭제판\tNNG\tB_MOVIE',
#  '가슴 큰 친구 여친\tNNG\tB_MOVIE',
#  '가슴 큰 친구여친 무삭제\tNNG\tB_MOVIE',
#  '가슴 큰 태희\tNNG\tB_MOVIE',
#  '가슴 큰 태희-무삭제판\tNNG\tB_MOVIE',
#  '가슴 큰 형수\tNNG\tB_MOVIE',
#  '가슴 큰 형수-무삭제판\tNNG\tB_MOVIE',
#  '가슴에 돋는 칼로 슬픔을 자르고\tNNG\tB_MOVIE',
#  '가슴을 탐하는 남자들\tNNG\tB_MOVIE',
#  '가슴이 떨리는 건 너 때문\tNNG\tB_MOVIE',
#  '가슴큰누나들\tNNG\tB_MOVIE',
#  '가슴큰누나들-무삭제\tNNG\tB_MOVIE',
#  '가슴큰며느리\tNNG\tB_MOVIE',
#  '가슴큰며느리-무삭제\tNNG\tB_MOVIE',
#  '가슴큰새엄마\tNNG\tB_MOVIE',
#  '가슴큰새엄마-무삭제\tNNG\tB_MOVIE',
#  '가슴큰엄마들\tNNG\tB_MOVIE',
#  '가슴큰엄마들-무삭제\tNNG\tB_MOVIE',
#  '가슴큰엄마친구\tNNG\tB_MOVIE',
#  '가슴큰엄마친구-무삭제\tNNG\tB_MOVIE',
#  '가슴큰자매들\tNNG\tB_MOVIE',
#  '가슴큰자매들 - 무삭제\tNNG\tB_MOVIE',
#  '가슴큰친구누나들\tNNG\tB_MOVIE',
#  '가슴큰친구누나들-무삭제\tNNG\tB_MOVIE',
#  '가시\tNNG\tB_MOVIE',
#  '가시꽃\tNNG\tB_MOVIE',
#  '가싶녀\tNNG\tB_MOVIE',
#  '가위 : 수면마비의 기억\tNNG\tB_MOVIE',
#  '가위손\tNNG\tB_MOVIE',
#  '가을 소나타\tNNG\tB_MOVIE',
#  '가을 우체국\tNNG\tB_MOVIE',
#  '가을날의 동화\tNNG\tB_MOVIE',
#  '가을날의 재회\tNNG\tB_MOVIE',
#  '가을로\tNNG\tB_MOVIE',
#  '가을비 우산속에\tNNG\tB_MOVIE',
#  '가을의 마티네\tNNG\tB_MOVIE',
#  '가을의 전설\tNNG\tB_MOVIE',
#  '가자 장미여관으로 4\tNNG\tB_MOVIE',
#  '가자 장미여관으로 4 - 무삭제판\tNNG\tB_MOVIE',
#  '가자! 장미여관으로 2 - 갈증\tNNG\tB_MOVIE',
#  '가자! 장미여관으로 3 - 방황\tNNG\tB_MOVIE',
#  '가자! 장미여관으로 3 - 방황 무삭제 감독판\tNNG\tB_MOVIE',
#  '가자, 장미여관으로\tNNG\tB_MOVIE',
#  '가장 따뜻한 색, 블루\tNNG\tB_MOVIE',
#  '가장 보통의 연애\tNNG\tB_MOVIE',
#  '가재가 노래하는 곳\tNNG\tB_MOVIE',
#  '가정교사 길들이기\tNNG\tB_MOVIE',
#  '가정교사-맛있는 섹스 비밀 수업\tNNG\tB_MOVIE',
#  '가정교사: 앞집 아줌마의 수업\tNNG\tB_MOVIE',
#  '가정교사: 하고 싶은 여자\tNNG\tB_MOVIE',
#  '가정교사:만져주기\tNNG\tB_MOVIE',
#  '가정교사의 맛있는 수업\tNNG\tB_MOVIE',
#  '가정교사의 비밀수업\tNNG\tB_MOVIE',
#  '가정교사의 위험한 방문\tNNG\tB_MOVIE',
#  '가정부 길들이기\tNNG\tB_MOVIE',
#  '가정부 길들이기 무삭제판\tNNG\tB_MOVIE',
#  '가정부와의 불륜\tNNG\tB_MOVIE',
#  '가정부의 맛\tNNG\tB_MOVIE',
#  '가정부의 목적\tNNG\tB_MOVIE',
#  '가정부의 목적 무삭제판\tNNG\tB_MOVIE',
#  '가정부의 손맛 감독판\tNNG\tB_MOVIE',
#  '가정부의 유혹\tNNG\tB_MOVIE',
#  '가져선 안될 비밀\tNNG\tB_MOVIE',
#  '가족\tNNG\tB_MOVIE',
#  '가족 연애사\tNNG\tB_MOVIE',
#  '가족사진\tNNG\tB_MOVIE',
#  '가족상속괴담\tNNG\tB_MOVIE',
#  '가족시네마\tNNG\tB_MOVIE',
#  '가족은 괴로워3: 아내여 장미처럼\tNNG\tB_MOVIE',
#  '가족의 나라\tNNG\tB_MOVIE',
#  '가족의 색깔\tNNG\tB_MOVIE',
#  '가족의 재구성\tNNG\tB_MOVIE',
#  '가족의 탄생\tNNG\tB_MOVIE',
#  '가족이 되기까지\tNNG\tB_MOVIE',
#  '가치 캅시다\tNNG\tB_MOVIE',
#  '가투의 연날리기\tNNG\tB_MOVIE',
#  '가필드\tNNG\tB_MOVIE',
#  '가필드 2\tNNG\tB_MOVIE',
#  '가필드 펫 포스 3D\tNNG\tB_MOVIE',
#  '가필드-마법의 샘물\tNNG\tB_MOVIE',
#  '각설탕\tNNG\tB_MOVIE',
#  '각시탈\tNNG\tB_MOVIE',
#  '간 큰 가족\tNNG\tB_MOVIE',
#  '간기남\tNNG\tB_MOVIE',
#  '간디\tNNG\tB_MOVIE',
#  '간병인의 황제서비스\tNNG\tB_MOVIE',
#  '간신\tNNG\tB_MOVIE',
#  '간음:위험한 유부녀들\tNNG\tB_MOVIE',
#  '간이역\tNNG\tB_MOVIE',
#  '간증\tNNG\tB_MOVIE',
#  '간첩\tNNG\tB_MOVIE',
#  '간첩 리철진\tNNG\tB_MOVIE',
#  '간츠\tNNG\tB_MOVIE',
#  '간츠: 오\tNNG\tB_MOVIE',
#  '간츠: 퍼펙트 앤서\tNNG\tB_MOVIE',
#  '간통 : 섹스 회춘 료칸\tNNG\tB_MOVIE',
#  '간통: 사장님의 아내\tNNG\tB_MOVIE',
#  '간호사와 음란 마사지\tNNG\tB_MOVIE',
#  '간호중\tNNG\tB_MOVIE',
#  '갇힌 여인\tNNG\tB_MOVIE',
#  '갈까부다\tNNG\tB_MOVIE',
#  '갈리폴리 상륙작전\tNNG\tB_MOVIE',
#  '갈리폴리: 최악의 상륙작전\tNNG\tB_MOVIE',
#  '갈매기\tNNG\tB_MOVIE',
#  '갈증\tNNG\tB_MOVIE',
#  '감금당한 청순미인의 절정\tNNG\tB_MOVIE',
#  '감금당해 범해지는 청순미인\tNNG\tB_MOVIE',
#  '감금의 시간\tNNG\tB_MOVIE',
#  '감금의 시간 2 무삭제\tNNG\tB_MOVIE',
#  '감금의 정사\tNNG\tB_MOVIE',
#  '감금일지-메이드\tNNG\tB_MOVIE',
#  '감기\tNNG\tB_MOVIE',
#  '감당이 안되는 욕정녀\tNNG\tB_MOVIE',
#  '감독 미카엘 하네케\tNNG\tB_MOVIE',
#  '감동주의보\tNNG\tB_MOVIE',
#  '감바의 대모험\tNNG\tB_MOVIE',
#  '감성에 젖은 음대선생님\tNNG\tB_MOVIE',
#  '감시자들\tNNG\tB_MOVIE',
#  '감염: 지구 최후의 날\tNNG\tB_MOVIE',
#  '감옥정사\tNNG\tB_MOVIE',
#  '감옥풍운\tNNG\tB_MOVIE',
#  '감자\tNNG\tB_MOVIE',
#  '감자심포니\tNNG\tB_MOVIE',
#  '감쪽같은 그녀\tNNG\tB_MOVIE',
#  '감출 수 없는 본능-몰카\tNNG\tB_MOVIE',
#  '갑질당하는 육덕가정부\tNNG\tB_MOVIE',
#  '갑질섹스-색기\tNNG\tB_MOVIE',
#  '갓 앤 몬스터\tNNG\tB_MOVIE',
#  '갓 오브 이집트\tNNG\tB_MOVIE',
#  '갓 헬프 더 걸\tNNG\tB_MOVIE',
#  '갓길로 달리는 코뿔소\tNNG\tB_MOVIE',
#  '갓센드\tNNG\tB_MOVIE',
#  '갓즈 포켓\tNNG\tB_MOVIE',
#  '갓파 쿠와 여름방학을\tNNG\tB_MOVIE',
#  '강간 몰카 유출 사건\tNNG\tB_MOVIE',
#  '강남 1970\tNNG\tB_MOVIE',
#  '강남 며느리\tNNG\tB_MOVIE',
#  '강력 3반\tNNG\tB_MOVIE',
#  '강력 범죄\tNNG\tB_MOVIE',
#  '강령\tNNG\tB_MOVIE',
#  '강릉\tNNG\tB_MOVIE',
#  '강변호텔\tNNG\tB_MOVIE',
#  '강시: 리거모티스\tNNG\tB_MOVIE',
#  '강시선생 -일미도인\tNNG\tB_MOVIE',
#  '강시선생 2\tNNG\tB_MOVIE',
#  '강시선생 3 - 영환도사\tNNG\tB_MOVIE',
#  '강아지 삼총사\tNNG\tB_MOVIE',
#  '강원도의 힘\tNNG\tB_MOVIE',
#  '강을 건너는 사람들\tNNG\tB_MOVIE',
#  '강적\tNNG\tB_MOVIE',
#  '강제 섹스:거절하다 신음\tNNG\tB_MOVIE',
#  '강제로 당하는 새엄마\tNNG\tB_MOVIE',
#  '강제섹스: 그 남자의 섹스방식\tNNG\tB_MOVIE',
#  '강철대오:구국의 철가방\tNNG\tB_MOVIE',
#  '강철비\tNNG\tB_MOVIE',
#  '강철비2 : 정상회담 확장판\tNNG\tB_MOVIE',
#  '강철비2: 정상회담\tNNG\tB_MOVIE',
#  '강철의 연금술사 : 미로스의 성스러운 별\tNNG\tB_MOVIE',
#  '강철중+크로싱+쿵푸 팬더\tNNG\tB_MOVIE',
#  '강철중: 공공의 적 1-1\tNNG\tB_MOVIE',
#  '강철중:공공의 적1-1+인크레더블 헐크+겟 스마트\tNNG\tB_MOVIE',
#  '강한 칼: 도도견혈\tNNG\tB_MOVIE',
#  '강호\tNNG\tB_MOVIE',
#  '강호아녀\tNNG\tB_MOVIE',
#  '강호의 무림신공\tNNG\tB_MOVIE',
#  '강호제일검 금강철선\tNNG\tB_MOVIE',
#  '같은 달을 보고 있다\tNNG\tB_MOVIE',
#  '같은 속옷을 입는 두 여자\tNNG\tB_MOVIE',
#  '개 같은 것들\tNNG\tB_MOVIE',
#  '개: dog eat dog\tNNG\tB_MOVIE',
#  '개같은 날의 오후\tNNG\tB_MOVIE',
#  '개같은 내인생\tNNG\tB_MOVIE',
#  '개구리왕국\tNNG\tB_MOVIE',
#  '개구리왕국 2\tNNG\tB_MOVIE',
#  '개구리중사 케로로\tNNG\tB_MOVIE',
#  '개구쟁이 스머프\tNNG\tB_MOVIE',
#  '개구쟁이 스머프 2\tNNG\tB_MOVIE',
#  '개그 더 크라운\tNNG\tB_MOVIE',
#  '개그맨\tNNG\tB_MOVIE',
#  '개들의 섬\tNNG\tB_MOVIE',
#  '개들의 전쟁\tNNG\tB_MOVIE',
#  '개똥이\tNNG\tB_MOVIE',
#  '개를 훔치는 완벽한 방법\tNNG\tB_MOVIE',
#  '개벽\tNNG\tB_MOVIE',
#  '개선문\tNNG\tB_MOVIE',
#  '개에게 처음 이름을 지어준 날\tNNG\tB_MOVIE',
#  '개와 늑대 사이의 시간\tNNG\tB_MOVIE',
#  '개인교수 2014\tNNG\tB_MOVIE',
#  '개인교수 : 맛있게 섹스하는 방법\tNNG\tB_MOVIE',
#  '개인교수 : 맛있게 섹스하는 방법(무삭제)\tNNG\tB_MOVIE',
#  '개인교수 : 성적 올리기\tNNG\tB_MOVIE',
#  '개인교수 : 성적 올리기 무삭제\tNNG\tB_MOVIE',
#  '개인교수 : 세 여자의 섹스수업\tNNG\tB_MOVIE',
#  '개인교수 : 여친 만족 시키기\tNNG\tB_MOVIE',
#  '개인교수 : 여친 만족 시키기 무삭제\tNNG\tB_MOVIE',
#  '개인교수: 심화학습\tNNG\tB_MOVIE',
#  '개인교수: 심화학습 (무삭제)\tNNG\tB_MOVIE',
#  '개인교습\tNNG\tB_MOVIE',
#  '개인교습: 사촌여동생\tNNG\tB_MOVIE',
#  '개인레슨\tNNG\tB_MOVIE',
#  '개인영업 : 업소녀가 된 아내\tNNG\tB_MOVIE',
#  '개인지도:붓으로 그리는 황홀경\tNNG\tB_MOVIE',
#  '갤럭시 히어로즈: 라쳇 앤 클랭크\tNNG\tB_MOVIE',
#  '갤로우즈\tNNG\tB_MOVIE',
#  '갤로워커: 블레이드의 귀환\tNNG\tB_MOVIE',
#  '갤버스턴\tNNG\tB_MOVIE',
#  '갬빗\tNNG\tB_MOVIE',
#  '갯마을\tNNG\tB_MOVIE',
#  '갱\tNNG\tB_MOVIE',
#  '갱 브라더스: 마지막 대결\tNNG\tB_MOVIE',
#  '갱경떡삥이\tNNG\tB_MOVIE',
#  '갱스터 초치\tNNG\tB_MOVIE',
#  '거근이 좋아\tNNG\tB_MOVIE',
#  '거기엔 래퍼가 없다\tNNG\tB_MOVIE',
#  '거꾸로 된 파테마\tNNG\tB_MOVIE',
#  '거대 불개미의 습격\tNNG\tB_MOVIE',
#  '거대말벌의 습격\tNNG\tB_MOVIE',
#  '거대한 서부\tNNG\tB_MOVIE',
#  '거래완료\tNNG\tB_MOVIE',
#  '거래처 여직원\tNNG\tB_MOVIE',
#  '거룩한 계보\tNNG\tB_MOVIE',
#  '거룩한 분노\tNNG\tB_MOVIE',
#  '거룩한 소녀 마리아\tNNG\tB_MOVIE',
#  '거리의 보안관\tNNG\tB_MOVIE',
#  '거미숲\tNNG\tB_MOVIE',
#  '거미의 계략\tNNG\tB_MOVIE',
#  '거미의 땅\tNNG\tB_MOVIE',
#  '거미줄에 걸린 소녀\tNNG\tB_MOVIE',
#  '거부하다 신음하는 여자\tNNG\tB_MOVIE',
#  '거북이 달린다\tNNG\tB_MOVIE',
#  '거북이도 난다\tNNG\tB_MOVIE',
#  '거울나라의 앨리스\tNNG\tB_MOVIE',
#  '거유 며느리의 은밀한 일탈\tNNG\tB_MOVIE',
#  '거유 며느리의 친정나들이\tNNG\tB_MOVIE',
#  '거유 바니걸 리나\tNNG\tB_MOVIE',
#  '거유 새엄마와 형제들\tNNG\tB_MOVIE',
#  '거유 여사장의 약점\tNNG\tB_MOVIE',
#  '거유 와이프:남편 대신 상사와\tNNG\tB_MOVIE',
#  '거유 유부녀의 오일 마사지\tNNG\tB_MOVIE',
#  '거유 장모와 실제로 느끼는 사위\tNNG\tB_MOVIE',
#  '거유 치과 간호사\tNNG\tB_MOVIE',
#  '거유 치나미 사쿠라의 아찔 유혹\tNNG\tB_MOVIE',
#  '거유 칸나의 질펀한 서비스\tNNG\tB_MOVIE',
#  '거유간호사 폭유간호사\tNNG\tB_MOVIE',
#  '거유녀들의 아찔한 가슴골\tNNG\tB_MOVIE',
#  '거유녀의 젖어버린 작업복\tNNG\tB_MOVIE',
#  '거유미녀 서큐버스2\tNNG\tB_MOVIE',
#  '거유이발소-어서오세요\tNNG\tB_MOVIE',
#  '거인\tNNG\tB_MOVIE',
#  '거지의 오페라\tNNG\tB_MOVIE',
#  '거짓말\tNNG\tB_MOVIE',
#  '거짓말 2014\tNNG\tB_MOVIE',
#  '거짓말 2018: 감독판\tNNG\tB_MOVIE',
#  '거짓말 : 여자 모델의 섹스\tNNG\tB_MOVIE',
#  '거짓말 : 여자 모델의 섹스 무삭제\tNNG\tB_MOVIE',
#  '거짓말 섹스가 좋아\tNNG\tB_MOVIE',
#  '거짓말 섹스가 좋아2\tNNG\tB_MOVIE',
#  '거짓말 애인-감독판\tNNG\tB_MOVIE',
#  '거짓의\tNNG\tB_MOVIE',
#  '거친 녀석들\tNNG\tB_MOVIE',
#  '거친 섹스에 빠진 그녀들\tNNG\tB_MOVIE',
#  '거칠마루\tNNG\tB_MOVIE',
#  '거침없이 쏴라! 슛뎀업\tNNG\tB_MOVIE',
#  '걱정말아요\tNNG\tB_MOVIE',
#  '건\tNNG\tB_MOVIE',
#  '건 샤이\tNNG\tB_MOVIE',
#  '건달 가정부\tNNG\tB_MOVIE',
#  '건달티처\tNNG\tB_MOVIE',
#  '건마의 신: 어린 아내의 알바\tNNG\tB_MOVIE',
#  '건양강호: 운뢰검법의 비밀\tNNG\tB_MOVIE',
#  '건우먼\tNNG\tB_MOVIE',
#  '건즈 아킴보\tNNG\tB_MOVIE',
#  '건즈 포 하이어\tNNG\tB_MOVIE',
#  '건축학개론\tNNG\tB_MOVIE',
#  '건파우더 밀크셰이크\tNNG\tB_MOVIE',
#  '걷기 좋은 날\tNNG\tB_MOVIE',
#  '걷기왕\tNNG\tB_MOVIE',
#  '걸\tNNG\tB_MOVIE',
#  '걸 아바타\tNNG\tB_MOVIE',
#  '걸 온 더 브릿지\tNNG\tB_MOVIE',
#  '걸 온 더 트레인\tNNG\tB_MOVIE',
#  '걸 위드 더 카메라\tNNG\tB_MOVIE',
#  '걸 인 더 포토그래프\tNNG\tB_MOVIE',
#  '걸리버 리턴즈\tNNG\tB_MOVIE',
#  '걸리버 여행기\tNNG\tB_MOVIE',
#  '걸스\tNNG\tB_MOVIE',
#  '걸스 곤 데드\tNNG\tB_MOVIE',
#  '걸스 나잇\tNNG\tB_MOVIE',
#  '걸스 스텝\tNNG\tB_MOVIE',
#  '걸스 온 탑2\tNNG\tB_MOVIE',
#  '걸스카우트\tNNG\tB_MOVIE',
#  '걸어도 걸어도\tNNG\tB_MOVIE',
#  '걸작\tNNG\tB_MOVIE',
#  '걸즈 앤 판처 극장판\tNNG\tB_MOVIE',
#  '걸즈 앤 판처 제\u200b 63회 전차도 전국 고교생 대회\tNNG\tB_MOVIE',
#  '걸즈 앤 판처 최종장\tNNG\tB_MOVIE',
#  '걸즈 앤 판처 최종장 제1화\tNNG\tB_MOVIE',
#  '걸즈 앤 판처 최종장 제3화\tNNG\tB_MOVIE',
#  '걸캅스\tNNG\tB_MOVIE',
#  '걸캅스 누나들\tNNG\tB_MOVIE',
#  '걸프렌즈\tNNG\tB_MOVIE',
#  '걸후드\tNNG\tB_MOVIE',
#  '검객\tNNG\tB_MOVIE',
#  '검객풍운\tNNG\tB_MOVIE',
#  '검사외전\tNNG\tB_MOVIE',
#  '검우강호\tNNG\tB_MOVIE',
#  '검은 고양이 흰 고양이\tNNG\tB_MOVIE',
#  '검은 땅의 소녀와\tNNG\tB_MOVIE',
#  '검은 물밑에서\tNNG\tB_MOVIE',
#  '검은 사제들\tNNG\tB_MOVIE',
#  '검은 사제들: 지옥의 문\tNNG\tB_MOVIE',
#  '검은 숲\tNNG\tB_MOVIE',
#  '검은 여름\tNNG\tB_MOVIE',
#  '검은 집\tNNG\tB_MOVIE',
#  '검은 집: 죽음을 보는 눈\tNNG\tB_MOVIE',
#  '검은비: 악의연대기\tNNG\tB_MOVIE',
#  '검은손\tNNG\tB_MOVIE',
#  '겁나는 여친의 완벽한 비밀\tNNG\tB_MOVIE',
#  '겁쟁이 페달: 더 무비\tNNG\tB_MOVIE',
#  '겁쟁이 페달: 리라이드\tNNG\tB_MOVIE',
#  '겁쟁이 페달: 리로드\tNNG\tB_MOVIE',
#  '겁쟁이 페달: 스페어 바이크\tNNG\tB_MOVIE',
#  '겁탈당한 유부녀\tNNG\tB_MOVIE',
#  '겁탈당한 유부녀 무삭제판\tNNG\tB_MOVIE',
#  '게드전기 : 어스시의 전설\tNNG\tB_MOVIE',
#  '게발트 파이브:구타본능\tNNG\tB_MOVIE',
#  '게스트하우스\tNNG\tB_MOVIE',
#  '게스후\tNNG\tB_MOVIE',
#  '게이머\tNNG\tB_MOVIE',
#  '게이샤 하우스\tNNG\tB_MOVIE',
#  '게이샤:격정정사\tNNG\tB_MOVIE',
#  ...]

# %%
txt = txts[0].split('\t')
txt
# Out:
# ['0시', 'NNG', 'B_DT']

# %%
# new_user_dict.append(txt[0]+'\t'+txt[1])
# new_user_dict
# Out:
# ['0시\tNNG']

# %%
for txt in txts:
    t = txt.split('\t')
    new_user_dict.append(t[0]+'\t'+t[1])

# %%
print(len(new_user_dict))
new_user_dict
# Out:
# 57076
# ['0시\tNNG',
#  '1시\tNNG',
#  '2시\tNNG',
#  '3시\tNNG',
#  '4시\tNNG',
#  '5시\tNNG',
#  '6시\tNNG',
#  '7시\tNNG',
#  '8시\tNNG',
#  '9시\tNNG',
#  '10시\tNNG',
#  '11시\tNNG',
#  '12시\tNNG',
#  '13시\tNNG',
#  '14시\tNNG',
#  '15시\tNNG',
#  '16시\tNNG',
#  '17시\tNNG',
#  '18시\tNNG',
#  '19시\tNNG',
#  '20시\tNNG',
#  '21시\tNNG',
#  '22시\tNNG',
#  '23시\tNNG',
#  '24시\tNNG',
#  '0분\tNNG',
#  '1분\tNNG',
#  '2분\tNNG',
#  '3분\tNNG',
#  '4분\tNNG',
#  '5분\tNNG',
#  '6분\tNNG',
#  '7분\tNNG',
#  '8분\tNNG',
#  '9분\tNNG',
#  '10분\tNNG',
#  '11분\tNNG',
#  '12분\tNNG',
#  '13분\tNNG',
#  '14분\tNNG',
#  '15분\tNNG',
#  '16분\tNNG',
#  '17분\tNNG',
#  '18분\tNNG',
#  '19분\tNNG',
#  '20분\tNNG',
#  '21분\tNNG',
#  '22분\tNNG',
#  '23분\tNNG',
#  '24분\tNNG',
#  '25분\tNNG',
#  '26분\tNNG',
#  '27분\tNNG',
#  '28분\tNNG',
#  '29분\tNNG',
#  '30분\tNNG',
#  '31분\tNNG',
#  '32분\tNNG',
#  '33분\tNNG',
#  '34분\tNNG',
#  '35분\tNNG',
#  '36분\tNNG',
#  '37분\tNNG',
#  '38분\tNNG',
#  '39분\tNNG',
#  '40분\tNNG',
#  '41분\tNNG',
#  '42분\tNNG',
#  '43분\tNNG',
#  '44분\tNNG',
#  '45분\tNNG',
#  '46분\tNNG',
#  '47분\tNNG',
#  '48분\tNNG',
#  '49분\tNNG',
#  '50분\tNNG',
#  '51분\tNNG',
#  '52분\tNNG',
#  '53분\tNNG',
#  '54분\tNNG',
#  '55분\tNNG',
#  '56분\tNNG',
#  '57분\tNNG',
#  '58분\tNNG',
#  '59분\tNNG',
#  '60분\tNNG',
#  '1월\tNNG',
#  '2월\tNNG',
#  '3월\tNNG',
#  '4월\tNNG',
#  '5월\tNNG',
#  '6월\tNNG',
#  '7월\tNNG',
#  '8월\tNNG',
#  '9월\tNNG',
#  '10월\tNNG',
#  '11월\tNNG',
#  '12월\tNNG',
#  '1일\tNNG',
#  '2일\tNNG',
#  '3일\tNNG',
#  '4일\tNNG',
#  '5일\tNNG',
#  '6일\tNNG',
#  '7일\tNNG',
#  '8일\tNNG',
#  '9일\tNNG',
#  '10일\tNNG',
#  '11일\tNNG',
#  '12일\tNNG',
#  '13일\tNNG',
#  '14일\tNNG',
#  '15일\tNNG',
#  '16일\tNNG',
#  '17일\tNNG',
#  '18일\tNNG',
#  '19일\tNNG',
#  '20일\tNNG',
#  '21일\tNNG',
#  '22일\tNNG',
#  '23일\tNNG',
#  '24일\tNNG',
#  '25일\tNNG',
#  '26일\tNNG',
#  '27일\tNNG',
#  '28일\tNNG',
#  '29일\tNNG',
#  '30일\tNNG',
#  '31일\tNNG',
#  '월요일\tNNG',
#  '화요일\tNNG',
#  '수요일\tNNG',
#  '목요일\tNNG',
#  '금요일\tNNG',
#  '토요일\tNNG',
#  '일요일\tNNG',
#  '#살아있다\tNNG',
#  '#아이엠히어\tNNG',
#  '#위왓치유\tNNG',
#  '...ing\tNNG',
#  '0.0MHz\tNNG',
#  '007 노 타임 투 다이\tNNG',
#  '007 북경특급 2\tNNG',
#  '007 스카이폴\tNNG',
#  '007 스펙터\tNNG',
#  '007 제2편 : 위기일발\tNNG',
#  '007 카지노 로얄\tNNG',
#  '007 퀀텀 오브 솔러스\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+뱅크 잡\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+순정만화\tNNG',
#  '009 사이보그\tNNG',
#  '10 미니츠 곤\tNNG',
#  '10 바이 10\tNNG',
#  '10 아이템 오어 레스\tNNG',
#  '10,000 BC\tNNG',
#  '10,000 BC + 어메이징 그레이스 + 댄 인 러브\tNNG',
#  '10,000BC+마이 블루베리 나이츠+연을 쫓는 아이\tNNG',
#  '10,000BC+연을 쫓는 아이+마이 블루베리 나이츠\tNNG',
#  '10,000km(만 킬로미터)\tNNG',
#  '100 피트\tNNG',
#  '100% 울프: 푸들이 될 순 없어\tNNG',
#  '1000 : 최후의 전사들\tNNG',
#  '100년 동안의 히틀러\tNNG',
#  '100미터\tNNG',
#  '100일 동안 100가지로 100퍼센트 행복찾기\tNNG',
#  '10년\tNNG',
#  '10분\tNNG',
#  '10억\tNNG',
#  '10일간의 원나잇 스탠드\tNNG',
#  '10층의 모기\tNNG',
#  '117편의 러브레터\tNNG',
#  '11월 실험영화 정기 상영회\tNNG',
#  '11인의 카우보이\tNNG',
#  '12 솔져스\tNNG',
#  '120 BPM\tNNG',
#  '125 전승철\tNNG',
#  '127시간\tNNG',
#  '12번째 솔저\tNNG',
#  '12시에 열리는 쾌락의 문\tNNG',
#  '12월실험영화상영회-야수토 유라 특별전\tNNG',
#  '12인의 하숙생\tNNG',
#  '12피트\tNNG',
#  '13 이어리\tNNG',
#  '13 자메티\tNNG',
#  '13구역\tNNG',
#  '13구역: 얼티메이텀\tNNG',
#  '13년의 공백\tNNG',
#  '13번째 전사\tNNG',
#  '13시간\tNNG',
#  '13인의 자객\tNNG',
#  '13일의 금요일\tNNG',
#  '13일의 금요일: 더 파이널\tNNG',
#  '1408\tNNG',
#  '1492 콜럼버스\tNNG',
#  '14인의 여걸\tNNG',
#  '15소년 우주 표류기\tNNG',
#  '15소년 표류기: 해적섬을 탈출하라\tNNG',
#  '16세의 사운드트랙\tNNG',
#  '1724 기방난동사건\tNNG',
#  '17인의사자들\tNNG',
#  '18 BJ 하연의 화려한 테크닉\tNNG',
#  '18 걸그룹 승하의 눈치게임\tNNG',
#  '18 모델 리카의 화려한 외출\tNNG',
#  '18 성인배우 이수의 섹스 판타지\tNNG',
#  '18 섹시퀸 유진의 섹스 스캔들\tNNG',
#  '18 승하의 누워서 떡 먹기\tNNG',
#  '18 여대생 소라의 순결상실\tNNG',
#  '18 주아의 뜨거운 하루\tNNG',
#  '18 출사녀 화진의 미친 섹스\tNNG',
#  '18 하라의 맛있는 수업\tNNG',
#  '1812 나폴레옹 대전투\tNNG',
#  '1820: 잃어버린 제국의 비밀\tNNG',
#  '1850 길로틴 트레지디\tNNG',
#  '18: 우리들의 성장 느와르\tNNG',
#  '18금 아이돌 승하의 섹스 스캔들\tNNG',
#  '18금 아이돌 승하의 화려한 외출\tNNG',
#  '19 섹스 맛있는 속 궁합\tNNG',
#  '19-Nineteen\tNNG',
#  '1900년\tNNG',
#  '1917\tNNG',
#  '1919 유관순\tNNG',
#  '1940: 최강의 독일 전차부대\tNNG',
#  '1941\tNNG',
#  '1941: 세바스토폴 상륙작전\tNNG',
#  '1942: 언노운 배틀\tNNG',
#  '1942: 최정예특수부대 스페츠나츠\tNNG',
#  '1944\tNNG',
#  '1944 대전투\tNNG',
#  '1944 워 히어로\tNNG',
#  '1944: 인간병기\tNNG',
#  '1945 그레이트 워\tNNG',
#  '1945: 포인트 오브 노 리턴\tNNG',
#  '1975 킬링필드, 푸난\tNNG',
#  '1984 최동원\tNNG',
#  '1987\tNNG',
#  '1991, 봄\tNNG',
#  '1999, 면회\tNNG',
#  '19곰 테드\tNNG',
#  '19곰 테드 2\tNNG',
#  '19금 만남의 목적\tNNG',
#  '19금 불륜소설\tNNG',
#  '19금 불륜소설 무삭제판\tNNG',
#  '19금 비밀과외\tNNG',
#  '19금 섹스비디오\tNNG',
#  '19금 섹스비디오 무삭제 감독판\tNNG',
#  '19금 섹스의 늪 무삭특별판\tNNG',
#  '19금 연애소설\tNNG',
#  '19금 연애소설 무삭제판\tNNG',
#  '19금 절대섹스\tNNG',
#  '19금 정사: 말할 수 없는 비밀\tNNG',
#  '19금 특별한 정사\tNNG',
#  '19금 특별한 정사 무삭제 특별판\tNNG',
#  '19번가물많은여자친구\tNNG',
#  '1급기밀\tNNG',
#  '1박2일 소개팅\tNNG',
#  '1번가의 기적\tNNG',
#  '1번국도\tNNG',
#  '1월 단편 상상극장\tNNG',
#  '1월의 두 얼굴\tNNG',
#  '2 데이즈 인 뉴욕\tNNG',
#  '2%필름페스티발\tNNG',
#  '20 30 40\tNNG',
#  '2007 시네바캉스 서울\tNNG',
#  '2007 아시아나국제단편영화제\tNNG',
#  '2007 인디애니페스트\tNNG',
#  '2007 칸국제광고제 수상작 필름 페스티벌\tNNG',
#  '2007CJ중국영화제\tNNG',
#  '2008 광주국제영화제\tNNG',
#  '2008 음악 영화제\tNNG',
#  '2008 최강애니전\tNNG',
#  '2008년 시네마테크의 친구들 영화제\tNNG',
#  '2010 3D한국국제영화제\tNNG',
#  '2010 AISFF-개막식\tNNG',
#  '2010 AISFF-거장들의 패션필름\tNNG',
#  '2010 AISFF-국제경쟁1\tNNG',
#  '2010 AISFF-국제경쟁2\tNNG',
#  '2010 AISFF-국제경쟁3\tNNG',
#  '2010 AISFF-국제경쟁4\tNNG',
#  '2010 AISFF-국제경쟁5\tNNG',
#  '2010 AISFF-국제경쟁6\tNNG',
#  '2010 AISFF-국제경쟁7\tNNG',
#  '2010 AISFF-국제경쟁8\tNNG',
#  '2010 AISFF-메이드 바이 커머셜 디렉터스\tNNG',
#  '2010 AISFF-시상식\tNNG',
#  '2010 AISFF-여자는 두 번 플레이 한다\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 저팬\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 코리아\tNNG',
#  '2010 시네바캉스 서울\tNNG',
#  '2010 한-EU단편영화 교류전\tNNG',
#  '2010 한국영화아카데미 영화제\tNNG',
#  '2010년 시네마테크의 친구들 영화제\tNNG',
#  '2010칸국제광고제 수상작페스티벌\tNNG',
#  '2012\tNNG',
#  '2014 지구 최후의 날\tNNG',
#  '2017 동명이인 프로젝트\tNNG',
#  '2017복상사\tNNG',
#  '2020년 마지막 섹스\tNNG',
#  '2021 첫 섹스\tNNG',
#  '2023-09-11 00:00:00\tNNG',
#  '2025 지구전쟁: 얼리전스 오브 파워\tNNG',
#  '2035 매드 레이스\tNNG',
#  '2046\tNNG',
#  '2047 버추얼 레볼루션\tNNG',
#  '2047: 지구 최후의 날\tNNG',
#  '2067\tNNG',
#  '20대 같은 40대 미시녀\tNNG',
#  '20세기 소년\tNNG',
#  '20세기 소년 ; 최종장 - 우리들의 깃발\tNNG',
#  '20세기 소년+맘마미아+방콕 데인저러스\tNNG',
#  '20세기 소년-제2장: 마지막 희망\tNNG',
#  '20일밤, 그리고 비 오는 하루\tNNG',
#  '21\tNNG',
#  '21 그램\tNNG',
#  '21 브릿지: 테러 셧다운\tNNG',
#  '21 앤드 오버\tNNG',
#  '21살승하의아이돌비밀일기\tNNG',
#  '21살승하의아이돌비밀일기-무삭제\tNNG',
#  '21세기 우리 시대의 영화 특별전\tNNG',
#  '21세기의 기원\tNNG',
#  '22\tNNG',
#  '22 블렛\tNNG',
#  '22년 후의 고백\tNNG',
#  '22분: 아덴만 구출작전\tNNG',
#  '23 아이덴티티\tNNG',
#  '24 시티\tNNG',
#  '24살윤율의섹시한젖가슴\tNNG',
#  '24살윤율의섹시한젖가슴-무삭제\tNNG',
#  '24시간 달리는 쾌락 버스\tNNG',
#  '24주\tNNG',
#  '25시\tNNG',
#  '26년\tNNG',
#  '27번의 결혼리허설\tNNG',
#  '27번의 결혼리허설 + 마이 뉴 파트너 + 마이 블루베리 나이츠\tNNG',
#  '27번의 결혼리허설+10,000BC+밴티지 포인트\tNNG',
#  '28세 미성년\tNNG',
#  '28일 후\tNNG',
#  '2솔져스: 배틀필드\tNNG',
#  '2월 29일 - 어느날 갑자기 첫번째 이야기\tNNG',
#  '2차 노출\tNNG',
#  '2차 세계대전 타임트랙\tNNG',
#  '2차 송환\tNNG',
#  '2회 브라질 영화제: 시네마 노보 회고전\tNNG',
#  '3-4X10월\tNNG',
#  '3.5교시\tNNG',
#  '300\tNNG',
#  '300: 전사의 귀환\tNNG',
#  '300: 제국의 부활\tNNG',
#  '301, 302\tNNG',
#  '3022: 지구 대폭발\tNNG',
#  '3096일\tNNG',
#  '30년만의 대결\tNNG',
#  '33\tNNG',
#  '33리\tNNG',
#  '355\tNNG',
#  '365일: 비밀의 여자\tNNG',
#  '3:10 투 유마\tNNG',
#  '3:10 투 유마 + 주노 + 어톤먼트\tNNG',
#  '3xFTM\tNNG',
#  '3개의 얼굴들\tNNG',
#  '3데이즈: 라스트 서바이벌\tNNG',
#  '3류들의 사랑\tNNG',
#  '3분 파트너\tNNG',
#  '3분 파트너-무삭제\tNNG',
#  '3인3색 여성감독 특별전\tNNG',
#  '3인의 사기단: 진범을 찾아라\tNNG',
#  '3인조\tNNG',
#  '4 브라더스\tNNG',
#  '4.4.4\tNNG',
#  '400 데이즈\tNNG',
#  '400: 제국의 부활\tNNG',
#  '400번의 구타\tNNG',
#  '40살까지 못해본 사람\tNNG',
#  '438일\tNNG',
#  '45년 후\tNNG',
#  '47 미터\tNNG',
#  '47미터 2\tNNG',
#  '48미터\tNNG',
#  '48시간: 지구 최후의 날\tNNG',
#  '4DX 문유\tNNG',
#  '4개월, 3주... 그리고 2일\tNNG',
#  '4교시 추리영역\tNNG',
#  '4등\tNNG',
#  '4명의 암살자\tNNG',
#  '4요일: 자살을 부르는 요일\tNNG',
#  '4월 실험영화 정기상영회\tNNG',
#  '4월 이야기\tNNG',
#  '4월은 너의 거짓말\tNNG',
#  '4인용 식탁\tNNG',
#  '4인의 무뢰한\tNNG',
#  '5 데이즈 오브 워\tNNG',
#  '5 투 7\tNNG',
#  '5.18 힌츠페터 스토리\tNNG',
#  '50/50\tNNG',
#  '500일의 썸머\tNNG',
#  '500일의 썸머+들어는 봤니? 모건 부부+의형제\tNNG',
#  '500일의 썸머+들어는봤니? 모건 부부+하모니\tNNG',
#  '500일의 썸머+용서는 없다+주유소 습격사건2\tNNG',
#  '50가지 그림자: 심연\tNNG',
#  '50가지 그림자: 해방\tNNG',
#  '50가지 욕망의 그림자\tNNG',
#  '50대 장모님의 불타는 사위사랑\tNNG',
#  '51구역\tNNG',
#  '577 프로젝트\tNNG',
#  '5x2\tNNG',
#  '5백만불의 사나이\tNNG',
#  '5분 운동 30분 섹스\tNNG',
#  '5월 1일\tNNG',
#  '5월 실험영화 정기상영회-브루스 엘더\tNNG',
#  '5월의 구름\tNNG',
#  '5일의 마중\tNNG',
#  '5쿼터\tNNG',
#  '6 웨이 투 다이\tNNG',
#  '600 마일\tNNG',
#  '60년전, 사선에서\tNNG',
#  '60만번의 트라이\tNNG',
#  '60일의 썸머\tNNG',
#  '69 식스티 나인\tNNG',
#  '69번가육덕진가정교사\tNNG',
#  '69세\tNNG',
#  '6년째 연애중\tNNG',
#  '6솔져스\tNNG',
#  '6시간: 원전대폭발\tNNG',
#  '6월 독립애니메이션 정기상영회-밥 좀 먹자,잠 좀 자자\tNNG',
#  '6월 실험영화 정기상영회-칼 브라운-감각의 응축\tNNG',
#  '6월의 뱀\tNNG',
#  '6월의 일기\tNNG',
#  '71 : 벨파스트의 눈물\tNNG',
#  '7공주 대리운전\tNNG',
#  '7광구\tNNG',
#  '7급 공무원\tNNG',
#  '7년-그들이 없는 언론\tNNG',
#  '7년의 밤\tNNG',
#  '7번방의 선물\tNNG',
#  '7번째 내가 죽던 날\tNNG',
#  '7번째 아들\tNNG',
#  '7월 32일\tNNG',
#  '7월7일\tNNG',
#  '7인의 말괄량이\tNNG',
#  '7인의 신부\tNNG',
#  '7인의 악인전\tNNG',
#  '7호실\tNNG',
#  '8 마일\tNNG',
#  '800\tNNG',
#  '800 블렛\tNNG',
#  '80일간의 세계 일주\tNNG',
#  '82년생 김지영\tNNG',
#  '84 태권 V\tNNG',
#  '88분\tNNG',
#  '8광구: 몬스터의 부활\tNNG',
#  '8년 전쟁: 이란 vs 이라크\tNNG',
#  '8년을 뛰어넘은 신부\tNNG',
#  '8명의 여인들\tNNG',
#  '8월 실험영화정기상영회-타수아오키\tNNG',
#  '8월의 일요일들\tNNG',
#  '8월의 크리스마스\tNNG',
#  '8월의 크리스마스(일본판)\tNNG',
#  '8인: 최후의 결사단\tNNG',
#  '8인의 수상한 신사들\tNNG',
#  '90분\tNNG',
#  '9:나인\tNNG',
#  '9명의 번역가\tNNG',
#  '9월 실험영화정기상영회\tNNG',
#  '9월의 어느날\tNNG',
#  'A 계획 속집\tNNG',
#  'A-특공대\tNNG',
#  'A-특공대+베스트 키드+유령작가\tNNG',
#  'A.I.\tNNG',
#  'AISFF 프로그램1\tNNG',
#  'AISFF 프로그램2\tNNG',
#  'AISFF 프로그램3\tNNG',
#  'AS센터 대신맨\tNNG',
#  'AV 아이돌\tNNG',
#  'AV 아이돌 일본제일전 도전기\tNNG',
#  'AV 여배우의 직장 체험기\tNNG',
#  'AV스타: 과거를 지워주세요\tNNG',
#  'AV스타납치사건\tNNG',
#  'AV스타의 질펀한 실습\tNNG',
#  'AV제작사의 여직원\tNNG',
#  'A형젖큰여자친구\tNNG',
#  'BB프로젝트\tNNG',
#  'BJ노는이모\tNNG',
#  'BJ노는이모2\tNNG',
#  'B급 며느리\tNNG',
#  'B급 청춘\tNNG',
#  'B컷\tNNG',
#  'B형 남자친구\tNNG',
#  'B형물많고화끈한처제\tNNG',
#  'B형물많고화끈한처제-무삭제\tNNG',
#  'C+ 탐정\tNNG',
#  'CCTV\tNNG',
#  'CJ7:장강7호\tNNG',
#  'CQN 한국영화앵콜전\tNNG',
#  'CQN 할로윈 무비 파티\tNNG',
#  'D-day-어느날 갑자기 세번째 이야기\tNNG',
#  'DC 리그 오브 슈퍼-펫\tNNG',
#  'DMZ, 비무장지대\tNNG',
#  'DOA\tNNG',
#  'D컵 여형사-가슴으로 느껴져요\tNNG',
#  'D컵여자친구\tNNG',
#  'D컵여자친구-무삭제\tNNG',
#  'EBS친구들 씽씽 댄스파티\tNNG',
#  'EIDF-다큐멘터리 정신상 수상작\tNNG',
#  'EIDF-대상수상작\tNNG',
#  'EIDF-시청자상 수상작\tNNG',
#  'EIDF-심사위원 특별상 수상작\tNNG',
#  'EX-Choice 1 소_극\tNNG',
#  'EX-Choice 2 비_극\tNNG',
#  'EX-Choice 3 소비극\tNNG',
#  'EX-Choice 4 선택극\tNNG',
#  'EX-Live 1-무비 콘서트 III\tNNG',
#  'EX-Live 2 존 케이지 스페셜 : 퍼포먼스\tNNG',
#  'EX-Now 경쟁 1\tNNG',
#  'EX-Now 경쟁 2\tNNG',
#  'EX-Now 경쟁 4\tNNG',
#  'EX-Now 경쟁 5\tNNG',
#  'EX-Now 경쟁 6\tNNG',
#  'EX-Retro 에비게일 차일드 1\tNNG',
#  'EX-Retro 에비게일 차일드 2\tNNG',
#  'EX-Retro 에비게일 차일드 3\tNNG',
#  'F.O.E.: 에프.오.이.\tNNG',
#  'F20\tNNG',
#  'FBI 데스트랩\tNNG',
#  'Full Moon day 씨네큐브 영화축제\tNNG',
#  'F컵 거유녀의 이중 생활: 매춘\tNNG',
#  'F컵 거유녀의 잠입 수사\tNNG',
#  'F컵 거유의 육덕녀\tNNG',
#  'F컵 거유의 육덕녀 무삭제판\tNNG',
#  'F컵 옆집 부인의 질펀한 하루\tNNG',
#  'G-포스: 기니피그 특공대\tNNG',
#  'GP 506\tNNG',
#  'GROW: 인피니트의 리얼 청춘 라이프\tNNG',
#  'G컵 새 엄마:달아오른 날\tNNG',
#  'H2: 어느 살인마의 가족이야기\tNNG',
#  'H컵 이상 거유 여배우\tNNG',
#  'I AM\tNNG',
#  'IS 탈출\tNNG',
#  'Indi-Visual 제이 로젠블라트 1\tNNG',
#  'Indi-Visual 제이 로젠블라트 2\tNNG',
#  'Indi-Visual 진 리오타\tNNG',
#  'J-무비페스티벌 (버라이어티 나인 J - 무비페스티벌)\tNNG',
#  'JLG/JLG 고다르의 자화상 특별전-사랑의 찬가\tNNG',
#  'JSA 남북공동초등학교\tNNG',
#  'Jam Docu 강정\tNNG',
#  'K 미싱 킹즈\tNNG',
#  'K-19\tNNG',
#  'K-20 괴도가면\tNNG',
#  'K2\tNNG',
#  'KBS 프리미어 영화 페스티벌\tNNG',
#  'K클래식 제너레이션\tNNG',
#  'LA 대지진\tNNG',
#  'LA: 볼케이노칼립스\tNNG',
#  'Lab Program 1\tNNG',
#  'Lab Program 2\tNNG',
#  'Lab Program 3\tNNG',
#  'M 버터 플라이\tNNG',
#  'MB의 추억\tNNG',
#  'MR. 후아유\tNNG',
#  'Mr.로빈 꼬시기\tNNG',
#  'Mr.스타벅\tNNG',
#  'Mr.아이돌\tNNG',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG',
#  'NCN Cinema 특별전\tNNG',
#  'O.J. 심슨 사건 파일\tNNG',
#  'OL의 성\tNNG',
#  'O형수박가슴가정부\tNNG',
#  'O형수박가슴가정부-무삭제\tNNG',
#  'P.S 온리 유\tNNG',
#  'P.S. 걸\tNNG',
#  'P.S. 걸 무삭제\tNNG',
#  'P.S. 아이 러브 유\tNNG',
#  'PMC: 더 벙커\tNNG',
#  'R.I.P.D. : 알.아이.피.디.\tNNG',
#  'R2B: 리턴투베이스\tNNG',
#  'REC 알이씨\tNNG',
#  'S 다이어리\tNNG',
#  'S 중독자의 고백\tNNG',
#  'SICAF2007서울국제만화애니페스티벌\tNNG',
#  'SIFF2008_다큐멘터리 특별초청\tNNG',
#  'SIFF2008_해외초청1\tNNG',
#  'SIFF2008_해외초청2\tNNG',
#  'SIFF2008_해외초청3\tNNG',
#  'SIFF2008_해외초청4\tNNG',
#  'SM_음탕한 욕망\tNNG',
#  'SM작가\tNNG',
#  'SNS 러브\tNNG',
#  'SNS 불륜 집착 유부녀\tNNG',
#  'SX 테잎\tNNG',
#  'S걸의 덫\tNNG',
#  'S러버\tNNG',
#  'T-34\tNNG',
#  'U.F.O.\tNNG',
#  'UFO 스케치\tNNG',
#  'V/H/S/2: 악마를 부르는 비디오\tNNG',
#  'V/H/S:죽음을 부르는 비디오\tNNG',
#  'VJ의 은밀한 사생활\tNNG',
#  '[EIDF2011]마리아가 사는 방법+태양 아래 흐르는 소리\tNNG',
#  '[EIDF2011]비바 마리아+사운드 라이트 레볼루션\tNNG',
#  '[EIDF2011]펠란케의 사람들+잔인한 계절\tNNG',
#  '[EXiS2010]EX-Now 1\tNNG',
#  '[EXiS2010]EX-Now 2\tNNG',
#  '[EXiS2010]EX-Now 4\tNNG',
#  '[EXiS2010]EX-Now 5\tNNG',
#  '[EXiS2010]EX-Now 6\tNNG',
#  '[EXiS2010]비바 페스티벌 1\tNNG',
#  'n번째 이별 중\tNNG',
#  'pm 11:14\tNNG',
#  '新극장판 이니셜D: 레전드3 -몽현-\tNNG',
#  '犬견 : 버려진 아이들\tNNG',
#  '가가린\tNNG',
#  '가구야공주 이야기\tNNG',
#  '가까이서 본 기차\tNNG',
#  '가나의 혼인잔치: 언약\tNNG',
#  '가난한 새댁 : 몸으로 내는 월세\tNNG',
#  '가능한 변화들\tNNG',
#  '가든\tNNG',
#  '가디언\tNNG',
#  '가디언스\tNNG',
#  '가디언의 전설\tNNG',
#  '가디언즈\tNNG',
#  '가디언즈 오브 갤럭시\tNNG',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG',
#  '가라, 가라 두 번째 처녀\tNNG',
#  '가라데 파이터\tNNG',
#  '가라데로 죽여라\tNNG',
#  '가래떡의 맛: 감독판\tNNG',
#  '가려진 시간\tNNG',
#  '가루지기\tNNG',
#  '가루지기: 변강쇠 더 비기닝\tNNG',
#  '가루지기: 변강쇠 더 비기닝 - 무삭제판\tNNG',
#  '가르시아\tNNG',
#  '가름워즈: 마지막 예언자\tNNG',
#  '가면\tNNG',
#  '가면-감춰진 진실\tNNG',
#  '가면속의 아리아\tNNG',
#  '가면의 정사\tNNG',
#  '가문의 부활 - 가문의 영광3\tNNG',
#  '가문의 영광4 - 가문의 수난\tNNG',
#  '가문의 영광5 - 가문의 귀환\tNNG',
#  '가문의 위기(가문의 영광2)\tNNG',
#  '가미카제\tNNG',
#  '가발\tNNG',
#  '가버나움\tNNG',
#  '가베\tNNG',
#  '가벼운 잠\tNNG',
#  '가부와 메이 이야기\tNNG',
#  '가비\tNNG',
#  '가슴 노출을 허하라!\tNNG',
#  '가슴 배구단\tNNG',
#  '가슴 큰 가인\tNNG',
#  '가슴 큰 가인 - 무삭제판\tNNG',
#  '가슴 큰 그녀:질펀한 마사지\tNNG',
#  '가슴 큰 뒷집소녀\tNNG',
#  '가슴 큰 새 누나\tNNG',
#  '가슴 큰 새 누나 2\tNNG',
#  '가슴 큰 새엄마 루미\tNNG',
#  '가슴 큰 앞집 소녀\tNNG',
#  '가슴 큰 여대생\tNNG',
#  '가슴 큰 여동생\tNNG',
#  '가슴 큰 여자선배\tNNG',
#  '가슴 큰 여자선배 무삭제\tNNG',
#  '가슴 큰 여자친구\tNNG',
#  '가슴 큰 여자친구 무삭제판\tNNG',
#  '가슴 큰 연주\tNNG',
#  '가슴 큰 옆집 소녀\tNNG',
#  '가슴 큰 울 엄마\tNNG',
#  '가슴 큰 울 엄마 2\tNNG',
#  '가슴 큰 처제\tNNG',
#  '가슴 큰 처제-무삭제판\tNNG',
#  '가슴 큰 초희\tNNG',
#  '가슴 큰 초희 - 무삭제판\tNNG',
#  '가슴 큰 친구 여친\tNNG',
#  '가슴 큰 친구여친 무삭제\tNNG',
#  '가슴 큰 태희\tNNG',
#  '가슴 큰 태희-무삭제판\tNNG',
#  '가슴 큰 형수\tNNG',
#  '가슴 큰 형수-무삭제판\tNNG',
#  '가슴에 돋는 칼로 슬픔을 자르고\tNNG',
#  '가슴을 탐하는 남자들\tNNG',
#  '가슴이 떨리는 건 너 때문\tNNG',
#  '가슴큰누나들\tNNG',
#  '가슴큰누나들-무삭제\tNNG',
#  '가슴큰며느리\tNNG',
#  '가슴큰며느리-무삭제\tNNG',
#  '가슴큰새엄마\tNNG',
#  '가슴큰새엄마-무삭제\tNNG',
#  '가슴큰엄마들\tNNG',
#  '가슴큰엄마들-무삭제\tNNG',
#  '가슴큰엄마친구\tNNG',
#  '가슴큰엄마친구-무삭제\tNNG',
#  '가슴큰자매들\tNNG',
#  '가슴큰자매들 - 무삭제\tNNG',
#  '가슴큰친구누나들\tNNG',
#  '가슴큰친구누나들-무삭제\tNNG',
#  '가시\tNNG',
#  '가시꽃\tNNG',
#  '가싶녀\tNNG',
#  '가위 : 수면마비의 기억\tNNG',
#  '가위손\tNNG',
#  '가을 소나타\tNNG',
#  '가을 우체국\tNNG',
#  '가을날의 동화\tNNG',
#  '가을날의 재회\tNNG',
#  '가을로\tNNG',
#  '가을비 우산속에\tNNG',
#  '가을의 마티네\tNNG',
#  '가을의 전설\tNNG',
#  '가자 장미여관으로 4\tNNG',
#  '가자 장미여관으로 4 - 무삭제판\tNNG',
#  '가자! 장미여관으로 2 - 갈증\tNNG',
#  '가자! 장미여관으로 3 - 방황\tNNG',
#  '가자! 장미여관으로 3 - 방황 무삭제 감독판\tNNG',
#  '가자, 장미여관으로\tNNG',
#  '가장 따뜻한 색, 블루\tNNG',
#  '가장 보통의 연애\tNNG',
#  '가재가 노래하는 곳\tNNG',
#  '가정교사 길들이기\tNNG',
#  '가정교사-맛있는 섹스 비밀 수업\tNNG',
#  '가정교사: 앞집 아줌마의 수업\tNNG',
#  '가정교사: 하고 싶은 여자\tNNG',
#  '가정교사:만져주기\tNNG',
#  '가정교사의 맛있는 수업\tNNG',
#  '가정교사의 비밀수업\tNNG',
#  '가정교사의 위험한 방문\tNNG',
#  '가정부 길들이기\tNNG',
#  '가정부 길들이기 무삭제판\tNNG',
#  '가정부와의 불륜\tNNG',
#  '가정부의 맛\tNNG',
#  '가정부의 목적\tNNG',
#  '가정부의 목적 무삭제판\tNNG',
#  '가정부의 손맛 감독판\tNNG',
#  '가정부의 유혹\tNNG',
#  '가져선 안될 비밀\tNNG',
#  '가족\tNNG',
#  '가족 연애사\tNNG',
#  '가족사진\tNNG',
#  '가족상속괴담\tNNG',
#  '가족시네마\tNNG',
#  '가족은 괴로워3: 아내여 장미처럼\tNNG',
#  '가족의 나라\tNNG',
#  '가족의 색깔\tNNG',
#  '가족의 재구성\tNNG',
#  '가족의 탄생\tNNG',
#  '가족이 되기까지\tNNG',
#  '가치 캅시다\tNNG',
#  '가투의 연날리기\tNNG',
#  '가필드\tNNG',
#  '가필드 2\tNNG',
#  '가필드 펫 포스 3D\tNNG',
#  '가필드-마법의 샘물\tNNG',
#  '각설탕\tNNG',
#  '각시탈\tNNG',
#  '간 큰 가족\tNNG',
#  '간기남\tNNG',
#  '간디\tNNG',
#  '간병인의 황제서비스\tNNG',
#  '간신\tNNG',
#  '간음:위험한 유부녀들\tNNG',
#  '간이역\tNNG',
#  '간증\tNNG',
#  '간첩\tNNG',
#  '간첩 리철진\tNNG',
#  '간츠\tNNG',
#  '간츠: 오\tNNG',
#  '간츠: 퍼펙트 앤서\tNNG',
#  '간통 : 섹스 회춘 료칸\tNNG',
#  '간통: 사장님의 아내\tNNG',
#  '간호사와 음란 마사지\tNNG',
#  '간호중\tNNG',
#  '갇힌 여인\tNNG',
#  '갈까부다\tNNG',
#  '갈리폴리 상륙작전\tNNG',
#  '갈리폴리: 최악의 상륙작전\tNNG',
#  '갈매기\tNNG',
#  '갈증\tNNG',
#  '감금당한 청순미인의 절정\tNNG',
#  '감금당해 범해지는 청순미인\tNNG',
#  '감금의 시간\tNNG',
#  '감금의 시간 2 무삭제\tNNG',
#  '감금의 정사\tNNG',
#  '감금일지-메이드\tNNG',
#  '감기\tNNG',
#  '감당이 안되는 욕정녀\tNNG',
#  '감독 미카엘 하네케\tNNG',
#  '감동주의보\tNNG',
#  '감바의 대모험\tNNG',
#  '감성에 젖은 음대선생님\tNNG',
#  '감시자들\tNNG',
#  '감염: 지구 최후의 날\tNNG',
#  '감옥정사\tNNG',
#  '감옥풍운\tNNG',
#  '감자\tNNG',
#  '감자심포니\tNNG',
#  '감쪽같은 그녀\tNNG',
#  '감출 수 없는 본능-몰카\tNNG',
#  '갑질당하는 육덕가정부\tNNG',
#  '갑질섹스-색기\tNNG',
#  '갓 앤 몬스터\tNNG',
#  '갓 오브 이집트\tNNG',
#  '갓 헬프 더 걸\tNNG',
#  '갓길로 달리는 코뿔소\tNNG',
#  '갓센드\tNNG',
#  '갓즈 포켓\tNNG',
#  '갓파 쿠와 여름방학을\tNNG',
#  '강간 몰카 유출 사건\tNNG',
#  '강남 1970\tNNG',
#  '강남 며느리\tNNG',
#  '강력 3반\tNNG',
#  '강력 범죄\tNNG',
#  '강령\tNNG',
#  '강릉\tNNG',
#  '강변호텔\tNNG',
#  '강시: 리거모티스\tNNG',
#  '강시선생 -일미도인\tNNG',
#  '강시선생 2\tNNG',
#  '강시선생 3 - 영환도사\tNNG',
#  '강아지 삼총사\tNNG',
#  '강원도의 힘\tNNG',
#  '강을 건너는 사람들\tNNG',
#  '강적\tNNG',
#  '강제 섹스:거절하다 신음\tNNG',
#  '강제로 당하는 새엄마\tNNG',
#  '강제섹스: 그 남자의 섹스방식\tNNG',
#  '강철대오:구국의 철가방\tNNG',
#  '강철비\tNNG',
#  '강철비2 : 정상회담 확장판\tNNG',
#  '강철비2: 정상회담\tNNG',
#  '강철의 연금술사 : 미로스의 성스러운 별\tNNG',
#  '강철중+크로싱+쿵푸 팬더\tNNG',
#  '강철중: 공공의 적 1-1\tNNG',
#  '강철중:공공의 적1-1+인크레더블 헐크+겟 스마트\tNNG',
#  '강한 칼: 도도견혈\tNNG',
#  '강호\tNNG',
#  '강호아녀\tNNG',
#  '강호의 무림신공\tNNG',
#  '강호제일검 금강철선\tNNG',
#  '같은 달을 보고 있다\tNNG',
#  '같은 속옷을 입는 두 여자\tNNG',
#  '개 같은 것들\tNNG',
#  '개: dog eat dog\tNNG',
#  '개같은 날의 오후\tNNG',
#  '개같은 내인생\tNNG',
#  '개구리왕국\tNNG',
#  '개구리왕국 2\tNNG',
#  '개구리중사 케로로\tNNG',
#  '개구쟁이 스머프\tNNG',
#  '개구쟁이 스머프 2\tNNG',
#  '개그 더 크라운\tNNG',
#  '개그맨\tNNG',
#  '개들의 섬\tNNG',
#  '개들의 전쟁\tNNG',
#  '개똥이\tNNG',
#  '개를 훔치는 완벽한 방법\tNNG',
#  '개벽\tNNG',
#  '개선문\tNNG',
#  '개에게 처음 이름을 지어준 날\tNNG',
#  '개와 늑대 사이의 시간\tNNG',
#  '개인교수 2014\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법(무삭제)\tNNG',
#  '개인교수 : 성적 올리기\tNNG',
#  '개인교수 : 성적 올리기 무삭제\tNNG',
#  '개인교수 : 세 여자의 섹스수업\tNNG',
#  '개인교수 : 여친 만족 시키기\tNNG',
#  '개인교수 : 여친 만족 시키기 무삭제\tNNG',
#  '개인교수: 심화학습\tNNG',
#  '개인교수: 심화학습 (무삭제)\tNNG',
#  '개인교습\tNNG',
#  '개인교습: 사촌여동생\tNNG',
#  '개인레슨\tNNG',
#  '개인영업 : 업소녀가 된 아내\tNNG',
#  '개인지도:붓으로 그리는 황홀경\tNNG',
#  '갤럭시 히어로즈: 라쳇 앤 클랭크\tNNG',
#  '갤로우즈\tNNG',
#  '갤로워커: 블레이드의 귀환\tNNG',
#  '갤버스턴\tNNG',
#  '갬빗\tNNG',
#  '갯마을\tNNG',
#  '갱\tNNG',
#  '갱 브라더스: 마지막 대결\tNNG',
#  '갱경떡삥이\tNNG',
#  '갱스터 초치\tNNG',
#  '거근이 좋아\tNNG',
#  '거기엔 래퍼가 없다\tNNG',
#  '거꾸로 된 파테마\tNNG',
#  '거대 불개미의 습격\tNNG',
#  '거대말벌의 습격\tNNG',
#  '거대한 서부\tNNG',
#  '거래완료\tNNG',
#  '거래처 여직원\tNNG',
#  '거룩한 계보\tNNG',
#  '거룩한 분노\tNNG',
#  '거룩한 소녀 마리아\tNNG',
#  '거리의 보안관\tNNG',
#  '거미숲\tNNG',
#  '거미의 계략\tNNG',
#  '거미의 땅\tNNG',
#  '거미줄에 걸린 소녀\tNNG',
#  '거부하다 신음하는 여자\tNNG',
#  '거북이 달린다\tNNG',
#  '거북이도 난다\tNNG',
#  '거울나라의 앨리스\tNNG',
#  '거유 며느리의 은밀한 일탈\tNNG',
#  '거유 며느리의 친정나들이\tNNG',
#  '거유 바니걸 리나\tNNG',
#  '거유 새엄마와 형제들\tNNG',
#  '거유 여사장의 약점\tNNG',
#  '거유 와이프:남편 대신 상사와\tNNG',
#  '거유 유부녀의 오일 마사지\tNNG',
#  '거유 장모와 실제로 느끼는 사위\tNNG',
#  '거유 치과 간호사\tNNG',
#  '거유 치나미 사쿠라의 아찔 유혹\tNNG',
#  '거유 칸나의 질펀한 서비스\tNNG',
#  '거유간호사 폭유간호사\tNNG',
#  '거유녀들의 아찔한 가슴골\tNNG',
#  '거유녀의 젖어버린 작업복\tNNG',
#  '거유미녀 서큐버스2\tNNG',
#  '거유이발소-어서오세요\tNNG',
#  '거인\tNNG',
#  '거지의 오페라\tNNG',
#  '거짓말\tNNG',
#  '거짓말 2014\tNNG',
#  '거짓말 2018: 감독판\tNNG',
#  '거짓말 : 여자 모델의 섹스\tNNG',
#  '거짓말 : 여자 모델의 섹스 무삭제\tNNG',
#  '거짓말 섹스가 좋아\tNNG',
#  '거짓말 섹스가 좋아2\tNNG',
#  '거짓말 애인-감독판\tNNG',
#  '거짓의\tNNG',
#  '거친 녀석들\tNNG',
#  '거친 섹스에 빠진 그녀들\tNNG',
#  '거칠마루\tNNG',
#  '거침없이 쏴라! 슛뎀업\tNNG',
#  '걱정말아요\tNNG',
#  '건\tNNG',
#  '건 샤이\tNNG',
#  '건달 가정부\tNNG',
#  '건달티처\tNNG',
#  '건마의 신: 어린 아내의 알바\tNNG',
#  '건양강호: 운뢰검법의 비밀\tNNG',
#  '건우먼\tNNG',
#  '건즈 아킴보\tNNG',
#  '건즈 포 하이어\tNNG',
#  '건축학개론\tNNG',
#  '건파우더 밀크셰이크\tNNG',
#  '걷기 좋은 날\tNNG',
#  '걷기왕\tNNG',
#  '걸\tNNG',
#  '걸 아바타\tNNG',
#  '걸 온 더 브릿지\tNNG',
#  '걸 온 더 트레인\tNNG',
#  '걸 위드 더 카메라\tNNG',
#  '걸 인 더 포토그래프\tNNG',
#  '걸리버 리턴즈\tNNG',
#  '걸리버 여행기\tNNG',
#  '걸스\tNNG',
#  '걸스 곤 데드\tNNG',
#  '걸스 나잇\tNNG',
#  '걸스 스텝\tNNG',
#  '걸스 온 탑2\tNNG',
#  '걸스카우트\tNNG',
#  '걸어도 걸어도\tNNG',
#  '걸작\tNNG',
#  '걸즈 앤 판처 극장판\tNNG',
#  '걸즈 앤 판처 제\u200b 63회 전차도 전국 고교생 대회\tNNG',
#  '걸즈 앤 판처 최종장\tNNG',
#  '걸즈 앤 판처 최종장 제1화\tNNG',
#  '걸즈 앤 판처 최종장 제3화\tNNG',
#  '걸캅스\tNNG',
#  '걸캅스 누나들\tNNG',
#  '걸프렌즈\tNNG',
#  '걸후드\tNNG',
#  '검객\tNNG',
#  '검객풍운\tNNG',
#  '검사외전\tNNG',
#  '검우강호\tNNG',
#  '검은 고양이 흰 고양이\tNNG',
#  '검은 땅의 소녀와\tNNG',
#  '검은 물밑에서\tNNG',
#  '검은 사제들\tNNG',
#  '검은 사제들: 지옥의 문\tNNG',
#  '검은 숲\tNNG',
#  '검은 여름\tNNG',
#  '검은 집\tNNG',
#  '검은 집: 죽음을 보는 눈\tNNG',
#  '검은비: 악의연대기\tNNG',
#  '검은손\tNNG',
#  '겁나는 여친의 완벽한 비밀\tNNG',
#  '겁쟁이 페달: 더 무비\tNNG',
#  '겁쟁이 페달: 리라이드\tNNG',
#  '겁쟁이 페달: 리로드\tNNG',
#  '겁쟁이 페달: 스페어 바이크\tNNG',
#  '겁탈당한 유부녀\tNNG',
#  '겁탈당한 유부녀 무삭제판\tNNG',
#  '게드전기 : 어스시의 전설\tNNG',
#  '게발트 파이브:구타본능\tNNG',
#  '게스트하우스\tNNG',
#  '게스후\tNNG',
#  '게이머\tNNG',
#  '게이샤 하우스\tNNG',
#  '게이샤:격정정사\tNNG',
#  ...]

# %%
# new_user_dict = list(set(new_user_dict))
# new_user_dict

# %%
# print(len(new_user_dict))
# new_user_dict

# %%
# from collections import OrderedDict

# new_user_dict = list(OrderedDict.fromkeys(new_user_dict))
# new_user_dict
# Out:
# ['0시\tNNG',
#  '1시\tNNG',
#  '2시\tNNG',
#  '3시\tNNG',
#  '4시\tNNG',
#  '5시\tNNG',
#  '6시\tNNG',
#  '7시\tNNG',
#  '8시\tNNG',
#  '9시\tNNG',
#  '10시\tNNG',
#  '11시\tNNG',
#  '12시\tNNG',
#  '13시\tNNG',
#  '14시\tNNG',
#  '15시\tNNG',
#  '16시\tNNG',
#  '17시\tNNG',
#  '18시\tNNG',
#  '19시\tNNG',
#  '20시\tNNG',
#  '21시\tNNG',
#  '22시\tNNG',
#  '23시\tNNG',
#  '24시\tNNG',
#  '0분\tNNG',
#  '1분\tNNG',
#  '2분\tNNG',
#  '3분\tNNG',
#  '4분\tNNG',
#  '5분\tNNG',
#  '6분\tNNG',
#  '7분\tNNG',
#  '8분\tNNG',
#  '9분\tNNG',
#  '10분\tNNG',
#  '11분\tNNG',
#  '12분\tNNG',
#  '13분\tNNG',
#  '14분\tNNG',
#  '15분\tNNG',
#  '16분\tNNG',
#  '17분\tNNG',
#  '18분\tNNG',
#  '19분\tNNG',
#  '20분\tNNG',
#  '21분\tNNG',
#  '22분\tNNG',
#  '23분\tNNG',
#  '24분\tNNG',
#  '25분\tNNG',
#  '26분\tNNG',
#  '27분\tNNG',
#  '28분\tNNG',
#  '29분\tNNG',
#  '30분\tNNG',
#  '31분\tNNG',
#  '32분\tNNG',
#  '33분\tNNG',
#  '34분\tNNG',
#  '35분\tNNG',
#  '36분\tNNG',
#  '37분\tNNG',
#  '38분\tNNG',
#  '39분\tNNG',
#  '40분\tNNG',
#  '41분\tNNG',
#  '42분\tNNG',
#  '43분\tNNG',
#  '44분\tNNG',
#  '45분\tNNG',
#  '46분\tNNG',
#  '47분\tNNG',
#  '48분\tNNG',
#  '49분\tNNG',
#  '50분\tNNG',
#  '51분\tNNG',
#  '52분\tNNG',
#  '53분\tNNG',
#  '54분\tNNG',
#  '55분\tNNG',
#  '56분\tNNG',
#  '57분\tNNG',
#  '58분\tNNG',
#  '59분\tNNG',
#  '60분\tNNG',
#  '1월\tNNG',
#  '2월\tNNG',
#  '3월\tNNG',
#  '4월\tNNG',
#  '5월\tNNG',
#  '6월\tNNG',
#  '7월\tNNG',
#  '8월\tNNG',
#  '9월\tNNG',
#  '10월\tNNG',
#  '11월\tNNG',
#  '12월\tNNG',
#  '1일\tNNG',
#  '2일\tNNG',
#  '3일\tNNG',
#  '4일\tNNG',
#  '5일\tNNG',
#  '6일\tNNG',
#  '7일\tNNG',
#  '8일\tNNG',
#  '9일\tNNG',
#  '10일\tNNG',
#  '11일\tNNG',
#  '12일\tNNG',
#  '13일\tNNG',
#  '14일\tNNG',
#  '15일\tNNG',
#  '16일\tNNG',
#  '17일\tNNG',
#  '18일\tNNG',
#  '19일\tNNG',
#  '20일\tNNG',
#  '21일\tNNG',
#  '22일\tNNG',
#  '23일\tNNG',
#  '24일\tNNG',
#  '25일\tNNG',
#  '26일\tNNG',
#  '27일\tNNG',
#  '28일\tNNG',
#  '29일\tNNG',
#  '30일\tNNG',
#  '31일\tNNG',
#  '월요일\tNNG',
#  '화요일\tNNG',
#  '수요일\tNNG',
#  '목요일\tNNG',
#  '금요일\tNNG',
#  '토요일\tNNG',
#  '일요일\tNNG',
#  '#살아있다\tNNG',
#  '#아이엠히어\tNNG',
#  '#위왓치유\tNNG',
#  '...ing\tNNG',
#  '0.0MHz\tNNG',
#  '007 노 타임 투 다이\tNNG',
#  '007 북경특급 2\tNNG',
#  '007 스카이폴\tNNG',
#  '007 스펙터\tNNG',
#  '007 제2편 : 위기일발\tNNG',
#  '007 카지노 로얄\tNNG',
#  '007 퀀텀 오브 솔러스\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+뱅크 잡\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+순정만화\tNNG',
#  '009 사이보그\tNNG',
#  '10 미니츠 곤\tNNG',
#  '10 바이 10\tNNG',
#  '10 아이템 오어 레스\tNNG',
#  '10,000 BC\tNNG',
#  '10,000 BC + 어메이징 그레이스 + 댄 인 러브\tNNG',
#  '10,000BC+마이 블루베리 나이츠+연을 쫓는 아이\tNNG',
#  '10,000BC+연을 쫓는 아이+마이 블루베리 나이츠\tNNG',
#  '10,000km(만 킬로미터)\tNNG',
#  '100 피트\tNNG',
#  '100% 울프: 푸들이 될 순 없어\tNNG',
#  '1000 : 최후의 전사들\tNNG',
#  '100년 동안의 히틀러\tNNG',
#  '100미터\tNNG',
#  '100일 동안 100가지로 100퍼센트 행복찾기\tNNG',
#  '10년\tNNG',
#  '10억\tNNG',
#  '10일간의 원나잇 스탠드\tNNG',
#  '10층의 모기\tNNG',
#  '117편의 러브레터\tNNG',
#  '11월 실험영화 정기 상영회\tNNG',
#  '11인의 카우보이\tNNG',
#  '12 솔져스\tNNG',
#  '120 BPM\tNNG',
#  '125 전승철\tNNG',
#  '127시간\tNNG',
#  '12번째 솔저\tNNG',
#  '12시에 열리는 쾌락의 문\tNNG',
#  '12월실험영화상영회-야수토 유라 특별전\tNNG',
#  '12인의 하숙생\tNNG',
#  '12피트\tNNG',
#  '13 이어리\tNNG',
#  '13 자메티\tNNG',
#  '13구역\tNNG',
#  '13구역: 얼티메이텀\tNNG',
#  '13년의 공백\tNNG',
#  '13번째 전사\tNNG',
#  '13시간\tNNG',
#  '13인의 자객\tNNG',
#  '13일의 금요일\tNNG',
#  '13일의 금요일: 더 파이널\tNNG',
#  '1408\tNNG',
#  '1492 콜럼버스\tNNG',
#  '14인의 여걸\tNNG',
#  '15소년 우주 표류기\tNNG',
#  '15소년 표류기: 해적섬을 탈출하라\tNNG',
#  '16세의 사운드트랙\tNNG',
#  '1724 기방난동사건\tNNG',
#  '17인의사자들\tNNG',
#  '18 BJ 하연의 화려한 테크닉\tNNG',
#  '18 걸그룹 승하의 눈치게임\tNNG',
#  '18 모델 리카의 화려한 외출\tNNG',
#  '18 성인배우 이수의 섹스 판타지\tNNG',
#  '18 섹시퀸 유진의 섹스 스캔들\tNNG',
#  '18 승하의 누워서 떡 먹기\tNNG',
#  '18 여대생 소라의 순결상실\tNNG',
#  '18 주아의 뜨거운 하루\tNNG',
#  '18 출사녀 화진의 미친 섹스\tNNG',
#  '18 하라의 맛있는 수업\tNNG',
#  '1812 나폴레옹 대전투\tNNG',
#  '1820: 잃어버린 제국의 비밀\tNNG',
#  '1850 길로틴 트레지디\tNNG',
#  '18: 우리들의 성장 느와르\tNNG',
#  '18금 아이돌 승하의 섹스 스캔들\tNNG',
#  '18금 아이돌 승하의 화려한 외출\tNNG',
#  '19 섹스 맛있는 속 궁합\tNNG',
#  '19-Nineteen\tNNG',
#  '1900년\tNNG',
#  '1917\tNNG',
#  '1919 유관순\tNNG',
#  '1940: 최강의 독일 전차부대\tNNG',
#  '1941\tNNG',
#  '1941: 세바스토폴 상륙작전\tNNG',
#  '1942: 언노운 배틀\tNNG',
#  '1942: 최정예특수부대 스페츠나츠\tNNG',
#  '1944\tNNG',
#  '1944 대전투\tNNG',
#  '1944 워 히어로\tNNG',
#  '1944: 인간병기\tNNG',
#  '1945 그레이트 워\tNNG',
#  '1945: 포인트 오브 노 리턴\tNNG',
#  '1975 킬링필드, 푸난\tNNG',
#  '1984 최동원\tNNG',
#  '1987\tNNG',
#  '1991, 봄\tNNG',
#  '1999, 면회\tNNG',
#  '19곰 테드\tNNG',
#  '19곰 테드 2\tNNG',
#  '19금 만남의 목적\tNNG',
#  '19금 불륜소설\tNNG',
#  '19금 불륜소설 무삭제판\tNNG',
#  '19금 비밀과외\tNNG',
#  '19금 섹스비디오\tNNG',
#  '19금 섹스비디오 무삭제 감독판\tNNG',
#  '19금 섹스의 늪 무삭특별판\tNNG',
#  '19금 연애소설\tNNG',
#  '19금 연애소설 무삭제판\tNNG',
#  '19금 절대섹스\tNNG',
#  '19금 정사: 말할 수 없는 비밀\tNNG',
#  '19금 특별한 정사\tNNG',
#  '19금 특별한 정사 무삭제 특별판\tNNG',
#  '19번가물많은여자친구\tNNG',
#  '1급기밀\tNNG',
#  '1박2일 소개팅\tNNG',
#  '1번가의 기적\tNNG',
#  '1번국도\tNNG',
#  '1월 단편 상상극장\tNNG',
#  '1월의 두 얼굴\tNNG',
#  '2 데이즈 인 뉴욕\tNNG',
#  '2%필름페스티발\tNNG',
#  '20 30 40\tNNG',
#  '2007 시네바캉스 서울\tNNG',
#  '2007 아시아나국제단편영화제\tNNG',
#  '2007 인디애니페스트\tNNG',
#  '2007 칸국제광고제 수상작 필름 페스티벌\tNNG',
#  '2007CJ중국영화제\tNNG',
#  '2008 광주국제영화제\tNNG',
#  '2008 음악 영화제\tNNG',
#  '2008 최강애니전\tNNG',
#  '2008년 시네마테크의 친구들 영화제\tNNG',
#  '2010 3D한국국제영화제\tNNG',
#  '2010 AISFF-개막식\tNNG',
#  '2010 AISFF-거장들의 패션필름\tNNG',
#  '2010 AISFF-국제경쟁1\tNNG',
#  '2010 AISFF-국제경쟁2\tNNG',
#  '2010 AISFF-국제경쟁3\tNNG',
#  '2010 AISFF-국제경쟁4\tNNG',
#  '2010 AISFF-국제경쟁5\tNNG',
#  '2010 AISFF-국제경쟁6\tNNG',
#  '2010 AISFF-국제경쟁7\tNNG',
#  '2010 AISFF-국제경쟁8\tNNG',
#  '2010 AISFF-메이드 바이 커머셜 디렉터스\tNNG',
#  '2010 AISFF-시상식\tNNG',
#  '2010 AISFF-여자는 두 번 플레이 한다\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 저팬\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 코리아\tNNG',
#  '2010 시네바캉스 서울\tNNG',
#  '2010 한-EU단편영화 교류전\tNNG',
#  '2010 한국영화아카데미 영화제\tNNG',
#  '2010년 시네마테크의 친구들 영화제\tNNG',
#  '2010칸국제광고제 수상작페스티벌\tNNG',
#  '2012\tNNG',
#  '2014 지구 최후의 날\tNNG',
#  '2017 동명이인 프로젝트\tNNG',
#  '2017복상사\tNNG',
#  '2020년 마지막 섹스\tNNG',
#  '2021 첫 섹스\tNNG',
#  '2023-09-11 00:00:00\tNNG',
#  '2025 지구전쟁: 얼리전스 오브 파워\tNNG',
#  '2035 매드 레이스\tNNG',
#  '2046\tNNG',
#  '2047 버추얼 레볼루션\tNNG',
#  '2047: 지구 최후의 날\tNNG',
#  '2067\tNNG',
#  '20대 같은 40대 미시녀\tNNG',
#  '20세기 소년\tNNG',
#  '20세기 소년 ; 최종장 - 우리들의 깃발\tNNG',
#  '20세기 소년+맘마미아+방콕 데인저러스\tNNG',
#  '20세기 소년-제2장: 마지막 희망\tNNG',
#  '20일밤, 그리고 비 오는 하루\tNNG',
#  '21\tNNG',
#  '21 그램\tNNG',
#  '21 브릿지: 테러 셧다운\tNNG',
#  '21 앤드 오버\tNNG',
#  '21살승하의아이돌비밀일기\tNNG',
#  '21살승하의아이돌비밀일기-무삭제\tNNG',
#  '21세기 우리 시대의 영화 특별전\tNNG',
#  '21세기의 기원\tNNG',
#  '22\tNNG',
#  '22 블렛\tNNG',
#  '22년 후의 고백\tNNG',
#  '22분: 아덴만 구출작전\tNNG',
#  '23 아이덴티티\tNNG',
#  '24 시티\tNNG',
#  '24살윤율의섹시한젖가슴\tNNG',
#  '24살윤율의섹시한젖가슴-무삭제\tNNG',
#  '24시간 달리는 쾌락 버스\tNNG',
#  '24주\tNNG',
#  '25시\tNNG',
#  '26년\tNNG',
#  '27번의 결혼리허설\tNNG',
#  '27번의 결혼리허설 + 마이 뉴 파트너 + 마이 블루베리 나이츠\tNNG',
#  '27번의 결혼리허설+10,000BC+밴티지 포인트\tNNG',
#  '28세 미성년\tNNG',
#  '28일 후\tNNG',
#  '2솔져스: 배틀필드\tNNG',
#  '2월 29일 - 어느날 갑자기 첫번째 이야기\tNNG',
#  '2차 노출\tNNG',
#  '2차 세계대전 타임트랙\tNNG',
#  '2차 송환\tNNG',
#  '2회 브라질 영화제: 시네마 노보 회고전\tNNG',
#  '3-4X10월\tNNG',
#  '3.5교시\tNNG',
#  '300\tNNG',
#  '300: 전사의 귀환\tNNG',
#  '300: 제국의 부활\tNNG',
#  '301, 302\tNNG',
#  '3022: 지구 대폭발\tNNG',
#  '3096일\tNNG',
#  '30년만의 대결\tNNG',
#  '33\tNNG',
#  '33리\tNNG',
#  '355\tNNG',
#  '365일: 비밀의 여자\tNNG',
#  '3:10 투 유마\tNNG',
#  '3:10 투 유마 + 주노 + 어톤먼트\tNNG',
#  '3xFTM\tNNG',
#  '3개의 얼굴들\tNNG',
#  '3데이즈: 라스트 서바이벌\tNNG',
#  '3류들의 사랑\tNNG',
#  '3분 파트너\tNNG',
#  '3분 파트너-무삭제\tNNG',
#  '3인3색 여성감독 특별전\tNNG',
#  '3인의 사기단: 진범을 찾아라\tNNG',
#  '3인조\tNNG',
#  '4 브라더스\tNNG',
#  '4.4.4\tNNG',
#  '400 데이즈\tNNG',
#  '400: 제국의 부활\tNNG',
#  '400번의 구타\tNNG',
#  '40살까지 못해본 사람\tNNG',
#  '438일\tNNG',
#  '45년 후\tNNG',
#  '47 미터\tNNG',
#  '47미터 2\tNNG',
#  '48미터\tNNG',
#  '48시간: 지구 최후의 날\tNNG',
#  '4DX 문유\tNNG',
#  '4개월, 3주... 그리고 2일\tNNG',
#  '4교시 추리영역\tNNG',
#  '4등\tNNG',
#  '4명의 암살자\tNNG',
#  '4요일: 자살을 부르는 요일\tNNG',
#  '4월 실험영화 정기상영회\tNNG',
#  '4월 이야기\tNNG',
#  '4월은 너의 거짓말\tNNG',
#  '4인용 식탁\tNNG',
#  '4인의 무뢰한\tNNG',
#  '5 데이즈 오브 워\tNNG',
#  '5 투 7\tNNG',
#  '5.18 힌츠페터 스토리\tNNG',
#  '50/50\tNNG',
#  '500일의 썸머\tNNG',
#  '500일의 썸머+들어는 봤니? 모건 부부+의형제\tNNG',
#  '500일의 썸머+들어는봤니? 모건 부부+하모니\tNNG',
#  '500일의 썸머+용서는 없다+주유소 습격사건2\tNNG',
#  '50가지 그림자: 심연\tNNG',
#  '50가지 그림자: 해방\tNNG',
#  '50가지 욕망의 그림자\tNNG',
#  '50대 장모님의 불타는 사위사랑\tNNG',
#  '51구역\tNNG',
#  '577 프로젝트\tNNG',
#  '5x2\tNNG',
#  '5백만불의 사나이\tNNG',
#  '5분 운동 30분 섹스\tNNG',
#  '5월 1일\tNNG',
#  '5월 실험영화 정기상영회-브루스 엘더\tNNG',
#  '5월의 구름\tNNG',
#  '5일의 마중\tNNG',
#  '5쿼터\tNNG',
#  '6 웨이 투 다이\tNNG',
#  '600 마일\tNNG',
#  '60년전, 사선에서\tNNG',
#  '60만번의 트라이\tNNG',
#  '60일의 썸머\tNNG',
#  '69 식스티 나인\tNNG',
#  '69번가육덕진가정교사\tNNG',
#  '69세\tNNG',
#  '6년째 연애중\tNNG',
#  '6솔져스\tNNG',
#  '6시간: 원전대폭발\tNNG',
#  '6월 독립애니메이션 정기상영회-밥 좀 먹자,잠 좀 자자\tNNG',
#  '6월 실험영화 정기상영회-칼 브라운-감각의 응축\tNNG',
#  '6월의 뱀\tNNG',
#  '6월의 일기\tNNG',
#  '71 : 벨파스트의 눈물\tNNG',
#  '7공주 대리운전\tNNG',
#  '7광구\tNNG',
#  '7급 공무원\tNNG',
#  '7년-그들이 없는 언론\tNNG',
#  '7년의 밤\tNNG',
#  '7번방의 선물\tNNG',
#  '7번째 내가 죽던 날\tNNG',
#  '7번째 아들\tNNG',
#  '7월 32일\tNNG',
#  '7월7일\tNNG',
#  '7인의 말괄량이\tNNG',
#  '7인의 신부\tNNG',
#  '7인의 악인전\tNNG',
#  '7호실\tNNG',
#  '8 마일\tNNG',
#  '800\tNNG',
#  '800 블렛\tNNG',
#  '80일간의 세계 일주\tNNG',
#  '82년생 김지영\tNNG',
#  '84 태권 V\tNNG',
#  '88분\tNNG',
#  '8광구: 몬스터의 부활\tNNG',
#  '8년 전쟁: 이란 vs 이라크\tNNG',
#  '8년을 뛰어넘은 신부\tNNG',
#  '8명의 여인들\tNNG',
#  '8월 실험영화정기상영회-타수아오키\tNNG',
#  '8월의 일요일들\tNNG',
#  '8월의 크리스마스\tNNG',
#  '8월의 크리스마스(일본판)\tNNG',
#  '8인: 최후의 결사단\tNNG',
#  '8인의 수상한 신사들\tNNG',
#  '90분\tNNG',
#  '9:나인\tNNG',
#  '9명의 번역가\tNNG',
#  '9월 실험영화정기상영회\tNNG',
#  '9월의 어느날\tNNG',
#  'A 계획 속집\tNNG',
#  'A-특공대\tNNG',
#  'A-특공대+베스트 키드+유령작가\tNNG',
#  'A.I.\tNNG',
#  'AISFF 프로그램1\tNNG',
#  'AISFF 프로그램2\tNNG',
#  'AISFF 프로그램3\tNNG',
#  'AS센터 대신맨\tNNG',
#  'AV 아이돌\tNNG',
#  'AV 아이돌 일본제일전 도전기\tNNG',
#  'AV 여배우의 직장 체험기\tNNG',
#  'AV스타: 과거를 지워주세요\tNNG',
#  'AV스타납치사건\tNNG',
#  'AV스타의 질펀한 실습\tNNG',
#  'AV제작사의 여직원\tNNG',
#  'A형젖큰여자친구\tNNG',
#  'BB프로젝트\tNNG',
#  'BJ노는이모\tNNG',
#  'BJ노는이모2\tNNG',
#  'B급 며느리\tNNG',
#  'B급 청춘\tNNG',
#  'B컷\tNNG',
#  'B형 남자친구\tNNG',
#  'B형물많고화끈한처제\tNNG',
#  'B형물많고화끈한처제-무삭제\tNNG',
#  'C+ 탐정\tNNG',
#  'CCTV\tNNG',
#  'CJ7:장강7호\tNNG',
#  'CQN 한국영화앵콜전\tNNG',
#  'CQN 할로윈 무비 파티\tNNG',
#  'D-day-어느날 갑자기 세번째 이야기\tNNG',
#  'DC 리그 오브 슈퍼-펫\tNNG',
#  'DMZ, 비무장지대\tNNG',
#  'DOA\tNNG',
#  'D컵 여형사-가슴으로 느껴져요\tNNG',
#  'D컵여자친구\tNNG',
#  'D컵여자친구-무삭제\tNNG',
#  'EBS친구들 씽씽 댄스파티\tNNG',
#  'EIDF-다큐멘터리 정신상 수상작\tNNG',
#  'EIDF-대상수상작\tNNG',
#  'EIDF-시청자상 수상작\tNNG',
#  'EIDF-심사위원 특별상 수상작\tNNG',
#  'EX-Choice 1 소_극\tNNG',
#  'EX-Choice 2 비_극\tNNG',
#  'EX-Choice 3 소비극\tNNG',
#  'EX-Choice 4 선택극\tNNG',
#  'EX-Live 1-무비 콘서트 III\tNNG',
#  'EX-Live 2 존 케이지 스페셜 : 퍼포먼스\tNNG',
#  'EX-Now 경쟁 1\tNNG',
#  'EX-Now 경쟁 2\tNNG',
#  'EX-Now 경쟁 4\tNNG',
#  'EX-Now 경쟁 5\tNNG',
#  'EX-Now 경쟁 6\tNNG',
#  'EX-Retro 에비게일 차일드 1\tNNG',
#  'EX-Retro 에비게일 차일드 2\tNNG',
#  'EX-Retro 에비게일 차일드 3\tNNG',
#  'F.O.E.: 에프.오.이.\tNNG',
#  'F20\tNNG',
#  'FBI 데스트랩\tNNG',
#  'Full Moon day 씨네큐브 영화축제\tNNG',
#  'F컵 거유녀의 이중 생활: 매춘\tNNG',
#  'F컵 거유녀의 잠입 수사\tNNG',
#  'F컵 거유의 육덕녀\tNNG',
#  'F컵 거유의 육덕녀 무삭제판\tNNG',
#  'F컵 옆집 부인의 질펀한 하루\tNNG',
#  'G-포스: 기니피그 특공대\tNNG',
#  'GP 506\tNNG',
#  'GROW: 인피니트의 리얼 청춘 라이프\tNNG',
#  'G컵 새 엄마:달아오른 날\tNNG',
#  'H2: 어느 살인마의 가족이야기\tNNG',
#  'H컵 이상 거유 여배우\tNNG',
#  'I AM\tNNG',
#  'IS 탈출\tNNG',
#  'Indi-Visual 제이 로젠블라트 1\tNNG',
#  'Indi-Visual 제이 로젠블라트 2\tNNG',
#  'Indi-Visual 진 리오타\tNNG',
#  'J-무비페스티벌 (버라이어티 나인 J - 무비페스티벌)\tNNG',
#  'JLG/JLG 고다르의 자화상 특별전-사랑의 찬가\tNNG',
#  'JSA 남북공동초등학교\tNNG',
#  'Jam Docu 강정\tNNG',
#  'K 미싱 킹즈\tNNG',
#  'K-19\tNNG',
#  'K-20 괴도가면\tNNG',
#  'K2\tNNG',
#  'KBS 프리미어 영화 페스티벌\tNNG',
#  'K클래식 제너레이션\tNNG',
#  'LA 대지진\tNNG',
#  'LA: 볼케이노칼립스\tNNG',
#  'Lab Program 1\tNNG',
#  'Lab Program 2\tNNG',
#  'Lab Program 3\tNNG',
#  'M 버터 플라이\tNNG',
#  'MB의 추억\tNNG',
#  'MR. 후아유\tNNG',
#  'Mr.로빈 꼬시기\tNNG',
#  'Mr.스타벅\tNNG',
#  'Mr.아이돌\tNNG',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG',
#  'NCN Cinema 특별전\tNNG',
#  'O.J. 심슨 사건 파일\tNNG',
#  'OL의 성\tNNG',
#  'O형수박가슴가정부\tNNG',
#  'O형수박가슴가정부-무삭제\tNNG',
#  'P.S 온리 유\tNNG',
#  'P.S. 걸\tNNG',
#  'P.S. 걸 무삭제\tNNG',
#  'P.S. 아이 러브 유\tNNG',
#  'PMC: 더 벙커\tNNG',
#  'R.I.P.D. : 알.아이.피.디.\tNNG',
#  'R2B: 리턴투베이스\tNNG',
#  'REC 알이씨\tNNG',
#  'S 다이어리\tNNG',
#  'S 중독자의 고백\tNNG',
#  'SICAF2007서울국제만화애니페스티벌\tNNG',
#  'SIFF2008_다큐멘터리 특별초청\tNNG',
#  'SIFF2008_해외초청1\tNNG',
#  'SIFF2008_해외초청2\tNNG',
#  'SIFF2008_해외초청3\tNNG',
#  'SIFF2008_해외초청4\tNNG',
#  'SM_음탕한 욕망\tNNG',
#  'SM작가\tNNG',
#  'SNS 러브\tNNG',
#  'SNS 불륜 집착 유부녀\tNNG',
#  'SX 테잎\tNNG',
#  'S걸의 덫\tNNG',
#  'S러버\tNNG',
#  'T-34\tNNG',
#  'U.F.O.\tNNG',
#  'UFO 스케치\tNNG',
#  'V/H/S/2: 악마를 부르는 비디오\tNNG',
#  'V/H/S:죽음을 부르는 비디오\tNNG',
#  'VJ의 은밀한 사생활\tNNG',
#  '[EIDF2011]마리아가 사는 방법+태양 아래 흐르는 소리\tNNG',
#  '[EIDF2011]비바 마리아+사운드 라이트 레볼루션\tNNG',
#  '[EIDF2011]펠란케의 사람들+잔인한 계절\tNNG',
#  '[EXiS2010]EX-Now 1\tNNG',
#  '[EXiS2010]EX-Now 2\tNNG',
#  '[EXiS2010]EX-Now 4\tNNG',
#  '[EXiS2010]EX-Now 5\tNNG',
#  '[EXiS2010]EX-Now 6\tNNG',
#  '[EXiS2010]비바 페스티벌 1\tNNG',
#  'n번째 이별 중\tNNG',
#  'pm 11:14\tNNG',
#  '新극장판 이니셜D: 레전드3 -몽현-\tNNG',
#  '犬견 : 버려진 아이들\tNNG',
#  '가가린\tNNG',
#  '가구야공주 이야기\tNNG',
#  '가까이서 본 기차\tNNG',
#  '가나의 혼인잔치: 언약\tNNG',
#  '가난한 새댁 : 몸으로 내는 월세\tNNG',
#  '가능한 변화들\tNNG',
#  '가든\tNNG',
#  '가디언\tNNG',
#  '가디언스\tNNG',
#  '가디언의 전설\tNNG',
#  '가디언즈\tNNG',
#  '가디언즈 오브 갤럭시\tNNG',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG',
#  '가라, 가라 두 번째 처녀\tNNG',
#  '가라데 파이터\tNNG',
#  '가라데로 죽여라\tNNG',
#  '가래떡의 맛: 감독판\tNNG',
#  '가려진 시간\tNNG',
#  '가루지기\tNNG',
#  '가루지기: 변강쇠 더 비기닝\tNNG',
#  '가루지기: 변강쇠 더 비기닝 - 무삭제판\tNNG',
#  '가르시아\tNNG',
#  '가름워즈: 마지막 예언자\tNNG',
#  '가면\tNNG',
#  '가면-감춰진 진실\tNNG',
#  '가면속의 아리아\tNNG',
#  '가면의 정사\tNNG',
#  '가문의 부활 - 가문의 영광3\tNNG',
#  '가문의 영광4 - 가문의 수난\tNNG',
#  '가문의 영광5 - 가문의 귀환\tNNG',
#  '가문의 위기(가문의 영광2)\tNNG',
#  '가미카제\tNNG',
#  '가발\tNNG',
#  '가버나움\tNNG',
#  '가베\tNNG',
#  '가벼운 잠\tNNG',
#  '가부와 메이 이야기\tNNG',
#  '가비\tNNG',
#  '가슴 노출을 허하라!\tNNG',
#  '가슴 배구단\tNNG',
#  '가슴 큰 가인\tNNG',
#  '가슴 큰 가인 - 무삭제판\tNNG',
#  '가슴 큰 그녀:질펀한 마사지\tNNG',
#  '가슴 큰 뒷집소녀\tNNG',
#  '가슴 큰 새 누나\tNNG',
#  '가슴 큰 새 누나 2\tNNG',
#  '가슴 큰 새엄마 루미\tNNG',
#  '가슴 큰 앞집 소녀\tNNG',
#  '가슴 큰 여대생\tNNG',
#  '가슴 큰 여동생\tNNG',
#  '가슴 큰 여자선배\tNNG',
#  '가슴 큰 여자선배 무삭제\tNNG',
#  '가슴 큰 여자친구\tNNG',
#  '가슴 큰 여자친구 무삭제판\tNNG',
#  '가슴 큰 연주\tNNG',
#  '가슴 큰 옆집 소녀\tNNG',
#  '가슴 큰 울 엄마\tNNG',
#  '가슴 큰 울 엄마 2\tNNG',
#  '가슴 큰 처제\tNNG',
#  '가슴 큰 처제-무삭제판\tNNG',
#  '가슴 큰 초희\tNNG',
#  '가슴 큰 초희 - 무삭제판\tNNG',
#  '가슴 큰 친구 여친\tNNG',
#  '가슴 큰 친구여친 무삭제\tNNG',
#  '가슴 큰 태희\tNNG',
#  '가슴 큰 태희-무삭제판\tNNG',
#  '가슴 큰 형수\tNNG',
#  '가슴 큰 형수-무삭제판\tNNG',
#  '가슴에 돋는 칼로 슬픔을 자르고\tNNG',
#  '가슴을 탐하는 남자들\tNNG',
#  '가슴이 떨리는 건 너 때문\tNNG',
#  '가슴큰누나들\tNNG',
#  '가슴큰누나들-무삭제\tNNG',
#  '가슴큰며느리\tNNG',
#  '가슴큰며느리-무삭제\tNNG',
#  '가슴큰새엄마\tNNG',
#  '가슴큰새엄마-무삭제\tNNG',
#  '가슴큰엄마들\tNNG',
#  '가슴큰엄마들-무삭제\tNNG',
#  '가슴큰엄마친구\tNNG',
#  '가슴큰엄마친구-무삭제\tNNG',
#  '가슴큰자매들\tNNG',
#  '가슴큰자매들 - 무삭제\tNNG',
#  '가슴큰친구누나들\tNNG',
#  '가슴큰친구누나들-무삭제\tNNG',
#  '가시\tNNG',
#  '가시꽃\tNNG',
#  '가싶녀\tNNG',
#  '가위 : 수면마비의 기억\tNNG',
#  '가위손\tNNG',
#  '가을 소나타\tNNG',
#  '가을 우체국\tNNG',
#  '가을날의 동화\tNNG',
#  '가을날의 재회\tNNG',
#  '가을로\tNNG',
#  '가을비 우산속에\tNNG',
#  '가을의 마티네\tNNG',
#  '가을의 전설\tNNG',
#  '가자 장미여관으로 4\tNNG',
#  '가자 장미여관으로 4 - 무삭제판\tNNG',
#  '가자! 장미여관으로 2 - 갈증\tNNG',
#  '가자! 장미여관으로 3 - 방황\tNNG',
#  '가자! 장미여관으로 3 - 방황 무삭제 감독판\tNNG',
#  '가자, 장미여관으로\tNNG',
#  '가장 따뜻한 색, 블루\tNNG',
#  '가장 보통의 연애\tNNG',
#  '가재가 노래하는 곳\tNNG',
#  '가정교사 길들이기\tNNG',
#  '가정교사-맛있는 섹스 비밀 수업\tNNG',
#  '가정교사: 앞집 아줌마의 수업\tNNG',
#  '가정교사: 하고 싶은 여자\tNNG',
#  '가정교사:만져주기\tNNG',
#  '가정교사의 맛있는 수업\tNNG',
#  '가정교사의 비밀수업\tNNG',
#  '가정교사의 위험한 방문\tNNG',
#  '가정부 길들이기\tNNG',
#  '가정부 길들이기 무삭제판\tNNG',
#  '가정부와의 불륜\tNNG',
#  '가정부의 맛\tNNG',
#  '가정부의 목적\tNNG',
#  '가정부의 목적 무삭제판\tNNG',
#  '가정부의 손맛 감독판\tNNG',
#  '가정부의 유혹\tNNG',
#  '가져선 안될 비밀\tNNG',
#  '가족\tNNG',
#  '가족 연애사\tNNG',
#  '가족사진\tNNG',
#  '가족상속괴담\tNNG',
#  '가족시네마\tNNG',
#  '가족은 괴로워3: 아내여 장미처럼\tNNG',
#  '가족의 나라\tNNG',
#  '가족의 색깔\tNNG',
#  '가족의 재구성\tNNG',
#  '가족의 탄생\tNNG',
#  '가족이 되기까지\tNNG',
#  '가치 캅시다\tNNG',
#  '가투의 연날리기\tNNG',
#  '가필드\tNNG',
#  '가필드 2\tNNG',
#  '가필드 펫 포스 3D\tNNG',
#  '가필드-마법의 샘물\tNNG',
#  '각설탕\tNNG',
#  '각시탈\tNNG',
#  '간 큰 가족\tNNG',
#  '간기남\tNNG',
#  '간디\tNNG',
#  '간병인의 황제서비스\tNNG',
#  '간신\tNNG',
#  '간음:위험한 유부녀들\tNNG',
#  '간이역\tNNG',
#  '간증\tNNG',
#  '간첩\tNNG',
#  '간첩 리철진\tNNG',
#  '간츠\tNNG',
#  '간츠: 오\tNNG',
#  '간츠: 퍼펙트 앤서\tNNG',
#  '간통 : 섹스 회춘 료칸\tNNG',
#  '간통: 사장님의 아내\tNNG',
#  '간호사와 음란 마사지\tNNG',
#  '간호중\tNNG',
#  '갇힌 여인\tNNG',
#  '갈까부다\tNNG',
#  '갈리폴리 상륙작전\tNNG',
#  '갈리폴리: 최악의 상륙작전\tNNG',
#  '갈매기\tNNG',
#  '갈증\tNNG',
#  '감금당한 청순미인의 절정\tNNG',
#  '감금당해 범해지는 청순미인\tNNG',
#  '감금의 시간\tNNG',
#  '감금의 시간 2 무삭제\tNNG',
#  '감금의 정사\tNNG',
#  '감금일지-메이드\tNNG',
#  '감기\tNNG',
#  '감당이 안되는 욕정녀\tNNG',
#  '감독 미카엘 하네케\tNNG',
#  '감동주의보\tNNG',
#  '감바의 대모험\tNNG',
#  '감성에 젖은 음대선생님\tNNG',
#  '감시자들\tNNG',
#  '감염: 지구 최후의 날\tNNG',
#  '감옥정사\tNNG',
#  '감옥풍운\tNNG',
#  '감자\tNNG',
#  '감자심포니\tNNG',
#  '감쪽같은 그녀\tNNG',
#  '감출 수 없는 본능-몰카\tNNG',
#  '갑질당하는 육덕가정부\tNNG',
#  '갑질섹스-색기\tNNG',
#  '갓 앤 몬스터\tNNG',
#  '갓 오브 이집트\tNNG',
#  '갓 헬프 더 걸\tNNG',
#  '갓길로 달리는 코뿔소\tNNG',
#  '갓센드\tNNG',
#  '갓즈 포켓\tNNG',
#  '갓파 쿠와 여름방학을\tNNG',
#  '강간 몰카 유출 사건\tNNG',
#  '강남 1970\tNNG',
#  '강남 며느리\tNNG',
#  '강력 3반\tNNG',
#  '강력 범죄\tNNG',
#  '강령\tNNG',
#  '강릉\tNNG',
#  '강변호텔\tNNG',
#  '강시: 리거모티스\tNNG',
#  '강시선생 -일미도인\tNNG',
#  '강시선생 2\tNNG',
#  '강시선생 3 - 영환도사\tNNG',
#  '강아지 삼총사\tNNG',
#  '강원도의 힘\tNNG',
#  '강을 건너는 사람들\tNNG',
#  '강적\tNNG',
#  '강제 섹스:거절하다 신음\tNNG',
#  '강제로 당하는 새엄마\tNNG',
#  '강제섹스: 그 남자의 섹스방식\tNNG',
#  '강철대오:구국의 철가방\tNNG',
#  '강철비\tNNG',
#  '강철비2 : 정상회담 확장판\tNNG',
#  '강철비2: 정상회담\tNNG',
#  '강철의 연금술사 : 미로스의 성스러운 별\tNNG',
#  '강철중+크로싱+쿵푸 팬더\tNNG',
#  '강철중: 공공의 적 1-1\tNNG',
#  '강철중:공공의 적1-1+인크레더블 헐크+겟 스마트\tNNG',
#  '강한 칼: 도도견혈\tNNG',
#  '강호\tNNG',
#  '강호아녀\tNNG',
#  '강호의 무림신공\tNNG',
#  '강호제일검 금강철선\tNNG',
#  '같은 달을 보고 있다\tNNG',
#  '같은 속옷을 입는 두 여자\tNNG',
#  '개 같은 것들\tNNG',
#  '개: dog eat dog\tNNG',
#  '개같은 날의 오후\tNNG',
#  '개같은 내인생\tNNG',
#  '개구리왕국\tNNG',
#  '개구리왕국 2\tNNG',
#  '개구리중사 케로로\tNNG',
#  '개구쟁이 스머프\tNNG',
#  '개구쟁이 스머프 2\tNNG',
#  '개그 더 크라운\tNNG',
#  '개그맨\tNNG',
#  '개들의 섬\tNNG',
#  '개들의 전쟁\tNNG',
#  '개똥이\tNNG',
#  '개를 훔치는 완벽한 방법\tNNG',
#  '개벽\tNNG',
#  '개선문\tNNG',
#  '개에게 처음 이름을 지어준 날\tNNG',
#  '개와 늑대 사이의 시간\tNNG',
#  '개인교수 2014\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법(무삭제)\tNNG',
#  '개인교수 : 성적 올리기\tNNG',
#  '개인교수 : 성적 올리기 무삭제\tNNG',
#  '개인교수 : 세 여자의 섹스수업\tNNG',
#  '개인교수 : 여친 만족 시키기\tNNG',
#  '개인교수 : 여친 만족 시키기 무삭제\tNNG',
#  '개인교수: 심화학습\tNNG',
#  '개인교수: 심화학습 (무삭제)\tNNG',
#  '개인교습\tNNG',
#  '개인교습: 사촌여동생\tNNG',
#  '개인레슨\tNNG',
#  '개인영업 : 업소녀가 된 아내\tNNG',
#  '개인지도:붓으로 그리는 황홀경\tNNG',
#  '갤럭시 히어로즈: 라쳇 앤 클랭크\tNNG',
#  '갤로우즈\tNNG',
#  '갤로워커: 블레이드의 귀환\tNNG',
#  '갤버스턴\tNNG',
#  '갬빗\tNNG',
#  '갯마을\tNNG',
#  '갱\tNNG',
#  '갱 브라더스: 마지막 대결\tNNG',
#  '갱경떡삥이\tNNG',
#  '갱스터 초치\tNNG',
#  '거근이 좋아\tNNG',
#  '거기엔 래퍼가 없다\tNNG',
#  '거꾸로 된 파테마\tNNG',
#  '거대 불개미의 습격\tNNG',
#  '거대말벌의 습격\tNNG',
#  '거대한 서부\tNNG',
#  '거래완료\tNNG',
#  '거래처 여직원\tNNG',
#  '거룩한 계보\tNNG',
#  '거룩한 분노\tNNG',
#  '거룩한 소녀 마리아\tNNG',
#  '거리의 보안관\tNNG',
#  '거미숲\tNNG',
#  '거미의 계략\tNNG',
#  '거미의 땅\tNNG',
#  '거미줄에 걸린 소녀\tNNG',
#  '거부하다 신음하는 여자\tNNG',
#  '거북이 달린다\tNNG',
#  '거북이도 난다\tNNG',
#  '거울나라의 앨리스\tNNG',
#  '거유 며느리의 은밀한 일탈\tNNG',
#  '거유 며느리의 친정나들이\tNNG',
#  '거유 바니걸 리나\tNNG',
#  '거유 새엄마와 형제들\tNNG',
#  '거유 여사장의 약점\tNNG',
#  '거유 와이프:남편 대신 상사와\tNNG',
#  '거유 유부녀의 오일 마사지\tNNG',
#  '거유 장모와 실제로 느끼는 사위\tNNG',
#  '거유 치과 간호사\tNNG',
#  '거유 치나미 사쿠라의 아찔 유혹\tNNG',
#  '거유 칸나의 질펀한 서비스\tNNG',
#  '거유간호사 폭유간호사\tNNG',
#  '거유녀들의 아찔한 가슴골\tNNG',
#  '거유녀의 젖어버린 작업복\tNNG',
#  '거유미녀 서큐버스2\tNNG',
#  '거유이발소-어서오세요\tNNG',
#  '거인\tNNG',
#  '거지의 오페라\tNNG',
#  '거짓말\tNNG',
#  '거짓말 2014\tNNG',
#  '거짓말 2018: 감독판\tNNG',
#  '거짓말 : 여자 모델의 섹스\tNNG',
#  '거짓말 : 여자 모델의 섹스 무삭제\tNNG',
#  '거짓말 섹스가 좋아\tNNG',
#  '거짓말 섹스가 좋아2\tNNG',
#  '거짓말 애인-감독판\tNNG',
#  '거짓의\tNNG',
#  '거친 녀석들\tNNG',
#  '거친 섹스에 빠진 그녀들\tNNG',
#  '거칠마루\tNNG',
#  '거침없이 쏴라! 슛뎀업\tNNG',
#  '걱정말아요\tNNG',
#  '건\tNNG',
#  '건 샤이\tNNG',
#  '건달 가정부\tNNG',
#  '건달티처\tNNG',
#  '건마의 신: 어린 아내의 알바\tNNG',
#  '건양강호: 운뢰검법의 비밀\tNNG',
#  '건우먼\tNNG',
#  '건즈 아킴보\tNNG',
#  '건즈 포 하이어\tNNG',
#  '건축학개론\tNNG',
#  '건파우더 밀크셰이크\tNNG',
#  '걷기 좋은 날\tNNG',
#  '걷기왕\tNNG',
#  '걸\tNNG',
#  '걸 아바타\tNNG',
#  '걸 온 더 브릿지\tNNG',
#  '걸 온 더 트레인\tNNG',
#  '걸 위드 더 카메라\tNNG',
#  '걸 인 더 포토그래프\tNNG',
#  '걸리버 리턴즈\tNNG',
#  '걸리버 여행기\tNNG',
#  '걸스\tNNG',
#  '걸스 곤 데드\tNNG',
#  '걸스 나잇\tNNG',
#  '걸스 스텝\tNNG',
#  '걸스 온 탑2\tNNG',
#  '걸스카우트\tNNG',
#  '걸어도 걸어도\tNNG',
#  '걸작\tNNG',
#  '걸즈 앤 판처 극장판\tNNG',
#  '걸즈 앤 판처 제\u200b 63회 전차도 전국 고교생 대회\tNNG',
#  '걸즈 앤 판처 최종장\tNNG',
#  '걸즈 앤 판처 최종장 제1화\tNNG',
#  '걸즈 앤 판처 최종장 제3화\tNNG',
#  '걸캅스\tNNG',
#  '걸캅스 누나들\tNNG',
#  '걸프렌즈\tNNG',
#  '걸후드\tNNG',
#  '검객\tNNG',
#  '검객풍운\tNNG',
#  '검사외전\tNNG',
#  '검우강호\tNNG',
#  '검은 고양이 흰 고양이\tNNG',
#  '검은 땅의 소녀와\tNNG',
#  '검은 물밑에서\tNNG',
#  '검은 사제들\tNNG',
#  '검은 사제들: 지옥의 문\tNNG',
#  '검은 숲\tNNG',
#  '검은 여름\tNNG',
#  '검은 집\tNNG',
#  '검은 집: 죽음을 보는 눈\tNNG',
#  '검은비: 악의연대기\tNNG',
#  '검은손\tNNG',
#  '겁나는 여친의 완벽한 비밀\tNNG',
#  '겁쟁이 페달: 더 무비\tNNG',
#  '겁쟁이 페달: 리라이드\tNNG',
#  '겁쟁이 페달: 리로드\tNNG',
#  '겁쟁이 페달: 스페어 바이크\tNNG',
#  '겁탈당한 유부녀\tNNG',
#  '겁탈당한 유부녀 무삭제판\tNNG',
#  '게드전기 : 어스시의 전설\tNNG',
#  '게발트 파이브:구타본능\tNNG',
#  '게스트하우스\tNNG',
#  '게스후\tNNG',
#  '게이머\tNNG',
#  '게이샤 하우스\tNNG',
#  '게이샤:격정정사\tNNG',
#  '게이샤의 기억\tNNG',
#  ...]

# %%
print(len(new_user_dict))
new_user_dict
# Out:
# 57076
# ['0시\tNNG',
#  '1시\tNNG',
#  '2시\tNNG',
#  '3시\tNNG',
#  '4시\tNNG',
#  '5시\tNNG',
#  '6시\tNNG',
#  '7시\tNNG',
#  '8시\tNNG',
#  '9시\tNNG',
#  '10시\tNNG',
#  '11시\tNNG',
#  '12시\tNNG',
#  '13시\tNNG',
#  '14시\tNNG',
#  '15시\tNNG',
#  '16시\tNNG',
#  '17시\tNNG',
#  '18시\tNNG',
#  '19시\tNNG',
#  '20시\tNNG',
#  '21시\tNNG',
#  '22시\tNNG',
#  '23시\tNNG',
#  '24시\tNNG',
#  '0분\tNNG',
#  '1분\tNNG',
#  '2분\tNNG',
#  '3분\tNNG',
#  '4분\tNNG',
#  '5분\tNNG',
#  '6분\tNNG',
#  '7분\tNNG',
#  '8분\tNNG',
#  '9분\tNNG',
#  '10분\tNNG',
#  '11분\tNNG',
#  '12분\tNNG',
#  '13분\tNNG',
#  '14분\tNNG',
#  '15분\tNNG',
#  '16분\tNNG',
#  '17분\tNNG',
#  '18분\tNNG',
#  '19분\tNNG',
#  '20분\tNNG',
#  '21분\tNNG',
#  '22분\tNNG',
#  '23분\tNNG',
#  '24분\tNNG',
#  '25분\tNNG',
#  '26분\tNNG',
#  '27분\tNNG',
#  '28분\tNNG',
#  '29분\tNNG',
#  '30분\tNNG',
#  '31분\tNNG',
#  '32분\tNNG',
#  '33분\tNNG',
#  '34분\tNNG',
#  '35분\tNNG',
#  '36분\tNNG',
#  '37분\tNNG',
#  '38분\tNNG',
#  '39분\tNNG',
#  '40분\tNNG',
#  '41분\tNNG',
#  '42분\tNNG',
#  '43분\tNNG',
#  '44분\tNNG',
#  '45분\tNNG',
#  '46분\tNNG',
#  '47분\tNNG',
#  '48분\tNNG',
#  '49분\tNNG',
#  '50분\tNNG',
#  '51분\tNNG',
#  '52분\tNNG',
#  '53분\tNNG',
#  '54분\tNNG',
#  '55분\tNNG',
#  '56분\tNNG',
#  '57분\tNNG',
#  '58분\tNNG',
#  '59분\tNNG',
#  '60분\tNNG',
#  '1월\tNNG',
#  '2월\tNNG',
#  '3월\tNNG',
#  '4월\tNNG',
#  '5월\tNNG',
#  '6월\tNNG',
#  '7월\tNNG',
#  '8월\tNNG',
#  '9월\tNNG',
#  '10월\tNNG',
#  '11월\tNNG',
#  '12월\tNNG',
#  '1일\tNNG',
#  '2일\tNNG',
#  '3일\tNNG',
#  '4일\tNNG',
#  '5일\tNNG',
#  '6일\tNNG',
#  '7일\tNNG',
#  '8일\tNNG',
#  '9일\tNNG',
#  '10일\tNNG',
#  '11일\tNNG',
#  '12일\tNNG',
#  '13일\tNNG',
#  '14일\tNNG',
#  '15일\tNNG',
#  '16일\tNNG',
#  '17일\tNNG',
#  '18일\tNNG',
#  '19일\tNNG',
#  '20일\tNNG',
#  '21일\tNNG',
#  '22일\tNNG',
#  '23일\tNNG',
#  '24일\tNNG',
#  '25일\tNNG',
#  '26일\tNNG',
#  '27일\tNNG',
#  '28일\tNNG',
#  '29일\tNNG',
#  '30일\tNNG',
#  '31일\tNNG',
#  '월요일\tNNG',
#  '화요일\tNNG',
#  '수요일\tNNG',
#  '목요일\tNNG',
#  '금요일\tNNG',
#  '토요일\tNNG',
#  '일요일\tNNG',
#  '#살아있다\tNNG',
#  '#아이엠히어\tNNG',
#  '#위왓치유\tNNG',
#  '...ing\tNNG',
#  '0.0MHz\tNNG',
#  '007 노 타임 투 다이\tNNG',
#  '007 북경특급 2\tNNG',
#  '007 스카이폴\tNNG',
#  '007 스펙터\tNNG',
#  '007 제2편 : 위기일발\tNNG',
#  '007 카지노 로얄\tNNG',
#  '007 퀀텀 오브 솔러스\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+뱅크 잡\tNNG',
#  '007 퀀텀 오브 솔러스+굿 바이+순정만화\tNNG',
#  '009 사이보그\tNNG',
#  '10 미니츠 곤\tNNG',
#  '10 바이 10\tNNG',
#  '10 아이템 오어 레스\tNNG',
#  '10,000 BC\tNNG',
#  '10,000 BC + 어메이징 그레이스 + 댄 인 러브\tNNG',
#  '10,000BC+마이 블루베리 나이츠+연을 쫓는 아이\tNNG',
#  '10,000BC+연을 쫓는 아이+마이 블루베리 나이츠\tNNG',
#  '10,000km(만 킬로미터)\tNNG',
#  '100 피트\tNNG',
#  '100% 울프: 푸들이 될 순 없어\tNNG',
#  '1000 : 최후의 전사들\tNNG',
#  '100년 동안의 히틀러\tNNG',
#  '100미터\tNNG',
#  '100일 동안 100가지로 100퍼센트 행복찾기\tNNG',
#  '10년\tNNG',
#  '10분\tNNG',
#  '10억\tNNG',
#  '10일간의 원나잇 스탠드\tNNG',
#  '10층의 모기\tNNG',
#  '117편의 러브레터\tNNG',
#  '11월 실험영화 정기 상영회\tNNG',
#  '11인의 카우보이\tNNG',
#  '12 솔져스\tNNG',
#  '120 BPM\tNNG',
#  '125 전승철\tNNG',
#  '127시간\tNNG',
#  '12번째 솔저\tNNG',
#  '12시에 열리는 쾌락의 문\tNNG',
#  '12월실험영화상영회-야수토 유라 특별전\tNNG',
#  '12인의 하숙생\tNNG',
#  '12피트\tNNG',
#  '13 이어리\tNNG',
#  '13 자메티\tNNG',
#  '13구역\tNNG',
#  '13구역: 얼티메이텀\tNNG',
#  '13년의 공백\tNNG',
#  '13번째 전사\tNNG',
#  '13시간\tNNG',
#  '13인의 자객\tNNG',
#  '13일의 금요일\tNNG',
#  '13일의 금요일: 더 파이널\tNNG',
#  '1408\tNNG',
#  '1492 콜럼버스\tNNG',
#  '14인의 여걸\tNNG',
#  '15소년 우주 표류기\tNNG',
#  '15소년 표류기: 해적섬을 탈출하라\tNNG',
#  '16세의 사운드트랙\tNNG',
#  '1724 기방난동사건\tNNG',
#  '17인의사자들\tNNG',
#  '18 BJ 하연의 화려한 테크닉\tNNG',
#  '18 걸그룹 승하의 눈치게임\tNNG',
#  '18 모델 리카의 화려한 외출\tNNG',
#  '18 성인배우 이수의 섹스 판타지\tNNG',
#  '18 섹시퀸 유진의 섹스 스캔들\tNNG',
#  '18 승하의 누워서 떡 먹기\tNNG',
#  '18 여대생 소라의 순결상실\tNNG',
#  '18 주아의 뜨거운 하루\tNNG',
#  '18 출사녀 화진의 미친 섹스\tNNG',
#  '18 하라의 맛있는 수업\tNNG',
#  '1812 나폴레옹 대전투\tNNG',
#  '1820: 잃어버린 제국의 비밀\tNNG',
#  '1850 길로틴 트레지디\tNNG',
#  '18: 우리들의 성장 느와르\tNNG',
#  '18금 아이돌 승하의 섹스 스캔들\tNNG',
#  '18금 아이돌 승하의 화려한 외출\tNNG',
#  '19 섹스 맛있는 속 궁합\tNNG',
#  '19-Nineteen\tNNG',
#  '1900년\tNNG',
#  '1917\tNNG',
#  '1919 유관순\tNNG',
#  '1940: 최강의 독일 전차부대\tNNG',
#  '1941\tNNG',
#  '1941: 세바스토폴 상륙작전\tNNG',
#  '1942: 언노운 배틀\tNNG',
#  '1942: 최정예특수부대 스페츠나츠\tNNG',
#  '1944\tNNG',
#  '1944 대전투\tNNG',
#  '1944 워 히어로\tNNG',
#  '1944: 인간병기\tNNG',
#  '1945 그레이트 워\tNNG',
#  '1945: 포인트 오브 노 리턴\tNNG',
#  '1975 킬링필드, 푸난\tNNG',
#  '1984 최동원\tNNG',
#  '1987\tNNG',
#  '1991, 봄\tNNG',
#  '1999, 면회\tNNG',
#  '19곰 테드\tNNG',
#  '19곰 테드 2\tNNG',
#  '19금 만남의 목적\tNNG',
#  '19금 불륜소설\tNNG',
#  '19금 불륜소설 무삭제판\tNNG',
#  '19금 비밀과외\tNNG',
#  '19금 섹스비디오\tNNG',
#  '19금 섹스비디오 무삭제 감독판\tNNG',
#  '19금 섹스의 늪 무삭특별판\tNNG',
#  '19금 연애소설\tNNG',
#  '19금 연애소설 무삭제판\tNNG',
#  '19금 절대섹스\tNNG',
#  '19금 정사: 말할 수 없는 비밀\tNNG',
#  '19금 특별한 정사\tNNG',
#  '19금 특별한 정사 무삭제 특별판\tNNG',
#  '19번가물많은여자친구\tNNG',
#  '1급기밀\tNNG',
#  '1박2일 소개팅\tNNG',
#  '1번가의 기적\tNNG',
#  '1번국도\tNNG',
#  '1월 단편 상상극장\tNNG',
#  '1월의 두 얼굴\tNNG',
#  '2 데이즈 인 뉴욕\tNNG',
#  '2%필름페스티발\tNNG',
#  '20 30 40\tNNG',
#  '2007 시네바캉스 서울\tNNG',
#  '2007 아시아나국제단편영화제\tNNG',
#  '2007 인디애니페스트\tNNG',
#  '2007 칸국제광고제 수상작 필름 페스티벌\tNNG',
#  '2007CJ중국영화제\tNNG',
#  '2008 광주국제영화제\tNNG',
#  '2008 음악 영화제\tNNG',
#  '2008 최강애니전\tNNG',
#  '2008년 시네마테크의 친구들 영화제\tNNG',
#  '2010 3D한국국제영화제\tNNG',
#  '2010 AISFF-개막식\tNNG',
#  '2010 AISFF-거장들의 패션필름\tNNG',
#  '2010 AISFF-국제경쟁1\tNNG',
#  '2010 AISFF-국제경쟁2\tNNG',
#  '2010 AISFF-국제경쟁3\tNNG',
#  '2010 AISFF-국제경쟁4\tNNG',
#  '2010 AISFF-국제경쟁5\tNNG',
#  '2010 AISFF-국제경쟁6\tNNG',
#  '2010 AISFF-국제경쟁7\tNNG',
#  '2010 AISFF-국제경쟁8\tNNG',
#  '2010 AISFF-메이드 바이 커머셜 디렉터스\tNNG',
#  '2010 AISFF-시상식\tNNG',
#  '2010 AISFF-여자는 두 번 플레이 한다\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 저팬\tNNG',
#  '2010 AISFF-트래블링 쇼츠 인 코리아\tNNG',
#  '2010 시네바캉스 서울\tNNG',
#  '2010 한-EU단편영화 교류전\tNNG',
#  '2010 한국영화아카데미 영화제\tNNG',
#  '2010년 시네마테크의 친구들 영화제\tNNG',
#  '2010칸국제광고제 수상작페스티벌\tNNG',
#  '2012\tNNG',
#  '2014 지구 최후의 날\tNNG',
#  '2017 동명이인 프로젝트\tNNG',
#  '2017복상사\tNNG',
#  '2020년 마지막 섹스\tNNG',
#  '2021 첫 섹스\tNNG',
#  '2023-09-11 00:00:00\tNNG',
#  '2025 지구전쟁: 얼리전스 오브 파워\tNNG',
#  '2035 매드 레이스\tNNG',
#  '2046\tNNG',
#  '2047 버추얼 레볼루션\tNNG',
#  '2047: 지구 최후의 날\tNNG',
#  '2067\tNNG',
#  '20대 같은 40대 미시녀\tNNG',
#  '20세기 소년\tNNG',
#  '20세기 소년 ; 최종장 - 우리들의 깃발\tNNG',
#  '20세기 소년+맘마미아+방콕 데인저러스\tNNG',
#  '20세기 소년-제2장: 마지막 희망\tNNG',
#  '20일밤, 그리고 비 오는 하루\tNNG',
#  '21\tNNG',
#  '21 그램\tNNG',
#  '21 브릿지: 테러 셧다운\tNNG',
#  '21 앤드 오버\tNNG',
#  '21살승하의아이돌비밀일기\tNNG',
#  '21살승하의아이돌비밀일기-무삭제\tNNG',
#  '21세기 우리 시대의 영화 특별전\tNNG',
#  '21세기의 기원\tNNG',
#  '22\tNNG',
#  '22 블렛\tNNG',
#  '22년 후의 고백\tNNG',
#  '22분: 아덴만 구출작전\tNNG',
#  '23 아이덴티티\tNNG',
#  '24 시티\tNNG',
#  '24살윤율의섹시한젖가슴\tNNG',
#  '24살윤율의섹시한젖가슴-무삭제\tNNG',
#  '24시간 달리는 쾌락 버스\tNNG',
#  '24주\tNNG',
#  '25시\tNNG',
#  '26년\tNNG',
#  '27번의 결혼리허설\tNNG',
#  '27번의 결혼리허설 + 마이 뉴 파트너 + 마이 블루베리 나이츠\tNNG',
#  '27번의 결혼리허설+10,000BC+밴티지 포인트\tNNG',
#  '28세 미성년\tNNG',
#  '28일 후\tNNG',
#  '2솔져스: 배틀필드\tNNG',
#  '2월 29일 - 어느날 갑자기 첫번째 이야기\tNNG',
#  '2차 노출\tNNG',
#  '2차 세계대전 타임트랙\tNNG',
#  '2차 송환\tNNG',
#  '2회 브라질 영화제: 시네마 노보 회고전\tNNG',
#  '3-4X10월\tNNG',
#  '3.5교시\tNNG',
#  '300\tNNG',
#  '300: 전사의 귀환\tNNG',
#  '300: 제국의 부활\tNNG',
#  '301, 302\tNNG',
#  '3022: 지구 대폭발\tNNG',
#  '3096일\tNNG',
#  '30년만의 대결\tNNG',
#  '33\tNNG',
#  '33리\tNNG',
#  '355\tNNG',
#  '365일: 비밀의 여자\tNNG',
#  '3:10 투 유마\tNNG',
#  '3:10 투 유마 + 주노 + 어톤먼트\tNNG',
#  '3xFTM\tNNG',
#  '3개의 얼굴들\tNNG',
#  '3데이즈: 라스트 서바이벌\tNNG',
#  '3류들의 사랑\tNNG',
#  '3분 파트너\tNNG',
#  '3분 파트너-무삭제\tNNG',
#  '3인3색 여성감독 특별전\tNNG',
#  '3인의 사기단: 진범을 찾아라\tNNG',
#  '3인조\tNNG',
#  '4 브라더스\tNNG',
#  '4.4.4\tNNG',
#  '400 데이즈\tNNG',
#  '400: 제국의 부활\tNNG',
#  '400번의 구타\tNNG',
#  '40살까지 못해본 사람\tNNG',
#  '438일\tNNG',
#  '45년 후\tNNG',
#  '47 미터\tNNG',
#  '47미터 2\tNNG',
#  '48미터\tNNG',
#  '48시간: 지구 최후의 날\tNNG',
#  '4DX 문유\tNNG',
#  '4개월, 3주... 그리고 2일\tNNG',
#  '4교시 추리영역\tNNG',
#  '4등\tNNG',
#  '4명의 암살자\tNNG',
#  '4요일: 자살을 부르는 요일\tNNG',
#  '4월 실험영화 정기상영회\tNNG',
#  '4월 이야기\tNNG',
#  '4월은 너의 거짓말\tNNG',
#  '4인용 식탁\tNNG',
#  '4인의 무뢰한\tNNG',
#  '5 데이즈 오브 워\tNNG',
#  '5 투 7\tNNG',
#  '5.18 힌츠페터 스토리\tNNG',
#  '50/50\tNNG',
#  '500일의 썸머\tNNG',
#  '500일의 썸머+들어는 봤니? 모건 부부+의형제\tNNG',
#  '500일의 썸머+들어는봤니? 모건 부부+하모니\tNNG',
#  '500일의 썸머+용서는 없다+주유소 습격사건2\tNNG',
#  '50가지 그림자: 심연\tNNG',
#  '50가지 그림자: 해방\tNNG',
#  '50가지 욕망의 그림자\tNNG',
#  '50대 장모님의 불타는 사위사랑\tNNG',
#  '51구역\tNNG',
#  '577 프로젝트\tNNG',
#  '5x2\tNNG',
#  '5백만불의 사나이\tNNG',
#  '5분 운동 30분 섹스\tNNG',
#  '5월 1일\tNNG',
#  '5월 실험영화 정기상영회-브루스 엘더\tNNG',
#  '5월의 구름\tNNG',
#  '5일의 마중\tNNG',
#  '5쿼터\tNNG',
#  '6 웨이 투 다이\tNNG',
#  '600 마일\tNNG',
#  '60년전, 사선에서\tNNG',
#  '60만번의 트라이\tNNG',
#  '60일의 썸머\tNNG',
#  '69 식스티 나인\tNNG',
#  '69번가육덕진가정교사\tNNG',
#  '69세\tNNG',
#  '6년째 연애중\tNNG',
#  '6솔져스\tNNG',
#  '6시간: 원전대폭발\tNNG',
#  '6월 독립애니메이션 정기상영회-밥 좀 먹자,잠 좀 자자\tNNG',
#  '6월 실험영화 정기상영회-칼 브라운-감각의 응축\tNNG',
#  '6월의 뱀\tNNG',
#  '6월의 일기\tNNG',
#  '71 : 벨파스트의 눈물\tNNG',
#  '7공주 대리운전\tNNG',
#  '7광구\tNNG',
#  '7급 공무원\tNNG',
#  '7년-그들이 없는 언론\tNNG',
#  '7년의 밤\tNNG',
#  '7번방의 선물\tNNG',
#  '7번째 내가 죽던 날\tNNG',
#  '7번째 아들\tNNG',
#  '7월 32일\tNNG',
#  '7월7일\tNNG',
#  '7인의 말괄량이\tNNG',
#  '7인의 신부\tNNG',
#  '7인의 악인전\tNNG',
#  '7호실\tNNG',
#  '8 마일\tNNG',
#  '800\tNNG',
#  '800 블렛\tNNG',
#  '80일간의 세계 일주\tNNG',
#  '82년생 김지영\tNNG',
#  '84 태권 V\tNNG',
#  '88분\tNNG',
#  '8광구: 몬스터의 부활\tNNG',
#  '8년 전쟁: 이란 vs 이라크\tNNG',
#  '8년을 뛰어넘은 신부\tNNG',
#  '8명의 여인들\tNNG',
#  '8월 실험영화정기상영회-타수아오키\tNNG',
#  '8월의 일요일들\tNNG',
#  '8월의 크리스마스\tNNG',
#  '8월의 크리스마스(일본판)\tNNG',
#  '8인: 최후의 결사단\tNNG',
#  '8인의 수상한 신사들\tNNG',
#  '90분\tNNG',
#  '9:나인\tNNG',
#  '9명의 번역가\tNNG',
#  '9월 실험영화정기상영회\tNNG',
#  '9월의 어느날\tNNG',
#  'A 계획 속집\tNNG',
#  'A-특공대\tNNG',
#  'A-특공대+베스트 키드+유령작가\tNNG',
#  'A.I.\tNNG',
#  'AISFF 프로그램1\tNNG',
#  'AISFF 프로그램2\tNNG',
#  'AISFF 프로그램3\tNNG',
#  'AS센터 대신맨\tNNG',
#  'AV 아이돌\tNNG',
#  'AV 아이돌 일본제일전 도전기\tNNG',
#  'AV 여배우의 직장 체험기\tNNG',
#  'AV스타: 과거를 지워주세요\tNNG',
#  'AV스타납치사건\tNNG',
#  'AV스타의 질펀한 실습\tNNG',
#  'AV제작사의 여직원\tNNG',
#  'A형젖큰여자친구\tNNG',
#  'BB프로젝트\tNNG',
#  'BJ노는이모\tNNG',
#  'BJ노는이모2\tNNG',
#  'B급 며느리\tNNG',
#  'B급 청춘\tNNG',
#  'B컷\tNNG',
#  'B형 남자친구\tNNG',
#  'B형물많고화끈한처제\tNNG',
#  'B형물많고화끈한처제-무삭제\tNNG',
#  'C+ 탐정\tNNG',
#  'CCTV\tNNG',
#  'CJ7:장강7호\tNNG',
#  'CQN 한국영화앵콜전\tNNG',
#  'CQN 할로윈 무비 파티\tNNG',
#  'D-day-어느날 갑자기 세번째 이야기\tNNG',
#  'DC 리그 오브 슈퍼-펫\tNNG',
#  'DMZ, 비무장지대\tNNG',
#  'DOA\tNNG',
#  'D컵 여형사-가슴으로 느껴져요\tNNG',
#  'D컵여자친구\tNNG',
#  'D컵여자친구-무삭제\tNNG',
#  'EBS친구들 씽씽 댄스파티\tNNG',
#  'EIDF-다큐멘터리 정신상 수상작\tNNG',
#  'EIDF-대상수상작\tNNG',
#  'EIDF-시청자상 수상작\tNNG',
#  'EIDF-심사위원 특별상 수상작\tNNG',
#  'EX-Choice 1 소_극\tNNG',
#  'EX-Choice 2 비_극\tNNG',
#  'EX-Choice 3 소비극\tNNG',
#  'EX-Choice 4 선택극\tNNG',
#  'EX-Live 1-무비 콘서트 III\tNNG',
#  'EX-Live 2 존 케이지 스페셜 : 퍼포먼스\tNNG',
#  'EX-Now 경쟁 1\tNNG',
#  'EX-Now 경쟁 2\tNNG',
#  'EX-Now 경쟁 4\tNNG',
#  'EX-Now 경쟁 5\tNNG',
#  'EX-Now 경쟁 6\tNNG',
#  'EX-Retro 에비게일 차일드 1\tNNG',
#  'EX-Retro 에비게일 차일드 2\tNNG',
#  'EX-Retro 에비게일 차일드 3\tNNG',
#  'F.O.E.: 에프.오.이.\tNNG',
#  'F20\tNNG',
#  'FBI 데스트랩\tNNG',
#  'Full Moon day 씨네큐브 영화축제\tNNG',
#  'F컵 거유녀의 이중 생활: 매춘\tNNG',
#  'F컵 거유녀의 잠입 수사\tNNG',
#  'F컵 거유의 육덕녀\tNNG',
#  'F컵 거유의 육덕녀 무삭제판\tNNG',
#  'F컵 옆집 부인의 질펀한 하루\tNNG',
#  'G-포스: 기니피그 특공대\tNNG',
#  'GP 506\tNNG',
#  'GROW: 인피니트의 리얼 청춘 라이프\tNNG',
#  'G컵 새 엄마:달아오른 날\tNNG',
#  'H2: 어느 살인마의 가족이야기\tNNG',
#  'H컵 이상 거유 여배우\tNNG',
#  'I AM\tNNG',
#  'IS 탈출\tNNG',
#  'Indi-Visual 제이 로젠블라트 1\tNNG',
#  'Indi-Visual 제이 로젠블라트 2\tNNG',
#  'Indi-Visual 진 리오타\tNNG',
#  'J-무비페스티벌 (버라이어티 나인 J - 무비페스티벌)\tNNG',
#  'JLG/JLG 고다르의 자화상 특별전-사랑의 찬가\tNNG',
#  'JSA 남북공동초등학교\tNNG',
#  'Jam Docu 강정\tNNG',
#  'K 미싱 킹즈\tNNG',
#  'K-19\tNNG',
#  'K-20 괴도가면\tNNG',
#  'K2\tNNG',
#  'KBS 프리미어 영화 페스티벌\tNNG',
#  'K클래식 제너레이션\tNNG',
#  'LA 대지진\tNNG',
#  'LA: 볼케이노칼립스\tNNG',
#  'Lab Program 1\tNNG',
#  'Lab Program 2\tNNG',
#  'Lab Program 3\tNNG',
#  'M 버터 플라이\tNNG',
#  'MB의 추억\tNNG',
#  'MR. 후아유\tNNG',
#  'Mr.로빈 꼬시기\tNNG',
#  'Mr.스타벅\tNNG',
#  'Mr.아이돌\tNNG',
#  'Mr.히치: 당신을 위한 데이트 코치\tNNG',
#  'NCN Cinema 특별전\tNNG',
#  'O.J. 심슨 사건 파일\tNNG',
#  'OL의 성\tNNG',
#  'O형수박가슴가정부\tNNG',
#  'O형수박가슴가정부-무삭제\tNNG',
#  'P.S 온리 유\tNNG',
#  'P.S. 걸\tNNG',
#  'P.S. 걸 무삭제\tNNG',
#  'P.S. 아이 러브 유\tNNG',
#  'PMC: 더 벙커\tNNG',
#  'R.I.P.D. : 알.아이.피.디.\tNNG',
#  'R2B: 리턴투베이스\tNNG',
#  'REC 알이씨\tNNG',
#  'S 다이어리\tNNG',
#  'S 중독자의 고백\tNNG',
#  'SICAF2007서울국제만화애니페스티벌\tNNG',
#  'SIFF2008_다큐멘터리 특별초청\tNNG',
#  'SIFF2008_해외초청1\tNNG',
#  'SIFF2008_해외초청2\tNNG',
#  'SIFF2008_해외초청3\tNNG',
#  'SIFF2008_해외초청4\tNNG',
#  'SM_음탕한 욕망\tNNG',
#  'SM작가\tNNG',
#  'SNS 러브\tNNG',
#  'SNS 불륜 집착 유부녀\tNNG',
#  'SX 테잎\tNNG',
#  'S걸의 덫\tNNG',
#  'S러버\tNNG',
#  'T-34\tNNG',
#  'U.F.O.\tNNG',
#  'UFO 스케치\tNNG',
#  'V/H/S/2: 악마를 부르는 비디오\tNNG',
#  'V/H/S:죽음을 부르는 비디오\tNNG',
#  'VJ의 은밀한 사생활\tNNG',
#  '[EIDF2011]마리아가 사는 방법+태양 아래 흐르는 소리\tNNG',
#  '[EIDF2011]비바 마리아+사운드 라이트 레볼루션\tNNG',
#  '[EIDF2011]펠란케의 사람들+잔인한 계절\tNNG',
#  '[EXiS2010]EX-Now 1\tNNG',
#  '[EXiS2010]EX-Now 2\tNNG',
#  '[EXiS2010]EX-Now 4\tNNG',
#  '[EXiS2010]EX-Now 5\tNNG',
#  '[EXiS2010]EX-Now 6\tNNG',
#  '[EXiS2010]비바 페스티벌 1\tNNG',
#  'n번째 이별 중\tNNG',
#  'pm 11:14\tNNG',
#  '新극장판 이니셜D: 레전드3 -몽현-\tNNG',
#  '犬견 : 버려진 아이들\tNNG',
#  '가가린\tNNG',
#  '가구야공주 이야기\tNNG',
#  '가까이서 본 기차\tNNG',
#  '가나의 혼인잔치: 언약\tNNG',
#  '가난한 새댁 : 몸으로 내는 월세\tNNG',
#  '가능한 변화들\tNNG',
#  '가든\tNNG',
#  '가디언\tNNG',
#  '가디언스\tNNG',
#  '가디언의 전설\tNNG',
#  '가디언즈\tNNG',
#  '가디언즈 오브 갤럭시\tNNG',
#  '가디언즈 오브 갤럭시 VOL. 2\tNNG',
#  '가라, 가라 두 번째 처녀\tNNG',
#  '가라데 파이터\tNNG',
#  '가라데로 죽여라\tNNG',
#  '가래떡의 맛: 감독판\tNNG',
#  '가려진 시간\tNNG',
#  '가루지기\tNNG',
#  '가루지기: 변강쇠 더 비기닝\tNNG',
#  '가루지기: 변강쇠 더 비기닝 - 무삭제판\tNNG',
#  '가르시아\tNNG',
#  '가름워즈: 마지막 예언자\tNNG',
#  '가면\tNNG',
#  '가면-감춰진 진실\tNNG',
#  '가면속의 아리아\tNNG',
#  '가면의 정사\tNNG',
#  '가문의 부활 - 가문의 영광3\tNNG',
#  '가문의 영광4 - 가문의 수난\tNNG',
#  '가문의 영광5 - 가문의 귀환\tNNG',
#  '가문의 위기(가문의 영광2)\tNNG',
#  '가미카제\tNNG',
#  '가발\tNNG',
#  '가버나움\tNNG',
#  '가베\tNNG',
#  '가벼운 잠\tNNG',
#  '가부와 메이 이야기\tNNG',
#  '가비\tNNG',
#  '가슴 노출을 허하라!\tNNG',
#  '가슴 배구단\tNNG',
#  '가슴 큰 가인\tNNG',
#  '가슴 큰 가인 - 무삭제판\tNNG',
#  '가슴 큰 그녀:질펀한 마사지\tNNG',
#  '가슴 큰 뒷집소녀\tNNG',
#  '가슴 큰 새 누나\tNNG',
#  '가슴 큰 새 누나 2\tNNG',
#  '가슴 큰 새엄마 루미\tNNG',
#  '가슴 큰 앞집 소녀\tNNG',
#  '가슴 큰 여대생\tNNG',
#  '가슴 큰 여동생\tNNG',
#  '가슴 큰 여자선배\tNNG',
#  '가슴 큰 여자선배 무삭제\tNNG',
#  '가슴 큰 여자친구\tNNG',
#  '가슴 큰 여자친구 무삭제판\tNNG',
#  '가슴 큰 연주\tNNG',
#  '가슴 큰 옆집 소녀\tNNG',
#  '가슴 큰 울 엄마\tNNG',
#  '가슴 큰 울 엄마 2\tNNG',
#  '가슴 큰 처제\tNNG',
#  '가슴 큰 처제-무삭제판\tNNG',
#  '가슴 큰 초희\tNNG',
#  '가슴 큰 초희 - 무삭제판\tNNG',
#  '가슴 큰 친구 여친\tNNG',
#  '가슴 큰 친구여친 무삭제\tNNG',
#  '가슴 큰 태희\tNNG',
#  '가슴 큰 태희-무삭제판\tNNG',
#  '가슴 큰 형수\tNNG',
#  '가슴 큰 형수-무삭제판\tNNG',
#  '가슴에 돋는 칼로 슬픔을 자르고\tNNG',
#  '가슴을 탐하는 남자들\tNNG',
#  '가슴이 떨리는 건 너 때문\tNNG',
#  '가슴큰누나들\tNNG',
#  '가슴큰누나들-무삭제\tNNG',
#  '가슴큰며느리\tNNG',
#  '가슴큰며느리-무삭제\tNNG',
#  '가슴큰새엄마\tNNG',
#  '가슴큰새엄마-무삭제\tNNG',
#  '가슴큰엄마들\tNNG',
#  '가슴큰엄마들-무삭제\tNNG',
#  '가슴큰엄마친구\tNNG',
#  '가슴큰엄마친구-무삭제\tNNG',
#  '가슴큰자매들\tNNG',
#  '가슴큰자매들 - 무삭제\tNNG',
#  '가슴큰친구누나들\tNNG',
#  '가슴큰친구누나들-무삭제\tNNG',
#  '가시\tNNG',
#  '가시꽃\tNNG',
#  '가싶녀\tNNG',
#  '가위 : 수면마비의 기억\tNNG',
#  '가위손\tNNG',
#  '가을 소나타\tNNG',
#  '가을 우체국\tNNG',
#  '가을날의 동화\tNNG',
#  '가을날의 재회\tNNG',
#  '가을로\tNNG',
#  '가을비 우산속에\tNNG',
#  '가을의 마티네\tNNG',
#  '가을의 전설\tNNG',
#  '가자 장미여관으로 4\tNNG',
#  '가자 장미여관으로 4 - 무삭제판\tNNG',
#  '가자! 장미여관으로 2 - 갈증\tNNG',
#  '가자! 장미여관으로 3 - 방황\tNNG',
#  '가자! 장미여관으로 3 - 방황 무삭제 감독판\tNNG',
#  '가자, 장미여관으로\tNNG',
#  '가장 따뜻한 색, 블루\tNNG',
#  '가장 보통의 연애\tNNG',
#  '가재가 노래하는 곳\tNNG',
#  '가정교사 길들이기\tNNG',
#  '가정교사-맛있는 섹스 비밀 수업\tNNG',
#  '가정교사: 앞집 아줌마의 수업\tNNG',
#  '가정교사: 하고 싶은 여자\tNNG',
#  '가정교사:만져주기\tNNG',
#  '가정교사의 맛있는 수업\tNNG',
#  '가정교사의 비밀수업\tNNG',
#  '가정교사의 위험한 방문\tNNG',
#  '가정부 길들이기\tNNG',
#  '가정부 길들이기 무삭제판\tNNG',
#  '가정부와의 불륜\tNNG',
#  '가정부의 맛\tNNG',
#  '가정부의 목적\tNNG',
#  '가정부의 목적 무삭제판\tNNG',
#  '가정부의 손맛 감독판\tNNG',
#  '가정부의 유혹\tNNG',
#  '가져선 안될 비밀\tNNG',
#  '가족\tNNG',
#  '가족 연애사\tNNG',
#  '가족사진\tNNG',
#  '가족상속괴담\tNNG',
#  '가족시네마\tNNG',
#  '가족은 괴로워3: 아내여 장미처럼\tNNG',
#  '가족의 나라\tNNG',
#  '가족의 색깔\tNNG',
#  '가족의 재구성\tNNG',
#  '가족의 탄생\tNNG',
#  '가족이 되기까지\tNNG',
#  '가치 캅시다\tNNG',
#  '가투의 연날리기\tNNG',
#  '가필드\tNNG',
#  '가필드 2\tNNG',
#  '가필드 펫 포스 3D\tNNG',
#  '가필드-마법의 샘물\tNNG',
#  '각설탕\tNNG',
#  '각시탈\tNNG',
#  '간 큰 가족\tNNG',
#  '간기남\tNNG',
#  '간디\tNNG',
#  '간병인의 황제서비스\tNNG',
#  '간신\tNNG',
#  '간음:위험한 유부녀들\tNNG',
#  '간이역\tNNG',
#  '간증\tNNG',
#  '간첩\tNNG',
#  '간첩 리철진\tNNG',
#  '간츠\tNNG',
#  '간츠: 오\tNNG',
#  '간츠: 퍼펙트 앤서\tNNG',
#  '간통 : 섹스 회춘 료칸\tNNG',
#  '간통: 사장님의 아내\tNNG',
#  '간호사와 음란 마사지\tNNG',
#  '간호중\tNNG',
#  '갇힌 여인\tNNG',
#  '갈까부다\tNNG',
#  '갈리폴리 상륙작전\tNNG',
#  '갈리폴리: 최악의 상륙작전\tNNG',
#  '갈매기\tNNG',
#  '갈증\tNNG',
#  '감금당한 청순미인의 절정\tNNG',
#  '감금당해 범해지는 청순미인\tNNG',
#  '감금의 시간\tNNG',
#  '감금의 시간 2 무삭제\tNNG',
#  '감금의 정사\tNNG',
#  '감금일지-메이드\tNNG',
#  '감기\tNNG',
#  '감당이 안되는 욕정녀\tNNG',
#  '감독 미카엘 하네케\tNNG',
#  '감동주의보\tNNG',
#  '감바의 대모험\tNNG',
#  '감성에 젖은 음대선생님\tNNG',
#  '감시자들\tNNG',
#  '감염: 지구 최후의 날\tNNG',
#  '감옥정사\tNNG',
#  '감옥풍운\tNNG',
#  '감자\tNNG',
#  '감자심포니\tNNG',
#  '감쪽같은 그녀\tNNG',
#  '감출 수 없는 본능-몰카\tNNG',
#  '갑질당하는 육덕가정부\tNNG',
#  '갑질섹스-색기\tNNG',
#  '갓 앤 몬스터\tNNG',
#  '갓 오브 이집트\tNNG',
#  '갓 헬프 더 걸\tNNG',
#  '갓길로 달리는 코뿔소\tNNG',
#  '갓센드\tNNG',
#  '갓즈 포켓\tNNG',
#  '갓파 쿠와 여름방학을\tNNG',
#  '강간 몰카 유출 사건\tNNG',
#  '강남 1970\tNNG',
#  '강남 며느리\tNNG',
#  '강력 3반\tNNG',
#  '강력 범죄\tNNG',
#  '강령\tNNG',
#  '강릉\tNNG',
#  '강변호텔\tNNG',
#  '강시: 리거모티스\tNNG',
#  '강시선생 -일미도인\tNNG',
#  '강시선생 2\tNNG',
#  '강시선생 3 - 영환도사\tNNG',
#  '강아지 삼총사\tNNG',
#  '강원도의 힘\tNNG',
#  '강을 건너는 사람들\tNNG',
#  '강적\tNNG',
#  '강제 섹스:거절하다 신음\tNNG',
#  '강제로 당하는 새엄마\tNNG',
#  '강제섹스: 그 남자의 섹스방식\tNNG',
#  '강철대오:구국의 철가방\tNNG',
#  '강철비\tNNG',
#  '강철비2 : 정상회담 확장판\tNNG',
#  '강철비2: 정상회담\tNNG',
#  '강철의 연금술사 : 미로스의 성스러운 별\tNNG',
#  '강철중+크로싱+쿵푸 팬더\tNNG',
#  '강철중: 공공의 적 1-1\tNNG',
#  '강철중:공공의 적1-1+인크레더블 헐크+겟 스마트\tNNG',
#  '강한 칼: 도도견혈\tNNG',
#  '강호\tNNG',
#  '강호아녀\tNNG',
#  '강호의 무림신공\tNNG',
#  '강호제일검 금강철선\tNNG',
#  '같은 달을 보고 있다\tNNG',
#  '같은 속옷을 입는 두 여자\tNNG',
#  '개 같은 것들\tNNG',
#  '개: dog eat dog\tNNG',
#  '개같은 날의 오후\tNNG',
#  '개같은 내인생\tNNG',
#  '개구리왕국\tNNG',
#  '개구리왕국 2\tNNG',
#  '개구리중사 케로로\tNNG',
#  '개구쟁이 스머프\tNNG',
#  '개구쟁이 스머프 2\tNNG',
#  '개그 더 크라운\tNNG',
#  '개그맨\tNNG',
#  '개들의 섬\tNNG',
#  '개들의 전쟁\tNNG',
#  '개똥이\tNNG',
#  '개를 훔치는 완벽한 방법\tNNG',
#  '개벽\tNNG',
#  '개선문\tNNG',
#  '개에게 처음 이름을 지어준 날\tNNG',
#  '개와 늑대 사이의 시간\tNNG',
#  '개인교수 2014\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법\tNNG',
#  '개인교수 : 맛있게 섹스하는 방법(무삭제)\tNNG',
#  '개인교수 : 성적 올리기\tNNG',
#  '개인교수 : 성적 올리기 무삭제\tNNG',
#  '개인교수 : 세 여자의 섹스수업\tNNG',
#  '개인교수 : 여친 만족 시키기\tNNG',
#  '개인교수 : 여친 만족 시키기 무삭제\tNNG',
#  '개인교수: 심화학습\tNNG',
#  '개인교수: 심화학습 (무삭제)\tNNG',
#  '개인교습\tNNG',
#  '개인교습: 사촌여동생\tNNG',
#  '개인레슨\tNNG',
#  '개인영업 : 업소녀가 된 아내\tNNG',
#  '개인지도:붓으로 그리는 황홀경\tNNG',
#  '갤럭시 히어로즈: 라쳇 앤 클랭크\tNNG',
#  '갤로우즈\tNNG',
#  '갤로워커: 블레이드의 귀환\tNNG',
#  '갤버스턴\tNNG',
#  '갬빗\tNNG',
#  '갯마을\tNNG',
#  '갱\tNNG',
#  '갱 브라더스: 마지막 대결\tNNG',
#  '갱경떡삥이\tNNG',
#  '갱스터 초치\tNNG',
#  '거근이 좋아\tNNG',
#  '거기엔 래퍼가 없다\tNNG',
#  '거꾸로 된 파테마\tNNG',
#  '거대 불개미의 습격\tNNG',
#  '거대말벌의 습격\tNNG',
#  '거대한 서부\tNNG',
#  '거래완료\tNNG',
#  '거래처 여직원\tNNG',
#  '거룩한 계보\tNNG',
#  '거룩한 분노\tNNG',
#  '거룩한 소녀 마리아\tNNG',
#  '거리의 보안관\tNNG',
#  '거미숲\tNNG',
#  '거미의 계략\tNNG',
#  '거미의 땅\tNNG',
#  '거미줄에 걸린 소녀\tNNG',
#  '거부하다 신음하는 여자\tNNG',
#  '거북이 달린다\tNNG',
#  '거북이도 난다\tNNG',
#  '거울나라의 앨리스\tNNG',
#  '거유 며느리의 은밀한 일탈\tNNG',
#  '거유 며느리의 친정나들이\tNNG',
#  '거유 바니걸 리나\tNNG',
#  '거유 새엄마와 형제들\tNNG',
#  '거유 여사장의 약점\tNNG',
#  '거유 와이프:남편 대신 상사와\tNNG',
#  '거유 유부녀의 오일 마사지\tNNG',
#  '거유 장모와 실제로 느끼는 사위\tNNG',
#  '거유 치과 간호사\tNNG',
#  '거유 치나미 사쿠라의 아찔 유혹\tNNG',
#  '거유 칸나의 질펀한 서비스\tNNG',
#  '거유간호사 폭유간호사\tNNG',
#  '거유녀들의 아찔한 가슴골\tNNG',
#  '거유녀의 젖어버린 작업복\tNNG',
#  '거유미녀 서큐버스2\tNNG',
#  '거유이발소-어서오세요\tNNG',
#  '거인\tNNG',
#  '거지의 오페라\tNNG',
#  '거짓말\tNNG',
#  '거짓말 2014\tNNG',
#  '거짓말 2018: 감독판\tNNG',
#  '거짓말 : 여자 모델의 섹스\tNNG',
#  '거짓말 : 여자 모델의 섹스 무삭제\tNNG',
#  '거짓말 섹스가 좋아\tNNG',
#  '거짓말 섹스가 좋아2\tNNG',
#  '거짓말 애인-감독판\tNNG',
#  '거짓의\tNNG',
#  '거친 녀석들\tNNG',
#  '거친 섹스에 빠진 그녀들\tNNG',
#  '거칠마루\tNNG',
#  '거침없이 쏴라! 슛뎀업\tNNG',
#  '걱정말아요\tNNG',
#  '건\tNNG',
#  '건 샤이\tNNG',
#  '건달 가정부\tNNG',
#  '건달티처\tNNG',
#  '건마의 신: 어린 아내의 알바\tNNG',
#  '건양강호: 운뢰검법의 비밀\tNNG',
#  '건우먼\tNNG',
#  '건즈 아킴보\tNNG',
#  '건즈 포 하이어\tNNG',
#  '건축학개론\tNNG',
#  '건파우더 밀크셰이크\tNNG',
#  '걷기 좋은 날\tNNG',
#  '걷기왕\tNNG',
#  '걸\tNNG',
#  '걸 아바타\tNNG',
#  '걸 온 더 브릿지\tNNG',
#  '걸 온 더 트레인\tNNG',
#  '걸 위드 더 카메라\tNNG',
#  '걸 인 더 포토그래프\tNNG',
#  '걸리버 리턴즈\tNNG',
#  '걸리버 여행기\tNNG',
#  '걸스\tNNG',
#  '걸스 곤 데드\tNNG',
#  '걸스 나잇\tNNG',
#  '걸스 스텝\tNNG',
#  '걸스 온 탑2\tNNG',
#  '걸스카우트\tNNG',
#  '걸어도 걸어도\tNNG',
#  '걸작\tNNG',
#  '걸즈 앤 판처 극장판\tNNG',
#  '걸즈 앤 판처 제\u200b 63회 전차도 전국 고교생 대회\tNNG',
#  '걸즈 앤 판처 최종장\tNNG',
#  '걸즈 앤 판처 최종장 제1화\tNNG',
#  '걸즈 앤 판처 최종장 제3화\tNNG',
#  '걸캅스\tNNG',
#  '걸캅스 누나들\tNNG',
#  '걸프렌즈\tNNG',
#  '걸후드\tNNG',
#  '검객\tNNG',
#  '검객풍운\tNNG',
#  '검사외전\tNNG',
#  '검우강호\tNNG',
#  '검은 고양이 흰 고양이\tNNG',
#  '검은 땅의 소녀와\tNNG',
#  '검은 물밑에서\tNNG',
#  '검은 사제들\tNNG',
#  '검은 사제들: 지옥의 문\tNNG',
#  '검은 숲\tNNG',
#  '검은 여름\tNNG',
#  '검은 집\tNNG',
#  '검은 집: 죽음을 보는 눈\tNNG',
#  '검은비: 악의연대기\tNNG',
#  '검은손\tNNG',
#  '겁나는 여친의 완벽한 비밀\tNNG',
#  '겁쟁이 페달: 더 무비\tNNG',
#  '겁쟁이 페달: 리라이드\tNNG',
#  '겁쟁이 페달: 리로드\tNNG',
#  '겁쟁이 페달: 스페어 바이크\tNNG',
#  '겁탈당한 유부녀\tNNG',
#  '겁탈당한 유부녀 무삭제판\tNNG',
#  '게드전기 : 어스시의 전설\tNNG',
#  '게발트 파이브:구타본능\tNNG',
#  '게스트하우스\tNNG',
#  '게스후\tNNG',
#  '게이머\tNNG',
#  '게이샤 하우스\tNNG',
#  '게이샤:격정정사\tNNG',
#  ...]

# %%
with open('d:/2nd_project/Data/new_user_dic.txt', 'w', encoding='utf8') as f:
    for item in new_user_dict:
        f.write("%s\n" % item)
