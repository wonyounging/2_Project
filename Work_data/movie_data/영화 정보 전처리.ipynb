# %%
import pandas as pd

# %%
df = pd.read_csv('c:/2nd_project/Data/movie_data/원본/xlsx 파일 2003~2022년/(완)[KOBIS] 박스오피스_일별(2003~2022)_장르_수정.csv')
df
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# ...

# %%
df.isnull().sum()
# Out:
# 순위            0
# 영화명           0
# 개봉일           0
# 등급         6734
# 장르            0
# 대표국적         38
# 국적           38
# 제작사      269504
# 배급사       17714
# 감독        13145
# 배우        35727
# 기준일           0
# 매출액           0
# 누적매출액         0
# 관객수           0
# 누적관객수         0
# 스크린수          0
# 상영횟수          0
# dtype: int64

# %% [markdown]
# # 컬럼 공백 제거

# %%
old_col_name = ['순위', '영화명', '개봉일', '등급 ', '장르 ', '대표국적 ', 
                '국적 ', '제작사 ', '배급사 ','감독 ', '배우 ','기준일',
                '매출액','누적매출액 ','관객수 ','누적관객수 ','스크린수 ', 
                '상영횟수 ']
new_col_name = ['순위', '영화명', '개봉일', '등급', '장르', '대표국적', 
                '국적', '제작사', '배급사','감독', '배우','기준일',
                '매출액','누적매출액','관객수','누적관객수','스크린수', 
                '상영횟수']

# %%
# new_col_list = ['영화명', '개봉일', '등급', '장르', '대표국적', '국적', '제작사', '배급사', '감독', '배우']

# %%
df_copy = df.copy()
df_copy
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# ...

# %%
# df_copy = df[old_col_name].copy()
# df_copy

# %%
df_copy.columns = new_col_name
df_copy
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482752 entries, 0 to 482751
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   순위      482752 non-null  int64
#  1   영화명     482752 non-null  object
#  2   개봉일     482752 non-null  object
#  3   등급      476018 non-null  object
#  4   장르      482752 non-null  object
#  5   대표국적    482714 non-null  object
#  6   국적      482714 non-null  object
#  7   제작사     213248 non-null  object
#  8   배급사     465038 non-null  object
#  9   감독      469607 non-null  object
#  10  배우      447025 non-null  object
#  11  기준일     482752 non-null  object
#  12  매출액     482752 non-null  int64
#  13  누적매출액   482752 non-null  int64
#  14  관객수     482752 non-null  int64
#  15  누적관객수   482752 non-null  int64
#  16  스크린수    482752 non-null  int64
#  17  상영횟수    482752 non-null  int64
# dtypes: int64(7), object(11)
# memory usage: 66.3+ MB

# %% [markdown]
# # 개봉일 결측인 행 제거

# %%
df_copy = df_copy[df_copy['개봉일'].isnull() == False]
df_copy
# Out:
#         순위                영화명         개봉일        등급        장르 대표국적  국적  \
# 0        1          동갑내기 과외하기  2003-02-07    12세관람가       코미디   한국  한국
# 1        1         매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄   미국  미국
# 2        2             위대한 유산  2003-10-24    15세관람가       코미디   한국  한국
# 3        3                황산벌  2003-10-17    15세관람가       코미디   한국  한국
# 4        4              아이덴티티  2003-10-31    15세관람가    범죄,스릴러   미국  미국
# ...     ..                ...         ...       ...       ...  ...  ..
# 482747  34              애프터 양  2022-06-01     전체관람가    드라마,SF   미국  미국
# 482748  31               더 메뉴  2022-12-07  15세이상관람가       스릴러   미국  미국
# 482749  28  양자경의 더 모든 날 모든 순간  2022-11-23  15세이상관람가    액션,코미디   미국  미국
# 482750  26           캐리와 슈퍼콜라  2023-01-18     전체관람가     애니메이션   한국  한국
# 482751  30                 수라  2023-06-21     전체관람가     다큐멘터리   한국  한국
#
#                     제작사                   배급사               감독  \
# ...

# %% [markdown]
# # 기준일 기준 오름차순 정렬

# %%
df_copy = df_copy.sort_values(by=['기준일'])
df_copy
# Out:
#          순위         영화명         개봉일        등급        장르   대표국적     국적  \
# 0         1   동갑내기 과외하기  2003-02-07    12세관람가       코미디     한국     한국
# 1         1  매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄     미국     미국
# 2         2      위대한 유산  2003-10-24    15세관람가       코미디     한국     한국
# 3         3         황산벌  2003-10-17    15세관람가       코미디     한국     한국
# 4         4       아이덴티티  2003-10-31    15세관람가    범죄,스릴러     미국     미국
# ...     ...         ...         ...       ...       ...    ...    ...
# 482687  100        더 게임  2022-12-08  15세이상관람가   드라마,스릴러    헝가리    헝가리
# 482686  100          성덕  2022-09-28  12세이상관람가     다큐멘터리     한국     한국
# 482685  100          나나  2022-12-15  15세이상관람가       드라마  인도네시아  인도네시아
# 482683   87          초선  2022-11-03  12세이상관람가     다큐멘터리     한국     한국
# 482751   30          수라  2023-06-21     전체관람가     다큐멘터리     한국     한국
#
#                     제작사            배급사               감독  \
# 0            코리아 엔터테인먼트         CJ ENM              김경형
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 482752 entries, 0 to 482751
# Data columns (total 18 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   순위      482752 non-null  int64
#  1   영화명     482752 non-null  object
#  2   개봉일     482752 non-null  object
#  3   등급      476018 non-null  object
#  4   장르      482752 non-null  object
#  5   대표국적    482714 non-null  object
#  6   국적      482714 non-null  object
#  7   제작사     213248 non-null  object
#  8   배급사     465038 non-null  object
#  9   감독      469607 non-null  object
#  10  배우      447025 non-null  object
#  11  기준일     482752 non-null  object
#  12  매출액     482752 non-null  int64
#  13  누적매출액   482752 non-null  int64
#  14  관객수     482752 non-null  int64
#  15  누적관객수   482752 non-null  int64
#  16  스크린수    482752 non-null  int64
#  17  상영횟수    482752 non-null  int64
# dtypes: int64(7), object(11)
# memory usage: 70.0+ MB

# %% [markdown]
# # 장르 : 성인물, 공연 제거

# %%
df_copy = df_copy[(df_copy["장르"].str.contains("성인물",na=True)==False)&
                     (df_copy["장르"].str.contains("공연",na=True)==False)]
df_copy.shape
# Out:
# (482752, 18)

# %%
df_copy
# Out:
#          순위         영화명         개봉일        등급        장르   대표국적     국적  \
# 0         1   동갑내기 과외하기  2003-02-07    12세관람가       코미디     한국     한국
# 1         1  매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄     미국     미국
# 2         2      위대한 유산  2003-10-24    15세관람가       코미디     한국     한국
# 3         3         황산벌  2003-10-17    15세관람가       코미디     한국     한국
# 4         4       아이덴티티  2003-10-31    15세관람가    범죄,스릴러     미국     미국
# ...     ...         ...         ...       ...       ...    ...    ...
# 482687  100        더 게임  2022-12-08  15세이상관람가   드라마,스릴러    헝가리    헝가리
# 482686  100          성덕  2022-09-28  12세이상관람가     다큐멘터리     한국     한국
# 482685  100          나나  2022-12-15  15세이상관람가       드라마  인도네시아  인도네시아
# 482683   87          초선  2022-11-03  12세이상관람가     다큐멘터리     한국     한국
# 482751   30          수라  2023-06-21     전체관람가     다큐멘터리     한국     한국
#
#                     제작사            배급사               감독  \
# 0            코리아 엔터테인먼트         CJ ENM              김경형
# ...

# %%
df_copy.to_csv('c:/2nd_project/Data/movie_data/2003~2022_merge_mid.csv', index = None)

# %% [markdown]
# # 중복 영화명 제거

# %%
movie_df = pd.read_csv('c:/2nd_project/Data/movie_data/2003~2022_merge_mid.csv')
movie_df
# Out:
#          순위         영화명         개봉일        등급        장르   대표국적     국적  \
# 0         1   동갑내기 과외하기  2003-02-07    12세관람가       코미디     한국     한국
# 1         1  매트릭스3 레볼루션  2003-11-05    15세관람가  SF,액션,범죄     미국     미국
# 2         2      위대한 유산  2003-10-24    15세관람가       코미디     한국     한국
# 3         3         황산벌  2003-10-17    15세관람가       코미디     한국     한국
# 4         4       아이덴티티  2003-10-31    15세관람가    범죄,스릴러     미국     미국
# ...     ...         ...         ...       ...       ...    ...    ...
# 482747  100        더 게임  2022-12-08  15세이상관람가   드라마,스릴러    헝가리    헝가리
# 482748  100          성덕  2022-09-28  12세이상관람가     다큐멘터리     한국     한국
# 482749  100          나나  2022-12-15  15세이상관람가       드라마  인도네시아  인도네시아
# 482750   87          초선  2022-11-03  12세이상관람가     다큐멘터리     한국     한국
# 482751   30          수라  2023-06-21     전체관람가     다큐멘터리     한국     한국
#
#                     제작사            배급사               감독  \
# 0            코리아 엔터테인먼트         CJ ENM              김경형
# ...

# %%
len(movie_df['영화명'].unique())
# Out:
# 17768

# %%
movie_df[movie_df['영화명'] == '드림']
# Out:
# Empty DataFrame
# Columns: [순위, 영화명, 개봉일, 등급, 장르, 대표국적, 국적, 제작사, 배급사, 감독, 배우, 기준일, 매출액, 누적매출액, 관객수, 누적관객수, 스크린수, 상영횟수]
# Index: []

# %%
movie_df.columns
# Out:
# Index(['순위', '영화명', '개봉일', '등급', '장르', '대표국적', '국적', '제작사', '배급사', '감독', '배우',
#        '기준일', '매출액', '누적매출액', '관객수', '누적관객수', '스크린수', '상영횟수'],
#       dtype='object')

# %%
movie_df = movie_df.groupby(['영화명', '개봉일']).agg({
    '등급' : 'first',
    '장르' : 'first',
    '대표국적' : 'first',
    '국적' : 'first',
    '제작사' : 'first',
    '배급사' : 'first',
    '감독' : 'first',
    '배우' : 'first',
    '누적관객수' : 'max'
}).reset_index()

movie_df
# Out:
#                 영화명         개봉일        등급          장르 대표국적   국적  \
# 0             #살아있다  2020-06-24  15세이상관람가         드라마   한국   한국
# 1            #아이엠히어  2021-01-14  12세이상관람가  멜로/로맨스,코미디  프랑스  프랑스
# 2             #위왓치유  2021-06-03   청소년관람불가       다큐멘터리   기타   기타
# 3            ...ing  2003-11-28    12세관람가  드라마,멜로/로맨스   한국   한국
# 4            0.0MHz  2019-05-29  15세이상관람가      공포(호러)   한국   한국
# ...             ...         ...       ...         ...  ...  ...
# 18144     힘내세요, 병헌씨  2013-06-27  15세이상관람가     코미디,드라마   한국   한국
# 18145  힘을 내요, 미스터 리  2019-09-11  12세이상관람가     코미디,드라마   한국   한국
# 18146    힙스터: 안개의 덫  2015-10-21   청소년관람불가  멜로/로맨스,드라마   한국   한국
# 18147            힛쳐  2007-08-01   청소년관람불가   액션,범죄,스릴러   미국   미국
# 18148    ＡＶ여배우의 자취방  2017-05-01   청소년관람불가      멜로/로맨스   일본   일본
#
#                      제작사                  배급사                감독  \
# 0      영화사 집,(주)퍼스펙티브픽쳐스    롯데컬처웍스(주)롯데엔터테인먼트               조일형
# 1                   None  (주)넥스트엔터테인먼트월드(NEW)            에릭 라티고
# ...

# %%
movie_df[movie_df['영화명'] == '드림']

# %%
movie_df[movie_df['개봉일'] == '2023-08-03']

# %% [markdown]
# # 23년 1월 1일 ~ 23년 7월 31일 사이 개봉한 영화

# %%
from datetime import datetime

# '개봉일' 컬럼을 datetime 형식으로 변환
movie_df['개봉일'] = pd.to_datetime(movie_df['개봉일'])
movie_df['영화명'] = movie_df['영화명'].astype(str)

# # '개봉일'이 2023년 1월 1일부터 2023년 7월 31일 사이인 데이터만 선택
# movie_df = movie_df[(movie_df['개봉일'] >= datetime(2023, 1, 1)) & (movie_df['개봉일'] <= datetime(2023, 7, 31))]
movie_df = movie_df[(movie_df['개봉일'] <= datetime(2022, 12, 31))]
movie_df
# Out:
#                 영화명        개봉일        등급          장르 대표국적   국적  \
# 0             #살아있다 2020-06-24  15세이상관람가         드라마   한국   한국
# 1            #아이엠히어 2021-01-14  12세이상관람가  멜로/로맨스,코미디  프랑스  프랑스
# 2             #위왓치유 2021-06-03   청소년관람불가       다큐멘터리   기타   기타
# 3            ...ing 2003-11-28    12세관람가  드라마,멜로/로맨스   한국   한국
# 4            0.0MHz 2019-05-29  15세이상관람가      공포(호러)   한국   한국
# ...             ...        ...       ...         ...  ...  ...
# 18144     힘내세요, 병헌씨 2013-06-27  15세이상관람가     코미디,드라마   한국   한국
# 18145  힘을 내요, 미스터 리 2019-09-11  12세이상관람가     코미디,드라마   한국   한국
# 18146    힙스터: 안개의 덫 2015-10-21   청소년관람불가  멜로/로맨스,드라마   한국   한국
# 18147            힛쳐 2007-08-01   청소년관람불가   액션,범죄,스릴러   미국   미국
# 18148    ＡＶ여배우의 자취방 2017-05-01   청소년관람불가      멜로/로맨스   일본   일본
#
#                      제작사                  배급사                감독  \
# 0      영화사 집,(주)퍼스펙티브픽쳐스    롯데컬처웍스(주)롯데엔터테인먼트               조일형
# 1                   None  (주)넥스트엔터테인먼트월드(NEW)            에릭 라티고
# ...

# %% [markdown]
# # 최종 데이터

# %%
movie_df.to_csv('c:/2nd_project/Data/movie_data/2003~2022_movie_fix.csv', index=None)
